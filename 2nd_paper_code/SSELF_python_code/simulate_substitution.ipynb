# %%
# simulate_substitution.ipynb

import random
import time
import pandas as pd
import numpy as np
from substitution_extension import ClassificationDatabase, SalesDatabase, Product, Company, System
from SSELF_base import FootprintDatabase

# Step 1: Set up classification data
classification_data = [
    {"class_code": "HS 2517", "class_name": "Crushed stone", "function": "Fills space", "unit": "m3"},
    {"class_code": "HS 2905", "class_name": "Alcohols", "function": "Chemical feedstock", "unit": "kg"},
    {"class_code": "HS 2618", "class_name": "Slag", "function": "Binder", "unit": "kg"},
]
classification_db = ClassificationDatabase(classification_data)

# Step 2: Initialize sales database for last year
last_year_sales = SalesDatabase(2023, classification_db)
product_1 = Product(12, "Granite", "m3", "Company_11", "HS 2517", "primary", 0.5, classification_db)
product_2 = Product(14, "Glycerol", "kg", "Company_12", "HS 2905", "primary", 0.05, classification_db)
product_3 = Product(16, "Slag", "kg", "Company_13", "HS 2618", "primary", 0.7, classification_db)

last_year_sales.add_sales(product_1, 1000)
last_year_sales.add_sales(product_2, 2000)
last_year_sales.add_sales(product_3, 3000)

# Step 3: Add dummy entries to last_year_sales
codes = classification_db.data['class_code'].unique()
next_id = 17
extras = []
base_function_outputs = {
    "HS 2517": 0.5,
    "HS 2905": 0.05,
    "HS 2618": 0.7,
}

for code in codes:
    for _ in range(2):
        unit = classification_db.get_class_info(code)[2]
        extras.append({
            "id": next_id,
            "class_code": code,
            "sales_volume": np.random.uniform(500, 2000),
            "unit": unit,
            "function_output": base_function_outputs[code],  #  Use fixed value
        })
        next_id += 1
last_year_sales.data = pd.concat([last_year_sales.data, pd.DataFrame(extras)], ignore_index=True)

# Step 4: Build the system
system = System(num_companies=13, num_products=19, classification_db=classification_db)

# Add co-products manually to companies 11, 12, and 13
co_product_details = [
    ("Crushed granite", "HS 2517", 0.025),
    ("Glycerol", "HS 2905", 0.05),
    ("Blast Furnace Slag", "HS 2618", 0.1)
]
for i, (name, code, fout) in enumerate(co_product_details):
    company = system.companies[f"Company_{11 + i}"]
    new_id = 17 + i  # Continuing from next_id above
    co_product = Product(new_id, name, "kg", company, code, "secondary", fout, classification_db)
    company.add_product(co_product)
    if company.sales.empty:
        company.sales = pd.DataFrame(columns=["Sales"])
    company.sales.loc[new_id] = [100]

# Step 5: Create and initialize footprint databases
fp_2023 = FootprintDatabase(2023)
fp_2024 = FootprintDatabase(2024)

# Initialize 2023/2024 footprints for all actual products
for company in system.companies.values():
    for product in company.products:
        fp_2023.report(product.product_id, random.uniform(1, 100))
        fp_2024.report(product.product_id, 0)

# Also initialize dummy entries from last_year_sales to support substitution logic
for row in last_year_sales.data.itertuples():
    if row.id not in fp_2023.data["id"].values:
        fp_2023.report(row.id, random.uniform(1, 100))


# Step 6: Solve
result = system.solve(
    fp_2024=fp_2024,
    fp_2023=fp_2023,
    last_year_sales=last_year_sales,
    atol=1e-6,
    max_iter=200,
    schedule="random",  # or "cyclic" for fixed order
    seed=42,            # set for reproducibility if using "random"
    verbose=True,
    patience=1,
)
print("\nResult:", result)

# Final reporting (unchanged)
print("\n Final Footprints:")
for cname, comp in system.companies.items():
    print(f"{cname}: {comp.latest_update:.4f} kg CO2e/unit")

print("\n Update Count:")
total_updates = sum(c.num_updates for c in system.companies.values())
for cname, comp in system.companies.items():
    print(f"{cname}: {comp.num_updates} updates")
print(f"Total updates: {total_updates}")

print("\n Carbon balance check:")
for name, company in system.companies.items():
    company.check_carbon_balance(fp_2024)


# Final reporting
print("\n Final Footprints:")
for cname, comp in system.companies.items():
    print(f"{cname}: {comp.latest_update:.4f} kg CO2e/unit")

print("\n Update Count:")
total_updates = sum(c.num_updates for c in system.companies.values())
for cname, comp in system.companies.items():
    print(f"{cname}: {comp.num_updates} updates")
print(f"Total updates: {total_updates}")

print("\n Carbon balance check:")
for name, company in system.companies.items():
    company.check_carbon_balance(fp_2024)
# Out:
# --- Iteration 1 ---
#
# [Company_8] Checking product 8 (Product 8)
#   Current footprint: 0.000000, Simulated footprint: 7.543280
#   Difference: 7.543280
# Company_8 was updated.
#
# [Company_7] Checking product 7 (Product 7)
#   Current footprint: 0.000000, Simulated footprint: 12.181515
#   Difference: 12.181515
# Company_7 was updated.
#
# [Company_3] Checking product 3 (Product 3)
#   Current footprint: 0.000000, Simulated footprint: 10.172326
#   Difference: 10.172326
# Company_3 was updated.
#
# [Company_10] Checking product 10 (Product 10)
#   Current footprint: 0.000000, Simulated footprint: 25.897008
#   Difference: 25.897008
# Company_10 was updated.
#   [DEBUG] Average footprint for HS 2618: total impact = 101950.1837, weight = 3594.9310
#
# [Company_13] Checking product 13 (Product 13)
#   Current footprint: 0.000000, Simulated footprint: 4.341618
#   Difference: 4.341618
# Company_13 was updated.
#   [DEBUG] Average footprint for HS 2618: total impact = 101950.1837, weight = 3594.9310
#
# [Company_6] Checking product 6 (Product 6)
#   Current footprint: 0.000000, Simulated footprint: 15.982577
#   Difference: 15.982577
# Company_6 was updated.
#   [DEBUG] Average footprint for HS 2905: total impact = 14019.3536, weight = 190.7712
#
# [Company_12] Checking product 12 (Product 12)
#   Current footprint: 0.000000, Simulated footprint: 3.078592
#   Difference: 3.078592
# Company_12 was updated.
#   [DEBUG] Average footprint for HS 2905: total impact = 14019.3536, weight = 190.7712
#
# [Company_9] Checking product 9 (Product 9)
#   Current footprint: 0.000000, Simulated footprint: 15.218303
#   Difference: 15.218303
# Company_9 was updated.
#
# [Company_4] Checking product 4 (Product 4)
#   Current footprint: 0.000000, Simulated footprint: 22.684673
#   Difference: 22.684673
# Company_4 was updated.
#
# [Company_5] Checking product 5 (Product 5)
#   Current footprint: 0.000000, Simulated footprint: 6.422511
#   Difference: 6.422511
# Company_5 was updated.
#
# [Company_1] Checking product 1 (Product 1)
#   Current footprint: 0.000000, Simulated footprint: 6.200193
#   Difference: 6.200193
# Company_1 was updated.
#
# [Company_2] Checking product 2 (Product 2)
#   Current footprint: 0.000000, Simulated footprint: 14.518562
#   Difference: 14.518562
# Company_2 was updated.
#   [DEBUG] Average footprint for HS 2517: total impact = 118640.0324, weight = 1630.9542
#
# [Company_11] Checking product 11 (Product 11)
#   Current footprint: 0.000000, Simulated footprint: 3.766365
#   Difference: 3.766365
# Company_11 was updated.
#   [DEBUG] Average footprint for HS 2517: total impact = 118640.0324, weight = 1630.9542
#
# --- Iteration 2 ---
#
# [Company_3] Checking product 3 (Product 3)
#   Current footprint: 10.172326, Simulated footprint: 14.311621
#   Difference: 4.139296
# Company_3 was updated.
#
# [Company_6] Checking product 6 (Product 6)
#   Current footprint: 15.982577, Simulated footprint: 18.391063
#   Difference: 2.408486
# Company_6 was updated.
#
# [Company_8] Checking product 8 (Product 8)
#   Current footprint: 7.543280, Simulated footprint: 12.529578
#   Difference: 4.986298
# Company_8 was updated.
#
# [Company_9] Checking product 9 (Product 9)
#   Current footprint: 15.218303, Simulated footprint: 17.333257
#   Difference: 2.114954
# Company_9 was updated.
#
# [Company_7] Checking product 7 (Product 7)
#   Current footprint: 12.181515, Simulated footprint: 16.629170
#   Difference: 4.447655
# Company_7 was updated.
#   [DEBUG] Average footprint for HS 2517: total impact = 118640.0324, weight = 1630.9542
#
# [Company_11] Checking product 11 (Product 11)
#   Current footprint: 3.766365, Simulated footprint: 4.424939
#   Difference: 0.658574
# Company_11 was updated.
#   [DEBUG] Average footprint for HS 2517: total impact = 118640.0324, weight = 1630.9542
#
# [Company_5] Checking product 5 (Product 5)
#   Current footprint: 6.422511, Simulated footprint: 8.015988
#   Difference: 1.593476
# Company_5 was updated.
#   [DEBUG] Average footprint for HS 2905: total impact = 14019.3536, weight = 190.7712
#
# [Company_12] Checking product 12 (Product 12)
#   Current footprint: 3.078592, Simulated footprint: 7.153182
#   Difference: 4.074591
# Company_12 was updated.
#   [DEBUG] Average footprint for HS 2905: total impact = 14019.3536, weight = 190.7712
#
# [Company_10] Checking product 10 (Product 10)
#   Current footprint: 25.897008, Simulated footprint: 30.713573
#   Difference: 4.816565
# Company_10 was updated.
#
# [Company_4] Checking product 4 (Product 4)
#   Current footprint: 22.684673, Simulated footprint: 25.067483
#   Difference: 2.382810
# Company_4 was updated.
#
# [Company_2] Checking product 2 (Product 2)
#   Current footprint: 14.518562, Simulated footprint: 15.740094
#   Difference: 1.221531
# Company_2 was updated.
#   [DEBUG] Average footprint for HS 2618: total impact = 101950.1837, weight = 3594.9310
#
# [Company_13] Checking product 13 (Product 13)
#   Current footprint: 4.341618, Simulated footprint: 8.485586
#   Difference: 4.143967
# Company_13 was updated.
#   [DEBUG] Average footprint for HS 2618: total impact = 101950.1837, weight = 3594.9310
#
# [Company_1] Checking product 1 (Product 1)
#   Current footprint: 6.200193, Simulated footprint: 8.269853
#   Difference: 2.069660
# Company_1 was updated.
#
# --- Iteration 3 ---
#   [DEBUG] Average footprint for HS 2905: total impact = 14019.3536, weight = 190.7712
#
# [Company_12] Checking product 12 (Product 12)
#   Current footprint: 7.153182, Simulated footprint: 7.783169
#   Difference: 0.629987
# Company_12 was updated.
#   [DEBUG] Average footprint for HS 2905: total impact = 14019.3536, weight = 190.7712
#
# [Company_4] Checking product 4 (Product 4)
#   Current footprint: 25.067483, Simulated footprint: 25.377616
#   Difference: 0.310133
# Company_4 was updated.
#   [DEBUG] Average footprint for HS 2517: total impact = 118640.0324, weight = 1630.9542
#
# [Company_11] Checking product 11 (Product 11)
#   Current footprint: 4.424939, Simulated footprint: 5.127411
#   Difference: 0.702472
# Company_11 was updated.
#   [DEBUG] Average footprint for HS 2517: total impact = 118640.0324, weight = 1630.9542
#
# [Company_9] Checking product 9 (Product 9)
#   Current footprint: 17.333257, Simulated footprint: 18.187877
#   Difference: 0.854620
# Company_9 was updated.
#
# [Company_8] Checking product 8 (Product 8)
#   Current footprint: 12.529578, Simulated footprint: 13.493224
#   Difference: 0.963646
# Company_8 was updated.
#
# [Company_2] Checking product 2 (Product 2)
#   Current footprint: 15.740094, Simulated footprint: 16.057708
#   Difference: 0.317615
# Company_2 was updated.
#   [DEBUG] Average footprint for HS 2618: total impact = 101950.1837, weight = 3594.9310
#
# [Company_13] Checking product 13 (Product 13)
#   Current footprint: 8.485586, Simulated footprint: 8.673384
#   Difference: 0.187799
# Company_13 was updated.
#   [DEBUG] Average footprint for HS 2618: total impact = 101950.1837, weight = 3594.9310
#
# [Company_6] Checking product 6 (Product 6)
#   Current footprint: 18.391063, Simulated footprint: 19.468728
#   Difference: 1.077665
# Company_6 was updated.
#
# [Company_7] Checking product 7 (Product 7)
#   Current footprint: 16.629170, Simulated footprint: 17.398911
#   Difference: 0.769741
# Company_7 was updated.
#
# [Company_3] Checking product 3 (Product 3)
#   Current footprint: 14.311621, Simulated footprint: 15.645089
#   Difference: 1.333468
# Company_3 was updated.
#
# [Company_1] Checking product 1 (Product 1)
#   Current footprint: 8.269853, Simulated footprint: 8.528948
#   Difference: 0.259095
# Company_1 was updated.
#
# [Company_5] Checking product 5 (Product 5)
#   Current footprint: 8.015988, Simulated footprint: 8.939538
#   Difference: 0.923550
# Company_5 was updated.
#
# [Company_10] Checking product 10 (Product 10)
#   Current footprint: 30.713573, Simulated footprint: 31.413044
#   Difference: 0.699471
# Company_10 was updated.
#
# --- Iteration 4 ---
#
# [Company_3] Checking product 3 (Product 3)
#   Current footprint: 15.645089, Simulated footprint: 15.706705
#   Difference: 0.061616
# Company_3 was updated.
#   [DEBUG] Average footprint for HS 2618: total impact = 101950.1837, weight = 3594.9310
#
# [Company_13] Checking product 13 (Product 13)
#   Current footprint: 8.673384, Simulated footprint: 8.837949
#   Difference: 0.164564
# Company_13 was updated.
#   [DEBUG] Average footprint for HS 2618: total impact = 101950.1837, weight = 3594.9310
#   [DEBUG] Average footprint for HS 2905: total impact = 14019.3536, weight = 190.7712
#
# [Company_12] Checking product 12 (Product 12)
#   Current footprint: 7.783169, Simulated footprint: 8.154478
#   Difference: 0.371308
# Company_12 was updated.
#   [DEBUG] Average footprint for HS 2905: total impact = 14019.3536, weight = 190.7712
#
# [Company_8] Checking product 8 (Product 8)
#   Current footprint: 13.493224, Simulated footprint: 13.691144
#   Difference: 0.197919
# Company_8 was updated.
#
# [Company_9] Checking product 9 (Product 9)
#   Current footprint: 18.187877, Simulated footprint: 18.419369
#   Difference: 0.231492
# Company_9 was updated.
#
# [Company_4] Checking product 4 (Product 4)
#   Current footprint: 25.377616, Simulated footprint: 25.728159
#   Difference: 0.350543
# Company_4 was updated.
#
# [Company_10] Checking product 10 (Product 10)
#   Current footprint: 31.413044, Simulated footprint: 31.466135
#   Difference: 0.053091
# Company_10 was updated.
#
# [Company_1] Checking product 1 (Product 1)
#   Current footprint: 8.528948, Simulated footprint: 8.639644
#   Difference: 0.110696
# Company_1 was updated.
#
# [Company_5] Checking product 5 (Product 5)
#   Current footprint: 8.939538, Simulated footprint: 9.018779
#   Difference: 0.079241
# Company_5 was updated.
#   [DEBUG] Average footprint for HS 2517: total impact = 118640.0324, weight = 1630.9542
#
# [Company_11] Checking product 11 (Product 11)
#   Current footprint: 5.127411, Simulated footprint: 5.425267
#   Difference: 0.297856
# Company_11 was updated.
#   [DEBUG] Average footprint for HS 2517: total impact = 118640.0324, weight = 1630.9542
#
# [Company_6] Checking product 6 (Product 6)
#   Current footprint: 19.468728, Simulated footprint: 19.643147
#   Difference: 0.174419
# Company_6 was updated.
#
# [Company_2] Checking product 2 (Product 2)
#   Current footprint: 16.057708, Simulated footprint: 16.298797
#   Difference: 0.241089
# Company_2 was updated.
#
# [Company_7] Checking product 7 (Product 7)
#   Current footprint: 17.398911, Simulated footprint: 17.563171
#   Difference: 0.164261
# Company_7 was updated.
#
# --- Iteration 5 ---
#
# [Company_3] Checking product 3 (Product 3)
#   Current footprint: 15.706705, Simulated footprint: 15.786469
#   Difference: 0.079764
# Company_3 was updated.
#   [DEBUG] Average footprint for HS 2905: total impact = 14019.3536, weight = 190.7712
#
# [Company_12] Checking product 12 (Product 12)
#   Current footprint: 8.154478, Simulated footprint: 8.239729
#   Difference: 0.085251
# Company_12 was updated.
#   [DEBUG] Average footprint for HS 2905: total impact = 14019.3536, weight = 190.7712
#
# [Company_8] Checking product 8 (Product 8)
#   Current footprint: 13.691144, Simulated footprint: 13.751095
#   Difference: 0.059951
# Company_8 was updated.
#
# [Company_2] Checking product 2 (Product 2)
#   Current footprint: 16.298797, Simulated footprint: 16.311576
#   Difference: 0.012778
# Company_2 was updated.
#
# [Company_7] Checking product 7 (Product 7)
#   Current footprint: 17.563171, Simulated footprint: 17.570208
#   Difference: 0.007037
# Company_7 was updated.
#
# [Company_1] Checking product 1 (Product 1)
#   Current footprint: 8.639644, Simulated footprint: 8.683205
#   Difference: 0.043561
# Company_1 was updated.
#   [DEBUG] Average footprint for HS 2618: total impact = 101950.1837, weight = 3594.9310
#
# [Company_13] Checking product 13 (Product 13)
#   Current footprint: 8.837949, Simulated footprint: 8.920165
#   Difference: 0.082217
# Company_13 was updated.
#   [DEBUG] Average footprint for HS 2618: total impact = 101950.1837, weight = 3594.9310
#
# [Company_4] Checking product 4 (Product 4)
#   Current footprint: 25.728159, Simulated footprint: 25.785501
#   Difference: 0.057342
# Company_4 was updated.
#
# [Company_6] Checking product 6 (Product 6)
#   Current footprint: 19.643147, Simulated footprint: 19.667764
#   Difference: 0.024618
# Company_6 was updated.
#
# [Company_10] Checking product 10 (Product 10)
#   Current footprint: 31.466135, Simulated footprint: 31.524724
#   Difference: 0.058589
# Company_10 was updated.
#   [DEBUG] Average footprint for HS 2517: total impact = 118640.0324, weight = 1630.9542
#
# [Company_11] Checking product 11 (Product 11)
#   Current footprint: 5.425267, Simulated footprint: 5.461341
#   Difference: 0.036074
# Company_11 was updated.
#   [DEBUG] Average footprint for HS 2517: total impact = 118640.0324, weight = 1630.9542
#
# [Company_5] Checking product 5 (Product 5)
#   Current footprint: 9.018779, Simulated footprint: 9.069166
#   Difference: 0.050387
# Company_5 was updated.
#
# [Company_9] Checking product 9 (Product 9)
#   Current footprint: 18.419369, Simulated footprint: 18.484727
#   Difference: 0.065357
# Company_9 was updated.
#
# --- Iteration 6 ---
#
# [Company_1] Checking product 1 (Product 1)
#   Current footprint: 8.683205, Simulated footprint: 8.696785
#   Difference: 0.013579
# Company_1 was updated.
#   [DEBUG] Average footprint for HS 2618: total impact = 101950.1837, weight = 3594.9310
#
# [Company_13] Checking product 13 (Product 13)
#   Current footprint: 8.920165, Simulated footprint: 8.929990
#   Difference: 0.009825
# Company_13 was updated.
#   [DEBUG] Average footprint for HS 2618: total impact = 101950.1837, weight = 3594.9310
#
# [Company_10] Checking product 10 (Product 10)
#   Current footprint: 31.524724, Simulated footprint: 31.531477
#   Difference: 0.006754
# Company_10 was updated.
#   [DEBUG] Average footprint for HS 2517: total impact = 118640.0324, weight = 1630.9542
#
# [Company_11] Checking product 11 (Product 11)
#   Current footprint: 5.461341, Simulated footprint: 5.466166
#   Difference: 0.004825
# Company_11 was updated.
#   [DEBUG] Average footprint for HS 2517: total impact = 118640.0324, weight = 1630.9542
#
# [Company_9] Checking product 9 (Product 9)
#   Current footprint: 18.484727, Simulated footprint: 18.485832
#   Difference: 0.001105
# Company_9 was updated.
#
# [Company_3] Checking product 3 (Product 3)
#   Current footprint: 15.786469, Simulated footprint: 15.806742
#   Difference: 0.020273
# Company_3 was updated.
#   [DEBUG] Average footprint for HS 2905: total impact = 14019.3536, weight = 190.7712
#
# [Company_12] Checking product 12 (Product 12)
#   Current footprint: 8.239729, Simulated footprint: 8.263589
#   Difference: 0.023860
# Company_12 was updated.
#   [DEBUG] Average footprint for HS 2905: total impact = 14019.3536, weight = 190.7712
#
# [Company_6] Checking product 6 (Product 6)
#   Current footprint: 19.667764, Simulated footprint: 19.676351
#   Difference: 0.008586
# Company_6 was updated.
#
# [Company_8] Checking product 8 (Product 8)
#   Current footprint: 13.751095, Simulated footprint: 13.768004
#   Difference: 0.016909
# Company_8 was updated.
#
# [Company_5] Checking product 5 (Product 5)
#   Current footprint: 9.069166, Simulated footprint: 9.075216
#   Difference: 0.006050
# Company_5 was updated.
#
# [Company_7] Checking product 7 (Product 7)
#   Current footprint: 17.570208, Simulated footprint: 17.585893
#   Difference: 0.015685
# Company_7 was updated.
#
# [Company_2] Checking product 2 (Product 2)
#   Current footprint: 16.311576, Simulated footprint: 16.329719
#   Difference: 0.018143
# Company_2 was updated.
#
# [Company_4] Checking product 4 (Product 4)
#   Current footprint: 25.785501, Simulated footprint: 25.800137
#   Difference: 0.014636
# Company_4 was updated.
#
# --- Iteration 7 ---
#
# [Company_7] Checking product 7 (Product 7)
#   Current footprint: 17.585893, Simulated footprint: 17.586864
#   Difference: 0.000970
# Company_7 was updated.
#
# [Company_1] Checking product 1 (Product 1)
#   Current footprint: 8.696785, Simulated footprint: 8.702136
#   Difference: 0.005351
# Company_1 was updated.
#
# [Company_5] Checking product 5 (Product 5)
#   Current footprint: 9.075216, Simulated footprint: 9.077153
#   Difference: 0.001937
# Company_5 was updated.
#
# [Company_9] Checking product 9 (Product 9)
#   Current footprint: 18.485832, Simulated footprint: 18.490015
#   Difference: 0.004183
# Company_9 was updated.
#
# [Company_6] Checking product 6 (Product 6)
#   Current footprint: 19.676351, Simulated footprint: 19.678828
#   Difference: 0.002478
# Company_6 was updated.
#
# [Company_8] Checking product 8 (Product 8)
#   Current footprint: 13.768004, Simulated footprint: 13.770233
#   Difference: 0.002229
# Company_8 was updated.
#
# [Company_10] Checking product 10 (Product 10)
#   Current footprint: 31.531477, Simulated footprint: 31.537152
#   Difference: 0.005674
# Company_10 was updated.
#
# [Company_4] Checking product 4 (Product 4)
#   Current footprint: 25.800137, Simulated footprint: 25.801015
#   Difference: 0.000878
# Company_4 was updated.
#
# [Company_3] Checking product 3 (Product 3)
#   Current footprint: 15.806742, Simulated footprint: 15.810918
#   Difference: 0.004176
# Company_3 was updated.
#
# [Company_2] Checking product 2 (Product 2)
#   Current footprint: 16.329719, Simulated footprint: 16.331114
#   Difference: 0.001396
# Company_2 was updated.
#   [DEBUG] Average footprint for HS 2618: total impact = 101950.1837, weight = 3594.9310
#
# [Company_13] Checking product 13 (Product 13)
#   Current footprint: 8.929990, Simulated footprint: 8.935324
#   Difference: 0.005334
# Company_13 was updated.
#   [DEBUG] Average footprint for HS 2618: total impact = 101950.1837, weight = 3594.9310
#   [DEBUG] Average footprint for HS 2517: total impact = 118640.0324, weight = 1630.9542
#
# [Company_11] Checking product 11 (Product 11)
#   Current footprint: 5.466166, Simulated footprint: 5.471452
#   Difference: 0.005286
# Company_11 was updated.
#   [DEBUG] Average footprint for HS 2517: total impact = 118640.0324, weight = 1630.9542
#   [DEBUG] Average footprint for HS 2905: total impact = 14019.3536, weight = 190.7712
#
# [Company_12] Checking product 12 (Product 12)
#   Current footprint: 8.263589, Simulated footprint: 8.268751
#   Difference: 0.005162
# Company_12 was updated.
#   [DEBUG] Average footprint for HS 2905: total impact = 14019.3536, weight = 190.7712
#
# --- Iteration 8 ---
#
# [Company_5] Checking product 5 (Product 5)
#   Current footprint: 9.077153, Simulated footprint: 9.078455
#   Difference: 0.001301
# Company_5 was updated.
#
# [Company_7] Checking product 7 (Product 7)
#   Current footprint: 17.586864, Simulated footprint: 17.588207
#   Difference: 0.001343
# Company_7 was updated.
#
# [Company_8] Checking product 8 (Product 8)
#   Current footprint: 13.770233, Simulated footprint: 13.771213
#   Difference: 0.000981
# Company_8 was updated.
#
# [Company_2] Checking product 2 (Product 2)
#   Current footprint: 16.331114, Simulated footprint: 16.331751
#   Difference: 0.000637
# Company_2 was updated.
#
# [Company_9] Checking product 9 (Product 9)
#   Current footprint: 18.490015, Simulated footprint: 18.491180
#   Difference: 0.001165
# Company_9 was updated.
#
# [Company_3] Checking product 3 (Product 3)
#   Current footprint: 15.810918, Simulated footprint: 15.811658
#   Difference: 0.000740
# Company_3 was updated.
#
# [Company_10] Checking product 10 (Product 10)
#   Current footprint: 31.537152, Simulated footprint: 31.538246
#   Difference: 0.001095
# Company_10 was updated.
#   [DEBUG] Average footprint for HS 2905: total impact = 14019.3536, weight = 190.7712
#
# [Company_12] Checking product 12 (Product 12)
#   Current footprint: 8.268751, Simulated footprint: 8.269063
#   Difference: 0.000313
# Company_12 was updated.
#   [DEBUG] Average footprint for HS 2905: total impact = 14019.3536, weight = 190.7712
#   [DEBUG] Average footprint for HS 2618: total impact = 101950.1837, weight = 3594.9310
#
# [Company_13] Checking product 13 (Product 13)
#   Current footprint: 8.935324, Simulated footprint: 8.935902
#   Difference: 0.000579
# Company_13 was updated.
#   [DEBUG] Average footprint for HS 2618: total impact = 101950.1837, weight = 3594.9310
#
# [Company_4] Checking product 4 (Product 4)
#   Current footprint: 25.801015, Simulated footprint: 25.802149
#   Difference: 0.001135
# Company_4 was updated.
#
# [Company_1] Checking product 1 (Product 1)
#   Current footprint: 8.702136, Simulated footprint: 8.703877
#   Difference: 0.001741
# Company_1 was updated.
#
# [Company_6] Checking product 6 (Product 6)
#   Current footprint: 19.678828, Simulated footprint: 19.680045
#   Difference: 0.001216
# Company_6 was updated.
#   [DEBUG] Average footprint for HS 2517: total impact = 118640.0324, weight = 1630.9542
#
# [Company_11] Checking product 11 (Product 11)
#   Current footprint: 5.471452, Simulated footprint: 5.472027
#   Difference: 0.000576
# Company_11 was updated.
#   [DEBUG] Average footprint for HS 2517: total impact = 118640.0324, weight = 1630.9542
#
# --- Iteration 9 ---
#
# [Company_1] Checking product 1 (Product 1)
#   Current footprint: 8.703877, Simulated footprint: 8.703942
#   Difference: 0.000065
#
# [Company_5] Checking product 5 (Product 5)
#   Current footprint: 9.078455, Simulated footprint: 9.078862
#   Difference: 0.000407
# Company_5 was updated.
#   [DEBUG] Average footprint for HS 2618: total impact = 101950.1837, weight = 3594.9310
#
# [Company_13] Checking product 13 (Product 13)
#   Current footprint: 8.935902, Simulated footprint: 8.936065
#   Difference: 0.000163
# Company_13 was updated.
#   [DEBUG] Average footprint for HS 2618: total impact = 101950.1837, weight = 3594.9310
#
# [Company_10] Checking product 10 (Product 10)
#   Current footprint: 31.538246, Simulated footprint: 31.538482
#   Difference: 0.000236
#
# [Company_6] Checking product 6 (Product 6)
#   Current footprint: 19.680045, Simulated footprint: 19.680078
#   Difference: 0.000034
#
# [Company_2] Checking product 2 (Product 2)
#   Current footprint: 16.331751, Simulated footprint: 16.332051
#   Difference: 0.000300
# Company_2 was updated.
#
# [Company_9] Checking product 9 (Product 9)
#   Current footprint: 18.491180, Simulated footprint: 18.491441
#   Difference: 0.000261
# Company_9 was updated.
#
# [Company_3] Checking product 3 (Product 3)
#   Current footprint: 15.811658, Simulated footprint: 15.811913
#   Difference: 0.000255
# Company_3 was updated.
#   [DEBUG] Average footprint for HS 2905: total impact = 14019.3536, weight = 190.7712
#
# [Company_12] Checking product 12 (Product 12)
#   Current footprint: 8.269063, Simulated footprint: 8.269349
#   Difference: 0.000285
# Company_12 was updated.
#   [DEBUG] Average footprint for HS 2905: total impact = 14019.3536, weight = 190.7712
#
# [Company_7] Checking product 7 (Product 7)
#   Current footprint: 17.588207, Simulated footprint: 17.588558
#   Difference: 0.000351
# Company_7 was updated.
#
# [Company_8] Checking product 8 (Product 8)
#   Current footprint: 13.771213, Simulated footprint: 13.771573
#   Difference: 0.000360
# Company_8 was updated.
#   [DEBUG] Average footprint for HS 2517: total impact = 118640.0324, weight = 1630.9542
#
# [Company_11] Checking product 11 (Product 11)
#   Current footprint: 5.472027, Simulated footprint: 5.472106
#   Difference: 0.000079
# Company_11 was updated.
#   [DEBUG] Average footprint for HS 2517: total impact = 118640.0324, weight = 1630.9542
#
# [Company_4] Checking product 4 (Product 4)
#   Current footprint: 25.802149, Simulated footprint: 25.802380
#   Difference: 0.000230
#
# --- Iteration 10 ---
#   [DEBUG] Average footprint for HS 2618: total impact = 101950.1837, weight = 3594.9310
#
# [Company_13] Checking product 13 (Product 13)
#   Current footprint: 8.936065, Simulated footprint: 8.936126
#   Difference: 0.000061
#   [DEBUG] Average footprint for HS 2618: total impact = 101950.1837, weight = 3594.9310
#
# [Company_13] Checking product 19 (Blast Furnace Slag)
#   Current footprint: 2.835943, Simulated footprint: 2.835943
#   Difference: 0.000000
#
# [Company_5] Checking product 5 (Product 5)
#   Current footprint: 9.078862, Simulated footprint: 9.078935
#   Difference: 0.000073
#
# [Company_9] Checking product 9 (Product 9)
#   Current footprint: 18.491441, Simulated footprint: 18.491483
#   Difference: 0.000042
#
# [Company_2] Checking product 2 (Product 2)
#   Current footprint: 16.332051, Simulated footprint: 16.332103
#   Difference: 0.000052
#   [DEBUG] Average footprint for HS 2517: total impact = 118640.0324, weight = 1630.9542
#
# [Company_11] Checking product 11 (Product 11)
#   Current footprint: 5.472106, Simulated footprint: 5.472106
#   Difference: 0.000000
#   [DEBUG] Average footprint for HS 2517: total impact = 118640.0324, weight = 1630.9542
#
# [Company_11] Checking product 17 (Crushed granite)
#   Current footprint: 1.818568, Simulated footprint: 1.818568
#   Difference: 0.000000
#   [DEBUG] Average footprint for HS 2905: total impact = 14019.3536, weight = 190.7712
#
# [Company_12] Checking product 12 (Product 12)
#   Current footprint: 8.269349, Simulated footprint: 8.269383
#   Difference: 0.000034
#   [DEBUG] Average footprint for HS 2905: total impact = 14019.3536, weight = 190.7712
#
# [Company_12] Checking product 18 (Glycerol)
#   Current footprint: 3.674389, Simulated footprint: 3.674389
#   Difference: 0.000000
#
# [Company_1] Checking product 1 (Product 1)
#   Current footprint: 8.703877, Simulated footprint: 8.704031
#   Difference: 0.000154
# Company_1 was updated.
#
# [Company_8] Checking product 8 (Product 8)
#   Current footprint: 13.771573, Simulated footprint: 13.771581
#   Difference: 0.000007
#
# [Company_3] Checking product 3 (Product 3)
#   Current footprint: 15.811913, Simulated footprint: 15.811953
#   Difference: 0.000040
#
# [Company_4] Checking product 4 (Product 4)
#   Current footprint: 25.802149, Simulated footprint: 25.802386
#   Difference: 0.000236
#
# [Company_6] Checking product 6 (Product 6)
#   Current footprint: 19.680045, Simulated footprint: 19.680139
#   Difference: 0.000094
#
# [Company_7] Checking product 7 (Product 7)
#   Current footprint: 17.588558, Simulated footprint: 17.588575
#   Difference: 0.000018
#
# [Company_10] Checking product 10 (Product 10)
#   Current footprint: 31.538246, Simulated footprint: 31.538561
#   Difference: 0.000315
#
# --- Iteration 11 ---
#
# [Company_9] Checking product 9 (Product 9)
#   Current footprint: 18.491441, Simulated footprint: 18.491488
#   Difference: 0.000047
#
# [Company_1] Checking product 1 (Product 1)
#   Current footprint: 8.704031, Simulated footprint: 8.704031
#   Difference: 0.000000
#
# [Company_6] Checking product 6 (Product 6)
#   Current footprint: 19.680045, Simulated footprint: 19.680139
#   Difference: 0.000094
#
# [Company_3] Checking product 3 (Product 3)
#   Current footprint: 15.811913, Simulated footprint: 15.811953
#   Difference: 0.000040
#
# [Company_8] Checking product 8 (Product 8)
#   Current footprint: 13.771573, Simulated footprint: 13.771581
#   Difference: 0.000007
#
# [Company_5] Checking product 5 (Product 5)
#   Current footprint: 9.078862, Simulated footprint: 9.078940
#   Difference: 0.000078
#
# [Company_4] Checking product 4 (Product 4)
#   Current footprint: 25.802149, Simulated footprint: 25.802386
#   Difference: 0.000236
#   [DEBUG] Average footprint for HS 2905: total impact = 14019.3536, weight = 190.7712
#
# [Company_12] Checking product 12 (Product 12)
#   Current footprint: 8.269349, Simulated footprint: 8.269389
#   Difference: 0.000041
#   [DEBUG] Average footprint for HS 2905: total impact = 14019.3536, weight = 190.7712
#
# [Company_12] Checking product 18 (Glycerol)
#   Current footprint: 3.674389, Simulated footprint: 3.674389
#   Difference: 0.000000
#
# [Company_2] Checking product 2 (Product 2)
#   Current footprint: 16.332051, Simulated footprint: 16.332108
#   Difference: 0.000057
#
# [Company_10] Checking product 10 (Product 10)
#   Current footprint: 31.538246, Simulated footprint: 31.538561
#   Difference: 0.000315
#
# [Company_7] Checking product 7 (Product 7)
#   Current footprint: 17.588558, Simulated footprint: 17.588575
#   Difference: 0.000018
#   [DEBUG] Average footprint for HS 2517: total impact = 118640.0324, weight = 1630.9542
#
# [Company_11] Checking product 11 (Product 11)
#   Current footprint: 5.472106, Simulated footprint: 5.472111
#   Difference: 0.000005
#   [DEBUG] Average footprint for HS 2517: total impact = 118640.0324, weight = 1630.9542
#
# [Company_11] Checking product 17 (Crushed granite)
#   Current footprint: 1.818568, Simulated footprint: 1.818568
#   Difference: 0.000000
#   [DEBUG] Average footprint for HS 2618: total impact = 101950.1837, weight = 3594.9310
#
# [Company_13] Checking product 13 (Product 13)
#   Current footprint: 8.936065, Simulated footprint: 8.936131
#   Difference: 0.000066
#   [DEBUG] Average footprint for HS 2618: total impact = 101950.1837, weight = 3594.9310
#
# [Company_13] Checking product 19 (Blast Furnace Slag)
#   Current footprint: 2.835943, Simulated footprint: 2.835943
#   Difference: 0.000000
#
# No updates needed for 1 consecutive iteration(s). Converged.
#
# Converged in 11 iterations; total company updates applied: 114
# Time taken: 0.50 s
#
# Result: {'iterations': 11, 'total_updates': 114, 'seconds': 0.504807710647583}
#
#  Final Footprints:
# Company_1: 8.7040 kg CO2e/unit
# Company_2: 16.3321 kg CO2e/unit
# Company_3: 15.8119 kg CO2e/unit
# Company_4: 25.8021 kg CO2e/unit
# Company_5: 9.0789 kg CO2e/unit
# Company_6: 19.6800 kg CO2e/unit
# Company_7: 17.5886 kg CO2e/unit
# Company_8: 13.7716 kg CO2e/unit
# Company_9: 18.4914 kg CO2e/unit
# Company_10: 31.5382 kg CO2e/unit
# Company_11: 5.4691 kg CO2e/unit
# Company_12: 8.2595 kg CO2e/unit
# Company_13: 8.9165 kg CO2e/unit
#
#  Update Count:
# Company_1: 9 updates
# Company_2: 9 updates
# Company_3: 9 updates
# Company_4: 8 updates
# Company_5: 9 updates
# Company_6: 8 updates
# Company_7: 9 updates
# Company_8: 9 updates
# Company_9: 9 updates
# Company_10: 8 updates
# Company_11: 9 updates
# Company_12: 9 updates
# Company_13: 9 updates
# Total updates: 114
#
#  Carbon balance check:
#
# --- Carbon balance check for Company_1 ---
#   Embodied in purchases: 199.1013
#   Direct emissions:      41.0000
#   Total carbon in:       240.1013
#   Product Product 1: 240.1013 kg CO2e in outputs
#   Total embodied out:    240.1013
#   Balanced?              True
#
# --- Carbon balance check for Company_2 ---
#   Embodied in purchases: 191.4732
#   Direct emissions:      306.0000
#   Total carbon in:       497.4732
#   Product Product 2: 497.4715 kg CO2e in outputs
#   Total embodied out:    497.4715
#   Balanced?              True
#
# --- Carbon balance check for Company_3 ---
#   Embodied in purchases: 191.9934
#   Direct emissions:      291.0000
#   Total carbon in:       482.9934
#   Product Product 3: 482.9921 kg CO2e in outputs
#   Total embodied out:    482.9921
#   Balanced?              True
#
# --- Carbon balance check for Company_4 ---
#   Embodied in purchases: 182.0031
#   Direct emissions:      489.0000
#   Total carbon in:       671.0031
#   Product Product 4: 670.9970 kg CO2e in outputs
#   Total embodied out:    670.9970
#   Balanced?              True
#
# --- Carbon balance check for Company_5 ---
#   Embodied in purchases: 198.7264
#   Direct emissions:      58.0000
#   Total carbon in:       256.7264
#   Product Product 5: 256.7242 kg CO2e in outputs
#   Total embodied out:    256.7242
#   Balanced?              True
#
# --- Carbon balance check for Company_6 ---
#   Embodied in purchases: 188.1252
#   Direct emissions:      478.0000
#   Total carbon in:       666.1252
#   Product Product 6: 666.1221 kg CO2e in outputs
#   Total embodied out:    666.1221
#   Balanced?              True
#
# --- Carbon balance check for Company_7 ---
#   Embodied in purchases: 190.2167
#   Direct emissions:      404.0000
#   Total carbon in:       594.2167
#   Product Product 7: 594.2161 kg CO2e in outputs
#   Total embodied out:    594.2161
#   Balanced?              True
#
# --- Carbon balance check for Company_8 ---
#   Embodied in purchases: 194.0337
#   Direct emissions:      235.0000
#   Total carbon in:       429.0337
#   Product Product 8: 429.0335 kg CO2e in outputs
#   Total embodied out:    429.0335
#   Balanced?              True
#
# --- Carbon balance check for Company_9 ---
#   Embodied in purchases: 189.3138
#   Direct emissions:      396.0000
#   Total carbon in:       585.3138
#   Product Product 9: 585.3124 kg CO2e in outputs
#   Total embodied out:    585.3124
#   Balanced?              True
#
# --- Carbon balance check for Company_10 ---
#   Embodied in purchases: 176.2670
#   Direct emissions:      642.0000
#   Total carbon in:       818.2670
#   Product Product 10: 818.2589 kg CO2e in outputs
#   Total embodied out:    818.2589
#   Balanced?              True
#
# --- Carbon balance check for Company_11 ---
#   Embodied in purchases: 202.3332
#   Direct emissions:      145.0000
#   Total carbon in:       347.3332
#   Product Product 11: 165.4762 kg CO2e in outputs
#   Product Crushed granite: 181.8568 kg CO2e in outputs
#   Total embodied out:    347.3330
#   Balanced?              True
#
# --- Carbon balance check for Company_12 ---
#   Embodied in purchases: 199.5359
#   Direct emissions:      360.0000
#   Total carbon in:       559.5359
#   Product Product 12: 192.0961 kg CO2e in outputs
#   Product Glycerol: 367.4389 kg CO2e in outputs
#   Total embodied out:    559.5350
#   Balanced?              True
#
# --- Carbon balance check for Company_13 ---
#   Embodied in purchases: 198.8692
#   Direct emissions:      363.0000
#   Total carbon in:       561.8692
#   Product Product 13: 278.2729 kg CO2e in outputs
#   Product Blast Furnace Slag: 283.5943 kg CO2e in outputs
#   Total embodied out:    561.8672
#   Balanced?              True
#
#  Final Footprints:
# Company_1: 8.7040 kg CO2e/unit
# Company_2: 16.3321 kg CO2e/unit
# Company_3: 15.8119 kg CO2e/unit
# Company_4: 25.8021 kg CO2e/unit
# Company_5: 9.0789 kg CO2e/unit
# Company_6: 19.6800 kg CO2e/unit
# Company_7: 17.5886 kg CO2e/unit
# Company_8: 13.7716 kg CO2e/unit
# Company_9: 18.4914 kg CO2e/unit
# Company_10: 31.5382 kg CO2e/unit
# Company_11: 5.4691 kg CO2e/unit
# Company_12: 8.2595 kg CO2e/unit
# Company_13: 8.9165 kg CO2e/unit
#
#  Update Count:
# Company_1: 9 updates
# Company_2: 9 updates
# Company_3: 9 updates
# Company_4: 8 updates
# Company_5: 9 updates
# Company_6: 8 updates
# Company_7: 9 updates
# Company_8: 9 updates
# Company_9: 9 updates
# Company_10: 8 updates
# Company_11: 9 updates
# Company_12: 9 updates
# Company_13: 9 updates
# Total updates: 114
#
#  Carbon balance check:
#
# --- Carbon balance check for Company_1 ---
#   Embodied in purchases: 199.1013
#   Direct emissions:      41.0000
#   Total carbon in:       240.1013
#   Product Product 1: 240.1013 kg CO2e in outputs
#   Total embodied out:    240.1013
#   Balanced?              True
#
# --- Carbon balance check for Company_2 ---
#   Embodied in purchases: 191.4732
#   Direct emissions:      306.0000
#   Total carbon in:       497.4732
#   Product Product 2: 497.4715 kg CO2e in outputs
#   Total embodied out:    497.4715
#   Balanced?              True
#
# --- Carbon balance check for Company_3 ---
#   Embodied in purchases: 191.9934
#   Direct emissions:      291.0000
#   Total carbon in:       482.9934
#   Product Product 3: 482.9921 kg CO2e in outputs
#   Total embodied out:    482.9921
#   Balanced?              True
#
# --- Carbon balance check for Company_4 ---
#   Embodied in purchases: 182.0031
#   Direct emissions:      489.0000
#   Total carbon in:       671.0031
#   Product Product 4: 670.9970 kg CO2e in outputs
#   Total embodied out:    670.9970
#   Balanced?              True
#
# --- Carbon balance check for Company_5 ---
#   Embodied in purchases: 198.7264
#   Direct emissions:      58.0000
#   Total carbon in:       256.7264
#   Product Product 5: 256.7242 kg CO2e in outputs
#   Total embodied out:    256.7242
#   Balanced?              True
#
# --- Carbon balance check for Company_6 ---
#   Embodied in purchases: 188.1252
#   Direct emissions:      478.0000
#   Total carbon in:       666.1252
#   Product Product 6: 666.1221 kg CO2e in outputs
#   Total embodied out:    666.1221
#   Balanced?              True
#
# --- Carbon balance check for Company_7 ---
#   Embodied in purchases: 190.2167
#   Direct emissions:      404.0000
#   Total carbon in:       594.2167
#   Product Product 7: 594.2161 kg CO2e in outputs
#   Total embodied out:    594.2161
#   Balanced?              True
#
# --- Carbon balance check for Company_8 ---
#   Embodied in purchases: 194.0337
#   Direct emissions:      235.0000
#   Total carbon in:       429.0337
#   Product Product 8: 429.0335 kg CO2e in outputs
#   Total embodied out:    429.0335
#   Balanced?              True
#
# --- Carbon balance check for Company_9 ---
#   Embodied in purchases: 189.3138
#   Direct emissions:      396.0000
#   Total carbon in:       585.3138
#   Product Product 9: 585.3124 kg CO2e in outputs
#   Total embodied out:    585.3124
#   Balanced?              True
#
# --- Carbon balance check for Company_10 ---
#   Embodied in purchases: 176.2670
#   Direct emissions:      642.0000
#   Total carbon in:       818.2670
#   Product Product 10: 818.2589 kg CO2e in outputs
#   Total embodied out:    818.2589
#   Balanced?              True
#
# --- Carbon balance check for Company_11 ---
#   Embodied in purchases: 202.3332
#   Direct emissions:      145.0000
#   Total carbon in:       347.3332
#   Product Product 11: 165.4762 kg CO2e in outputs
#   Product Crushed granite: 181.8568 kg CO2e in outputs
#   Total embodied out:    347.3330
#   Balanced?              True
#
# --- Carbon balance check for Company_12 ---
#   Embodied in purchases: 199.5359
#   Direct emissions:      360.0000
#   Total carbon in:       559.5359
#   Product Product 12: 192.0961 kg CO2e in outputs
#   Product Glycerol: 367.4389 kg CO2e in outputs
#   Total embodied out:    559.5350
#   Balanced?              True
#
# --- Carbon balance check for Company_13 ---
#   Embodied in purchases: 198.8692
#   Direct emissions:      363.0000
#   Total carbon in:       561.8692
#   Product Product 13: 278.2729 kg CO2e in outputs
#   Product Blast Furnace Slag: 283.5943 kg CO2e in outputs
#   Total embodied out:    561.8672
#   Balanced?              True

# %%
# Step 6: Run simulation loop
updates_completed = False
iteration = 0
start_time = time.time()
company_names = list(system.companies.keys())

while not updates_completed:
    iteration += 1
    print(f"\n--- Iteration {iteration} ---")
    any_updated = False
    unchecked = company_names[:]

    while unchecked:
        cname = random.choice(unchecked)
        comp = system.companies[cname]
        if comp.check_update_needed(fp_2024, last_year_sales, fp_2023):
            print(f"{cname} was updated.")
            comp.update_footprint(fp_2024, fp_2023, last_year_sales)  # ← MISSING!
            any_updated = True

        unchecked.remove(cname)

    updates_completed = not any_updated

end_time = time.time()
print(f"\n Updates completed in {iteration} iterations.")
print(f" Time taken: {end_time - start_time:.2f} seconds")

# %%
from substitution_extension import Company
print(Company.__module__)
print(dir(Company))

# %%
print(system.companies["Company_1"].__class__)
print(dir(system.companies["Company_1"]))
# Out:
# <class 'substitution_extension.Company'>
# ['__class__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__format__', '__ge__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__reduce__', '__reduce_ex__', '__repr__', '__setattr__', '__sizeof__', '__str__', '__subclasshook__', '__weakref__', 'add_product', 'check_carbon_balance', 'check_update_needed', 'direct_impacts', 'get_average_footprint', 'latest_update', 'name', 'num_updates', 'products', 'purchases', 'report_footprint', 'sales', 'update_footprint', 'year']
