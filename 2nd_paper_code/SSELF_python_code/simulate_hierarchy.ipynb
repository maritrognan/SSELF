# %%
# simulate_hierarchy.ipynb (content for a new Jupyter notebook)

import random
import time
import numpy as np
import pandas as pd

from SSELF_base import FootprintDatabase
from hierarchy_extension import HierarchicalSystem, HierarchicalCompany, Product

# Step 1: Define parameters
num_companies = 10
base_products = num_companies  # One product per company by default
companies_with_subs = ["Company_1", "Company_3"]
num_subs_per_company = 2


# Specify your file path here
products_path = r"C:\Users\marit.rognan\Documents\University\2nd paper\products_to_read.csv"
companies_path = r"C:\Users\marit.rognan\Documents\University\2nd paper\companies_to_read.csv"

# Initialize system and build from file
system = HierarchicalSystem(num_companies=0, num_products=0)
system.build_from_csv(companies_path, products_path)

# 2) Create the footprint DB
footprint_db = FootprintDatabase(year=2024)

# 3) (Temporary) seed baseline scores for all product IDs used internally
#    Otherwise you'll get "missing product IDs" warnings and zero impacts.
for pid in system._product_id_to_code.keys():  # internal integer IDs
    footprint_db.report(int(pid), 1.0)         # placeholder score; replace with real data later

# 4) Run the solver (random each run by default)
system.solve(footprint_db, verbose=True)

# if you ever need reproducible behavior:
# system.solve(footprint_db, verbose=True, random_state=42)
# Step 4: Initialize footprint DB
def print_hierarchy(company, indent=0):
    print("    " * indent + f"- {company.name} (latest_update={company.latest_update})")
    for sub in getattr(company, "sub_companies", []):
        print_hierarchy(sub, indent + 1)

# Print all root companies in the system
for cname, company in system.companies.items():
    print_hierarchy(company)
# Out:
# --- Iteration 1 ---
# Checking C5
#
# Calculating footprint for Vertex Plant Alpha
#   Product Vertex Iced Tea 500ml: Assigned footprint 17.4124
#   Final footprint for Vertex Plant Alpha: 17.4124
#   → Updated. New: N/A
# Checking C1
#
# Calculating footprint for Orion Plant A1
#   Product Orion Cola 500ml: Assigned footprint 48.9113
#   Product Orion Diet Cola 500ml: Assigned footprint 48.9113
#   Final footprint for Orion Plant A1: 48.9113
#   → Updated. New: N/A
# Checking C2
#
# Calculating footprint for Lumina Plant A
#   Product Lumina Sparkling Water 500ml: Assigned footprint 29.8170
#   Final footprint for Lumina Plant A: 29.8170
#   → Updated. New: N/A
# Checking C4
#
# Calculating footprint for Nimbus Subsidiary
#   Product Nimbus Tonic Water 1L: Assigned footprint 37.6373
#   Product Nimbus Cola 500ml: Assigned footprint 37.6373
#   Final footprint for Nimbus Subsidiary: 37.6373
#   → Updated. New: N/A
# Checking C3
#
# Calculating footprint for Apex Site X
#   Product Apex Ginger Ale 330ml: Assigned footprint 40.1473
#   Product Apex Zero Cola 500ml: Assigned footprint 40.1473
#   Final footprint for Apex Site X: 40.1473
#   → Updated. New: N/A
#
# --- Iteration 2 ---
# Checking C2
#
# Calculating footprint for Lumina Plant A
#   Product Lumina Sparkling Water 500ml: Assigned footprint 37.4783
#   Final footprint for Lumina Plant A: 37.4783
#   → Updated. New: N/A
# Checking C3
#
# Calculating footprint for Apex Site X
#   Product Apex Ginger Ale 330ml: Assigned footprint 40.6221
#   Product Apex Zero Cola 500ml: Assigned footprint 40.6221
#   Final footprint for Apex Site X: 40.6221
#   → Updated. New: N/A
# Checking C5
#
# Calculating footprint for Vertex Plant Alpha
#   Product Vertex Iced Tea 500ml: Assigned footprint 26.8448
#   Final footprint for Vertex Plant Alpha: 26.8448
#   → Updated. New: N/A
# Checking C1
#
# Calculating footprint for Orion Plant A1
#   Product Orion Cola 500ml: Assigned footprint 67.5332
#   Product Orion Diet Cola 500ml: Assigned footprint 67.5332
#   Final footprint for Orion Plant A1: 67.5332
#   → Updated. New: N/A
# Checking C4
#
# Calculating footprint for Nimbus Subsidiary
#   Product Nimbus Tonic Water 1L: Assigned footprint 47.7146
#   Product Nimbus Cola 500ml: Assigned footprint 47.7146
#   Final footprint for Nimbus Subsidiary: 47.7146
#   → Updated. New: N/A
#
# --- Iteration 3 ---
# Checking C1
#
# Calculating footprint for Orion Plant A1
#   Product Orion Cola 500ml: Assigned footprint 69.0524
#   Product Orion Diet Cola 500ml: Assigned footprint 69.0524
#   Final footprint for Orion Plant A1: 69.0524
#   → Updated. New: N/A
# Checking C5
#
# Calculating footprint for Vertex Plant Alpha
#   Product Vertex Iced Tea 500ml: Assigned footprint 28.6565
#   Final footprint for Vertex Plant Alpha: 28.6565
#   → Updated. New: N/A
# Checking C4
#
# Calculating footprint for Nimbus Subsidiary
#   Product Nimbus Tonic Water 1L: Assigned footprint 48.0732
#   Product Nimbus Cola 500ml: Assigned footprint 48.0732
#   Final footprint for Nimbus Subsidiary: 48.0732
#   → Updated. New: N/A
# Checking C2
#
# Calculating footprint for Lumina Plant A
#   Product Lumina Sparkling Water 500ml: Assigned footprint 41.0447
#   Final footprint for Lumina Plant A: 41.0447
#   → Updated. New: N/A
# Checking C3
#
# Calculating footprint for Apex Site X
#   Product Apex Ginger Ale 330ml: Assigned footprint 46.9326
#   Product Apex Zero Cola 500ml: Assigned footprint 46.9326
#   Final footprint for Apex Site X: 46.9326
#   → Updated. New: N/A
#
# --- Iteration 4 ---
# Checking C4
#
# Calculating footprint for Nimbus Subsidiary
#   Product Nimbus Tonic Water 1L: Assigned footprint 49.2914
#   Product Nimbus Cola 500ml: Assigned footprint 49.2914
#   Final footprint for Nimbus Subsidiary: 49.2914
#   → Updated. New: N/A
# Checking C3
#
# Calculating footprint for Apex Site X
#   Product Apex Ginger Ale 330ml: Assigned footprint 47.1333
#   Product Apex Zero Cola 500ml: Assigned footprint 47.1333
#   Final footprint for Apex Site X: 47.1333
#   → Updated. New: N/A
# Checking C2
#
# Calculating footprint for Lumina Plant A
#   Product Lumina Sparkling Water 500ml: Assigned footprint 41.8868
#   Final footprint for Lumina Plant A: 41.8868
#   → Updated. New: N/A
# Checking C1
#
# Calculating footprint for Orion Plant A1
#   Product Orion Cola 500ml: Assigned footprint 71.2029
#   Product Orion Diet Cola 500ml: Assigned footprint 71.2029
#   Final footprint for Orion Plant A1: 71.2029
#   → Updated. New: N/A
# Checking C5
#
# Calculating footprint for Vertex Plant Alpha
#   Product Vertex Iced Tea 500ml: Assigned footprint 29.4923
#   Final footprint for Vertex Plant Alpha: 29.4923
#   → Updated. New: N/A
#
# --- Iteration 5 ---
# Checking C5
#
# Calculating footprint for Vertex Plant Alpha
#   Product Vertex Iced Tea 500ml: Assigned footprint 29.4923
#   Final footprint for Vertex Plant Alpha: 29.4923
#
# Calculating footprint for Vertex Plant Beta
#   Product Vertex Cola 330ml: Assigned footprint 24.6125
#   Final footprint for Vertex Plant Beta: 24.6125
#   → Updated. New: N/A
# Checking C3
#
# Calculating footprint for Apex Site X
#   Product Apex Ginger Ale 330ml: Assigned footprint 49.2118
#   Product Apex Zero Cola 500ml: Assigned footprint 49.2118
#   Final footprint for Apex Site X: 49.2118
#   → Updated. New: N/A
# Checking C1
#
# Calculating footprint for Orion Plant A1
#   Product Orion Cola 500ml: Assigned footprint 73.3254
#   Product Orion Diet Cola 500ml: Assigned footprint 73.3254
#   Final footprint for Orion Plant A1: 73.3254
#   → Updated. New: N/A
# Checking C2
#
# Calculating footprint for Lumina Plant A
#   Product Lumina Sparkling Water 500ml: Assigned footprint 44.5439
#   Final footprint for Lumina Plant A: 44.5439
#   → Updated. New: N/A
# Checking C4
#
# Calculating footprint for Nimbus Subsidiary
#   Product Nimbus Tonic Water 1L: Assigned footprint 52.0065
#   Product Nimbus Cola 500ml: Assigned footprint 52.0065
#   Final footprint for Nimbus Subsidiary: 52.0065
#   → Updated. New: N/A
#
# --- Iteration 6 ---
# Checking C1
#
# Calculating footprint for Orion Plant A1
#   Product Orion Cola 500ml: Assigned footprint 74.1736
#   Product Orion Diet Cola 500ml: Assigned footprint 74.1736
#   Final footprint for Orion Plant A1: 74.1736
#   → Updated. New: N/A
# Checking C5
#
# Calculating footprint for Vertex Plant Alpha
#   Product Vertex Iced Tea 500ml: Assigned footprint 30.4457
#   Final footprint for Vertex Plant Alpha: 30.4457
#   → Updated. New: N/A
# Checking C4
#
# Calculating footprint for Nimbus Subsidiary
#   Product Nimbus Tonic Water 1L: Assigned footprint 52.2026
#   Product Nimbus Cola 500ml: Assigned footprint 52.2026
#   Final footprint for Nimbus Subsidiary: 52.2026
#   → Updated. New: N/A
# Checking C2
#
# Calculating footprint for Lumina Plant A
#   Product Lumina Sparkling Water 500ml: Assigned footprint 44.9321
#   Final footprint for Lumina Plant A: 44.9321
#   → Updated. New: N/A
# Checking C3
#
# Calculating footprint for Apex Site X
#   Product Apex Ginger Ale 330ml: Assigned footprint 50.4549
#   Product Apex Zero Cola 500ml: Assigned footprint 50.4549
#   Final footprint for Apex Site X: 50.4549
#   → Updated. New: N/A
#
# --- Iteration 7 ---
# Checking C5
#
# Calculating footprint for Vertex Plant Alpha
#   Product Vertex Iced Tea 500ml: Assigned footprint 30.5634
#   Final footprint for Vertex Plant Alpha: 30.5634
#   → Updated. New: N/A
# Checking C3
#
# Calculating footprint for Apex Site X
#   Product Apex Ginger Ale 330ml: Assigned footprint 50.4666
#   Product Apex Zero Cola 500ml: Assigned footprint 50.4666
#   Final footprint for Apex Site X: 50.4666
#   → Updated. New: N/A
# Checking C4
#
# Calculating footprint for Nimbus Subsidiary
#   Product Nimbus Tonic Water 1L: Assigned footprint 52.4296
#   Product Nimbus Cola 500ml: Assigned footprint 52.4296
#   Final footprint for Nimbus Subsidiary: 52.4296
#   → Updated. New: N/A
# Checking C2
#
# Calculating footprint for Lumina Plant A
#   Product Lumina Sparkling Water 500ml: Assigned footprint 45.0989
#   Final footprint for Lumina Plant A: 45.0989
#   → Updated. New: N/A
# Checking C1
#
# Calculating footprint for Orion Plant A1
#   Product Orion Cola 500ml: Assigned footprint 74.6182
#   Product Orion Diet Cola 500ml: Assigned footprint 74.6182
#   Final footprint for Orion Plant A1: 74.6182
#   → Updated. New: N/A
#
# --- Iteration 8 ---
# Checking C5
#
# Calculating footprint for Vertex Plant Alpha
#   Product Vertex Iced Tea 500ml: Assigned footprint 30.6099
#   Final footprint for Vertex Plant Alpha: 30.6099
#   → Updated. New: N/A
# Checking C3
#
# Calculating footprint for Apex Site X
#   Product Apex Ginger Ale 330ml: Assigned footprint 50.5908
#   Product Apex Zero Cola 500ml: Assigned footprint 50.5908
#   Final footprint for Apex Site X: 50.5908
#   → Updated. New: N/A
# Checking C1
#
# Calculating footprint for Orion Plant A1
#   Product Orion Cola 500ml: Assigned footprint 74.6418
#   Product Orion Diet Cola 500ml: Assigned footprint 74.6418
#   Final footprint for Orion Plant A1: 74.6418
#   → Updated. New: N/A
# Checking C2
#
# Calculating footprint for Lumina Plant A
#   Product Lumina Sparkling Water 500ml: Assigned footprint 45.1636
#   Final footprint for Lumina Plant A: 45.1636
#   → Updated. New: N/A
# Checking C4
#
# Calculating footprint for Nimbus Subsidiary
#   Product Nimbus Tonic Water 1L: Assigned footprint 52.5402
#   Product Nimbus Cola 500ml: Assigned footprint 52.5402
#   Final footprint for Nimbus Subsidiary: 52.5402
#   → Updated. New: N/A
#
# --- Iteration 9 ---
# Checking C1
#
# Calculating footprint for Orion Plant A1
#   Product Orion Cola 500ml: Assigned footprint 74.6691
#   Product Orion Diet Cola 500ml: Assigned footprint 74.6691
#   Final footprint for Orion Plant A1: 74.6691
#   → Updated. New: N/A
# Checking C4
#
# Calculating footprint for Nimbus Subsidiary
#   Product Nimbus Tonic Water 1L: Assigned footprint 52.5443
#   Product Nimbus Cola 500ml: Assigned footprint 52.5443
#   Final footprint for Nimbus Subsidiary: 52.5443
#   → Updated. New: N/A
# Checking C3
#
# Calculating footprint for Apex Site X
#   Product Apex Ginger Ale 330ml: Assigned footprint 50.6219
#   Product Apex Zero Cola 500ml: Assigned footprint 50.6219
#   Final footprint for Apex Site X: 50.6219
#   → Updated. New: N/A
# Checking C2
#
# Calculating footprint for Lumina Plant A
#   Product Lumina Sparkling Water 500ml: Assigned footprint 45.1801
#   Final footprint for Lumina Plant A: 45.1801
#   → Updated. New: N/A
# Checking C5
#
# Calculating footprint for Vertex Plant Alpha
#   Product Vertex Iced Tea 500ml: Assigned footprint 30.6363
#   Final footprint for Vertex Plant Alpha: 30.6363
#   → Updated. New: N/A
#
# --- Iteration 10 ---
# Checking C3
#
# Calculating footprint for Apex Site X
#   Product Apex Ginger Ale 330ml: Assigned footprint 50.6256
#   Product Apex Zero Cola 500ml: Assigned footprint 50.6256
#   Final footprint for Apex Site X: 50.6256
#   → Updated. New: N/A
# Checking C2
#
# Calculating footprint for Lumina Plant A
#   Product Lumina Sparkling Water 500ml: Assigned footprint 45.1817
#   Final footprint for Lumina Plant A: 45.1817
#   → Updated. New: N/A
# Checking C4
#
# Calculating footprint for Nimbus Subsidiary
#   Product Nimbus Tonic Water 1L: Assigned footprint 52.5528
#   Product Nimbus Cola 500ml: Assigned footprint 52.5528
#   Final footprint for Nimbus Subsidiary: 52.5528
#   → Updated. New: N/A
# Checking C1
#
# Calculating footprint for Orion Plant A1
#   Product Orion Cola 500ml: Assigned footprint 74.6818
#   Product Orion Diet Cola 500ml: Assigned footprint 74.6818
#   Final footprint for Orion Plant A1: 74.6818
#   → Updated. New: N/A
# Checking C5
#
# Calculating footprint for Vertex Plant Alpha
#   Product Vertex Iced Tea 500ml: Assigned footprint 30.6380
#   Final footprint for Vertex Plant Alpha: 30.6380
#   → Updated. New: N/A
#
# --- Iteration 11 ---
# Checking C4
#
# Calculating footprint for Nimbus Subsidiary
#   Product Nimbus Tonic Water 1L: Assigned footprint 52.5548
#   Product Nimbus Cola 500ml: Assigned footprint 52.5548
#   Final footprint for Nimbus Subsidiary: 52.5548
#   → Updated. New: N/A
# Checking C2
#
# Calculating footprint for Lumina Plant A
#   Product Lumina Sparkling Water 500ml: Assigned footprint 45.1840
#   Final footprint for Lumina Plant A: 45.1840
#   → Updated. New: N/A
# Checking C1
#
# Calculating footprint for Orion Plant A1
#   Product Orion Cola 500ml: Assigned footprint 74.6826
#   Product Orion Diet Cola 500ml: Assigned footprint 74.6826
#   Final footprint for Orion Plant A1: 74.6826
#   → Updated. New: N/A
# Checking C3
#
# Calculating footprint for Apex Site X
#   Product Apex Ginger Ale 330ml: Assigned footprint 50.6299
#   Product Apex Zero Cola 500ml: Assigned footprint 50.6299
#   Final footprint for Apex Site X: 50.6299
#   → Updated. New: N/A
# Checking C5
#
# Calculating footprint for Vertex Plant Alpha
#   Product Vertex Iced Tea 500ml: Assigned footprint 30.6386
#   Final footprint for Vertex Plant Alpha: 30.6386
#   → Updated. New: N/A
#
# --- Iteration 12 ---
# Checking C4
#
# Calculating footprint for Nimbus Subsidiary
#   Product Nimbus Tonic Water 1L: Assigned footprint 52.5558
#   Product Nimbus Cola 500ml: Assigned footprint 52.5558
#   Final footprint for Nimbus Subsidiary: 52.5558
#   → Updated. New: N/A
# Checking C3
#
# Calculating footprint for Apex Site X
#   Product Apex Ginger Ale 330ml: Assigned footprint 50.6301
#   Product Apex Zero Cola 500ml: Assigned footprint 50.6301
#   Final footprint for Apex Site X: 50.6301
#
# Calculating footprint for Apex Site X
#   Product Apex Ginger Ale 330ml: Assigned footprint 50.6301
#   Product Apex Zero Cola 500ml: Assigned footprint 50.6301
#   Final footprint for Apex Site X: 50.6301
#
# Calculating footprint for Apex Division 1
#   → Updated. New: N/A
# Checking C2
#
# Calculating footprint for Lumina Plant A
#   Product Lumina Sparkling Water 500ml: Assigned footprint 45.1847
#   Final footprint for Lumina Plant A: 45.1847
#   → Updated. New: N/A
# Checking C1
#
# Calculating footprint for Orion Plant A1
#   Product Orion Cola 500ml: Assigned footprint 74.6836
#   Product Orion Diet Cola 500ml: Assigned footprint 74.6836
#   Final footprint for Orion Plant A1: 74.6836
#   → Updated. New: N/A
# Checking C5
#
# Calculating footprint for Vertex Plant Alpha
#   Product Vertex Iced Tea 500ml: Assigned footprint 30.6388
#   Final footprint for Vertex Plant Alpha: 30.6388
#
# Calculating footprint for Vertex Plant Beta
#   Product Vertex Cola 330ml: Assigned footprint 25.6185
#   Final footprint for Vertex Plant Beta: 25.6185
#   → Updated. New: N/A
#
# --- Iteration 13 ---
# Checking C2
#
# Calculating footprint for Lumina Plant A
#   Product Lumina Sparkling Water 500ml: Assigned footprint 45.2676
#   Final footprint for Lumina Plant A: 45.2676
#   → Updated. New: N/A
# Checking C1
#
# Calculating footprint for Orion Plant A1
#   Product Orion Cola 500ml: Assigned footprint 74.7707
#   Product Orion Diet Cola 500ml: Assigned footprint 74.7707
#   Final footprint for Orion Plant A1: 74.7707
#   → Updated. New: N/A
# Checking C4
#
# Calculating footprint for Nimbus Subsidiary
#   Product Nimbus Tonic Water 1L: Assigned footprint 52.6352
#   Product Nimbus Cola 500ml: Assigned footprint 52.6352
#   Final footprint for Nimbus Subsidiary: 52.6352
#   → Updated. New: N/A
# Checking C3
#
# Calculating footprint for Apex Site X
#   Product Apex Ginger Ale 330ml: Assigned footprint 50.7306
#   Product Apex Zero Cola 500ml: Assigned footprint 50.7306
#   Final footprint for Apex Site X: 50.7306
#   → Updated. New: N/A
# Checking C5
#
# Calculating footprint for Vertex Plant Alpha
#   Product Vertex Iced Tea 500ml: Assigned footprint 30.6741
#   Final footprint for Vertex Plant Alpha: 30.6741
#   → Updated. New: N/A
#
# --- Iteration 14 ---
# Checking C5
#
# Calculating footprint for Vertex Plant Alpha
#   Product Vertex Iced Tea 500ml: Assigned footprint 30.6741
#   Final footprint for Vertex Plant Alpha: 30.6741
#
# Calculating footprint for Vertex Plant Beta
#   Product Vertex Cola 330ml: Assigned footprint 25.6450
#   Final footprint for Vertex Plant Beta: 25.6450
#   → Updated. New: N/A
# Checking C4
#
# Calculating footprint for Nimbus Subsidiary
#   Product Nimbus Tonic Water 1L: Assigned footprint 52.6545
#   Product Nimbus Cola 500ml: Assigned footprint 52.6545
#   Final footprint for Nimbus Subsidiary: 52.6545
#   → Updated. New: N/A
# Checking C2
#
# Calculating footprint for Lumina Plant A
#   Product Lumina Sparkling Water 500ml: Assigned footprint 45.3004
#   Final footprint for Lumina Plant A: 45.3004
#   → Updated. New: N/A
# Checking C1
#
# Calculating footprint for Orion Plant A1
#   Product Orion Cola 500ml: Assigned footprint 74.8118
#   Product Orion Diet Cola 500ml: Assigned footprint 74.8118
#   Final footprint for Orion Plant A1: 74.8118
#   → Updated. New: N/A
# Checking C3
#
# Calculating footprint for Apex Site X
#   Product Apex Ginger Ale 330ml: Assigned footprint 50.7478
#   Product Apex Zero Cola 500ml: Assigned footprint 50.7478
#   Final footprint for Apex Site X: 50.7478
#   → Updated. New: N/A
#
# --- Iteration 15 ---
# Checking C5
#
# Calculating footprint for Vertex Plant Alpha
#   Product Vertex Iced Tea 500ml: Assigned footprint 30.6804
#   Final footprint for Vertex Plant Alpha: 30.6804
#   → Updated. New: N/A
# Checking C3
#
# Calculating footprint for Apex Site X
#   Product Apex Ginger Ale 330ml: Assigned footprint 50.7484
#   Product Apex Zero Cola 500ml: Assigned footprint 50.7484
#   Final footprint for Apex Site X: 50.7484
#   → Updated. New: N/A
# Checking C4
#
# Calculating footprint for Nimbus Subsidiary
#   Product Nimbus Tonic Water 1L: Assigned footprint 52.6663
#   Product Nimbus Cola 500ml: Assigned footprint 52.6663
#   Final footprint for Nimbus Subsidiary: 52.6663
#   → Updated. New: N/A
# Checking C1
#
# Calculating footprint for Orion Plant A1
#   Product Orion Cola 500ml: Assigned footprint 74.8170
#   Product Orion Diet Cola 500ml: Assigned footprint 74.8170
#   Final footprint for Orion Plant A1: 74.8170
#   → Updated. New: N/A
# Checking C2
#
# Calculating footprint for Lumina Plant A
#   Product Lumina Sparkling Water 500ml: Assigned footprint 45.3086
#   Final footprint for Lumina Plant A: 45.3086
#   → Updated. New: N/A
#
# --- Iteration 16 ---
# Checking C3
#
# Calculating footprint for Apex Site X
#   Product Apex Ginger Ale 330ml: Assigned footprint 50.7517
#   Product Apex Zero Cola 500ml: Assigned footprint 50.7517
#   Final footprint for Apex Site X: 50.7517
#   → Updated. New: N/A
# Checking C2
#
# Calculating footprint for Lumina Plant A
#   Product Lumina Sparkling Water 500ml: Assigned footprint 45.3089
#   Final footprint for Lumina Plant A: 45.3089
#
# Calculating footprint for Lumina Plant B
#   Product Lumina Energy Drink 250ml: Assigned footprint 31.4913
#   Final footprint for Lumina Plant B: 31.4913
#   → Updated. New: N/A
# Checking C5
#
# Calculating footprint for Vertex Plant Alpha
#   Product Vertex Iced Tea 500ml: Assigned footprint 32.0396
#   Final footprint for Vertex Plant Alpha: 32.0396
#   → Updated. New: N/A
# Checking C4
#
# Calculating footprint for Nimbus Subsidiary
#   Product Nimbus Tonic Water 1L: Assigned footprint 55.0711
#   Product Nimbus Cola 500ml: Assigned footprint 55.0711
#   Final footprint for Nimbus Subsidiary: 55.0711
#   → Updated. New: N/A
# Checking C1
#
# Calculating footprint for Orion Plant A1
#   Product Orion Cola 500ml: Assigned footprint 79.1084
#   Product Orion Diet Cola 500ml: Assigned footprint 79.1084
#   Final footprint for Orion Plant A1: 79.1084
#   → Updated. New: N/A
#
# --- Iteration 17 ---
# Checking C2
#
# Calculating footprint for Lumina Plant A
#   Product Lumina Sparkling Water 500ml: Assigned footprint 46.9014
#   Final footprint for Lumina Plant A: 46.9014
#   → Updated. New: N/A
# Checking C5
#
# Calculating footprint for Vertex Plant Alpha
#   Product Vertex Iced Tea 500ml: Assigned footprint 32.5008
#   Final footprint for Vertex Plant Alpha: 32.5008
#   → Updated. New: N/A
# Checking C4
#
# Calculating footprint for Nimbus Subsidiary
#   Product Nimbus Tonic Water 1L: Assigned footprint 55.8749
#   Product Nimbus Cola 500ml: Assigned footprint 55.8749
#   Final footprint for Nimbus Subsidiary: 55.8749
#   → Updated. New: N/A
# Checking C3
#
# Calculating footprint for Apex Site X
#   Product Apex Ginger Ale 330ml: Assigned footprint 54.8693
#   Product Apex Zero Cola 500ml: Assigned footprint 54.8693
#   Final footprint for Apex Site X: 54.8693
#   → Updated. New: N/A
# Checking C1
#
# Calculating footprint for Orion Plant A1
#   Product Orion Cola 500ml: Assigned footprint 80.1833
#   Product Orion Diet Cola 500ml: Assigned footprint 80.1833
#   Final footprint for Orion Plant A1: 80.1833
#   → Updated. New: N/A
#
# --- Iteration 18 ---
# Checking C2
#
# Calculating footprint for Lumina Plant A
#   Product Lumina Sparkling Water 500ml: Assigned footprint 47.5688
#   Final footprint for Lumina Plant A: 47.5688
#   → Updated. New: N/A
# Checking C4
#
# Calculating footprint for Nimbus Subsidiary
#   Product Nimbus Tonic Water 1L: Assigned footprint 56.7129
#   Product Nimbus Cola 500ml: Assigned footprint 56.7129
#   Final footprint for Nimbus Subsidiary: 56.7129
#   → Updated. New: N/A
# Checking C5
#
# Calculating footprint for Vertex Plant Alpha
#   Product Vertex Iced Tea 500ml: Assigned footprint 33.0101
#   Final footprint for Vertex Plant Alpha: 33.0101
#   → Updated. New: N/A
# Checking C3
#
# Calculating footprint for Apex Site X
#   Product Apex Ginger Ale 330ml: Assigned footprint 55.2730
#   Product Apex Zero Cola 500ml: Assigned footprint 55.2730
#   Final footprint for Apex Site X: 55.2730
#   → Updated. New: N/A
# Checking C1
#
# Calculating footprint for Orion Plant A1
#   Product Orion Cola 500ml: Assigned footprint 80.5268
#   Product Orion Diet Cola 500ml: Assigned footprint 80.5268
#   Final footprint for Orion Plant A1: 80.5268
#   → Updated. New: N/A
#
# --- Iteration 19 ---
# Checking C4
#
# Calculating footprint for Nimbus Subsidiary
#   Product Nimbus Tonic Water 1L: Assigned footprint 56.8622
#   Product Nimbus Cola 500ml: Assigned footprint 56.8622
#   Final footprint for Nimbus Subsidiary: 56.8622
#   → Updated. New: N/A
# Checking C1
#
# Calculating footprint for Orion Plant A1
#   Product Orion Cola 500ml: Assigned footprint 80.5493
#   Product Orion Diet Cola 500ml: Assigned footprint 80.5493
#   Final footprint for Orion Plant A1: 80.5493
#   → Updated. New: N/A
# Checking C5
#
# Calculating footprint for Vertex Plant Alpha
#   Product Vertex Iced Tea 500ml: Assigned footprint 33.0680
#   Final footprint for Vertex Plant Alpha: 33.0680
#   → Updated. New: N/A
# Checking C2
#
# Calculating footprint for Lumina Plant A
#   Product Lumina Sparkling Water 500ml: Assigned footprint 47.7649
#   Final footprint for Lumina Plant A: 47.7649
#   → Updated. New: N/A
# Checking C3
#
# Calculating footprint for Apex Site X
#   Product Apex Ginger Ale 330ml: Assigned footprint 55.3746
#   Product Apex Zero Cola 500ml: Assigned footprint 55.3746
#   Final footprint for Apex Site X: 55.3746
#   → Updated. New: N/A
#
# --- Iteration 20 ---
# Checking C5
#
# Calculating footprint for Vertex Plant Alpha
#   Product Vertex Iced Tea 500ml: Assigned footprint 33.0814
#   Final footprint for Vertex Plant Alpha: 33.0814
#   → Updated. New: N/A
# Checking C2
#
# Calculating footprint for Lumina Plant A
#   Product Lumina Sparkling Water 500ml: Assigned footprint 47.7770
#   Final footprint for Lumina Plant A: 47.7770
#   → Updated. New: N/A
# Checking C3
#
# Calculating footprint for Apex Site X
#   Product Apex Ginger Ale 330ml: Assigned footprint 55.3767
#   Product Apex Zero Cola 500ml: Assigned footprint 55.3767
#   Final footprint for Apex Site X: 55.3767
#   → Updated. New: N/A
# Checking C4
#
# Calculating footprint for Nimbus Subsidiary
#   Product Nimbus Tonic Water 1L: Assigned footprint 56.9016
#   Product Nimbus Cola 500ml: Assigned footprint 56.9016
#   Final footprint for Nimbus Subsidiary: 56.9016
#   → Updated. New: N/A
# Checking C1
#
# Calculating footprint for Orion Plant A1
#   Product Orion Cola 500ml: Assigned footprint 80.6121
#   Product Orion Diet Cola 500ml: Assigned footprint 80.6121
#   Final footprint for Orion Plant A1: 80.6121
#   → Updated. New: N/A
#
# --- Iteration 21 ---
# Checking C4
#
# Calculating footprint for Nimbus Subsidiary
#   Product Nimbus Tonic Water 1L: Assigned footprint 56.9112
#   Product Nimbus Cola 500ml: Assigned footprint 56.9112
#   Final footprint for Nimbus Subsidiary: 56.9112
#   → Updated. New: N/A
# Checking C1
#
# Calculating footprint for Orion Plant A1
#   Product Orion Cola 500ml: Assigned footprint 80.6135
#   Product Orion Diet Cola 500ml: Assigned footprint 80.6135
#   Final footprint for Orion Plant A1: 80.6135
#   → Updated. New: N/A
# Checking C3
#
# Calculating footprint for Apex Site X
#   Product Apex Ginger Ale 330ml: Assigned footprint 55.3951
#   Product Apex Zero Cola 500ml: Assigned footprint 55.3951
#   Final footprint for Apex Site X: 55.3951
#   → Updated. New: N/A
# Checking C5
#
# Calculating footprint for Vertex Plant Alpha
#   Product Vertex Iced Tea 500ml: Assigned footprint 33.0905
#   Final footprint for Vertex Plant Alpha: 33.0905
#   → Updated. New: N/A
# Checking C2
#
# Calculating footprint for Lumina Plant A
#   Product Lumina Sparkling Water 500ml: Assigned footprint 47.7907
#   Final footprint for Lumina Plant A: 47.7907
#   → Updated. New: N/A
#
# --- Iteration 22 ---
# Checking C4
#
# Calculating footprint for Nimbus Subsidiary
#   Product Nimbus Tonic Water 1L: Assigned footprint 56.9158
#   Product Nimbus Cola 500ml: Assigned footprint 56.9158
#   Final footprint for Nimbus Subsidiary: 56.9158
#   → Updated. New: N/A
# Checking C1
#
# Calculating footprint for Orion Plant A1
#   Product Orion Cola 500ml: Assigned footprint 80.6202
#   Product Orion Diet Cola 500ml: Assigned footprint 80.6202
#   Final footprint for Orion Plant A1: 80.6202
#   → Updated. New: N/A
# Checking C2
#
# Calculating footprint for Lumina Plant A
#   Product Lumina Sparkling Water 500ml: Assigned footprint 47.7918
#   Final footprint for Lumina Plant A: 47.7918
#   → Updated. New: N/A
# Checking C5
#
# Calculating footprint for Vertex Plant Alpha
#   Product Vertex Iced Tea 500ml: Assigned footprint 33.0917
#   Final footprint for Vertex Plant Alpha: 33.0917
#   → Updated. New: N/A
# Checking C3
#
# Calculating footprint for Apex Site X
#   Product Apex Ginger Ale 330ml: Assigned footprint 55.3989
#   Product Apex Zero Cola 500ml: Assigned footprint 55.3989
#   Final footprint for Apex Site X: 55.3989
#   → Updated. New: N/A
#
# --- Iteration 23 ---
# Checking C5
#
# Calculating footprint for Vertex Plant Alpha
#   Product Vertex Iced Tea 500ml: Assigned footprint 33.0920
#   Final footprint for Vertex Plant Alpha: 33.0920
#
# Calculating footprint for Vertex Plant Beta
#   Product Vertex Cola 330ml: Assigned footprint 27.7407
#   Final footprint for Vertex Plant Beta: 27.7407
#   → Updated. New: N/A
# Checking C2
#
# Calculating footprint for Lumina Plant A
#   Product Lumina Sparkling Water 500ml: Assigned footprint 47.9647
#   Final footprint for Lumina Plant A: 47.9647
#   → Updated. New: N/A
# Checking C4
#
# Calculating footprint for Nimbus Subsidiary
#   Product Nimbus Tonic Water 1L: Assigned footprint 57.0547
#   Product Nimbus Cola 500ml: Assigned footprint 57.0547
#   Final footprint for Nimbus Subsidiary: 57.0547
#   → Updated. New: N/A
# Checking C1
#
# Calculating footprint for Orion Plant A1
#   Product Orion Cola 500ml: Assigned footprint 80.8235
#   Product Orion Diet Cola 500ml: Assigned footprint 80.8235
#   Final footprint for Orion Plant A1: 80.8235
#   → Updated. New: N/A
# Checking C3
#
# Calculating footprint for Apex Site X
#   Product Apex Ginger Ale 330ml: Assigned footprint 55.6070
#   Product Apex Zero Cola 500ml: Assigned footprint 55.6070
#   Final footprint for Apex Site X: 55.6070
#   → Updated. New: N/A
#
# --- Iteration 24 ---
# Checking C4
#
# Calculating footprint for Nimbus Subsidiary
#   Product Nimbus Tonic Water 1L: Assigned footprint 57.1173
#   Product Nimbus Cola 500ml: Assigned footprint 57.1173
#   Final footprint for Nimbus Subsidiary: 57.1173
#   → Updated. New: N/A
# Checking C1
#
# Calculating footprint for Orion Plant A1
#   Product Orion Cola 500ml: Assigned footprint 80.8658
#   Product Orion Diet Cola 500ml: Assigned footprint 80.8658
#   Final footprint for Orion Plant A1: 80.8658
#   → Updated. New: N/A
# Checking C5
#
# Calculating footprint for Vertex Plant Alpha
#   Product Vertex Iced Tea 500ml: Assigned footprint 33.1718
#   Final footprint for Vertex Plant Alpha: 33.1718
#   → Updated. New: N/A
# Checking C3
#
# Calculating footprint for Apex Site X
#   Product Apex Ginger Ale 330ml: Assigned footprint 55.6321
#   Product Apex Zero Cola 500ml: Assigned footprint 55.6321
#   Final footprint for Apex Site X: 55.6321
#   → Updated. New: N/A
# Checking C2
#
# Calculating footprint for Lumina Plant A
#   Product Lumina Sparkling Water 500ml: Assigned footprint 48.0379
#   Final footprint for Lumina Plant A: 48.0379
#   → Updated. New: N/A
#
# --- Iteration 25 ---
# Checking C1
#
# Calculating footprint for Orion Plant A1
#   Product Orion Cola 500ml: Assigned footprint 80.8887
#   Product Orion Diet Cola 500ml: Assigned footprint 80.8887
#   Final footprint for Orion Plant A1: 80.8887
#   → Updated. New: N/A
# Checking C2
#
# Calculating footprint for Lumina Plant A
#   Product Lumina Sparkling Water 500ml: Assigned footprint 48.0403
#   Final footprint for Lumina Plant A: 48.0403
#   → Updated. New: N/A
# Checking C5
#
# Calculating footprint for Vertex Plant Alpha
#   Product Vertex Iced Tea 500ml: Assigned footprint 33.1769
#   Final footprint for Vertex Plant Alpha: 33.1769
#   → Updated. New: N/A
# Checking C3
#
# Calculating footprint for Apex Site X
#   Product Apex Ginger Ale 330ml: Assigned footprint 55.6410
#   Product Apex Zero Cola 500ml: Assigned footprint 55.6410
#   Final footprint for Apex Site X: 55.6410
#   → Updated. New: N/A
# Checking C4
#
# Calculating footprint for Nimbus Subsidiary
#   Product Nimbus Tonic Water 1L: Assigned footprint 57.1439
#   Product Nimbus Cola 500ml: Assigned footprint 57.1439
#   Final footprint for Nimbus Subsidiary: 57.1439
#   → Updated. New: N/A
#
# --- Iteration 26 ---
# Checking C5
#
# Calculating footprint for Vertex Plant Alpha
#   Product Vertex Iced Tea 500ml: Assigned footprint 33.1800
#   Final footprint for Vertex Plant Alpha: 33.1800
#   → Updated. New: N/A
# Checking C1
#
# Calculating footprint for Orion Plant A1
#   Product Orion Cola 500ml: Assigned footprint 80.8952
#   Product Orion Diet Cola 500ml: Assigned footprint 80.8952
#   Final footprint for Orion Plant A1: 80.8952
#   → Updated. New: N/A
# Checking C2
#
# Calculating footprint for Lumina Plant A
#   Product Lumina Sparkling Water 500ml: Assigned footprint 48.0446
#   Final footprint for Lumina Plant A: 48.0446
#   → Updated. New: N/A
# Checking C3
#
# Calculating footprint for Apex Site X
#   Product Apex Ginger Ale 330ml: Assigned footprint 55.6470
#   Product Apex Zero Cola 500ml: Assigned footprint 55.6470
#   Final footprint for Apex Site X: 55.6470
#   → Updated. New: N/A
# Checking C4
#
# Calculating footprint for Nimbus Subsidiary
#   Product Nimbus Tonic Water 1L: Assigned footprint 57.1464
#   Product Nimbus Cola 500ml: Assigned footprint 57.1464
#   Final footprint for Nimbus Subsidiary: 57.1464
#   → Updated. New: N/A
#
# --- Iteration 27 ---
# Checking C1
#
# Calculating footprint for Orion Plant A1
#   Product Orion Cola 500ml: Assigned footprint 80.8972
#   Product Orion Diet Cola 500ml: Assigned footprint 80.8972
#   Final footprint for Orion Plant A1: 80.8972
#   → Updated. New: N/A
# Checking C2
#
# Calculating footprint for Lumina Plant A
#   Product Lumina Sparkling Water 500ml: Assigned footprint 48.0458
#   Final footprint for Lumina Plant A: 48.0458
#   → Updated. New: N/A
# Checking C4
#
# Calculating footprint for Nimbus Subsidiary
#   Product Nimbus Tonic Water 1L: Assigned footprint 57.1468
#   Product Nimbus Cola 500ml: Assigned footprint 57.1468
#   Final footprint for Nimbus Subsidiary: 57.1468
#
# Calculating footprint for Nimbus Subsidiary
#   Product Nimbus Tonic Water 1L: Assigned footprint 57.1468
#   Product Nimbus Cola 500ml: Assigned footprint 57.1468
#   Final footprint for Nimbus Subsidiary: 57.1468
#
# Calculating footprint for Nimbus Company
#   → Updated. New: 0.0000
# Checking C5
#
# Calculating footprint for Vertex Plant Alpha
#   Product Vertex Iced Tea 500ml: Assigned footprint 33.1813
#   Final footprint for Vertex Plant Alpha: 33.1813
#   → Updated. New: N/A
# Checking C3
#
# Calculating footprint for Apex Site X
#   Product Apex Ginger Ale 330ml: Assigned footprint 55.6480
#   Product Apex Zero Cola 500ml: Assigned footprint 55.6480
#   Final footprint for Apex Site X: 55.6480
#   → Updated. New: N/A
#
# --- Iteration 28 ---
# Checking C2
#
# Calculating footprint for Lumina Plant A
#   Product Lumina Sparkling Water 500ml: Assigned footprint 48.0460
#   Final footprint for Lumina Plant A: 48.0460
#
# Calculating footprint for Lumina Plant B
#   Product Lumina Energy Drink 250ml: Assigned footprint 32.8301
#   Final footprint for Lumina Plant B: 32.8301
#   → Updated. New: N/A
# Checking C4
#
# Calculating footprint for Nimbus Subsidiary
#   Product Nimbus Tonic Water 1L: Assigned footprint 57.2483
#   Product Nimbus Cola 500ml: Assigned footprint 57.2483
#   Final footprint for Nimbus Subsidiary: 57.2483
#   → Updated. New: 0.0000
# Checking C5
#
# Calculating footprint for Vertex Plant Alpha
#   Product Vertex Iced Tea 500ml: Assigned footprint 33.2505
#   Final footprint for Vertex Plant Alpha: 33.2505
#   → Updated. New: N/A
# Checking C3
#
# Calculating footprint for Apex Site X
#   Product Apex Ginger Ale 330ml: Assigned footprint 55.7865
#   Product Apex Zero Cola 500ml: Assigned footprint 55.7865
#   Final footprint for Apex Site X: 55.7865
#   → Updated. New: N/A
# Checking C1
#
# Calculating footprint for Orion Plant A1
#   Product Orion Cola 500ml: Assigned footprint 81.1082
#   Product Orion Diet Cola 500ml: Assigned footprint 81.1082
#   Final footprint for Orion Plant A1: 81.1082
#   → Updated. New: N/A
#
# --- Iteration 29 ---
# Checking C4
#
# Calculating footprint for Nimbus Subsidiary
#   Product Nimbus Tonic Water 1L: Assigned footprint 57.3064
#   Product Nimbus Cola 500ml: Assigned footprint 57.3064
#   Final footprint for Nimbus Subsidiary: 57.3064
#   → Updated. New: 0.0000
# Checking C1
#
# Calculating footprint for Orion Plant A1
#   Product Orion Cola 500ml: Assigned footprint 81.1169
#   Product Orion Diet Cola 500ml: Assigned footprint 81.1169
#   Final footprint for Orion Plant A1: 81.1169
#   → Updated. New: N/A
# Checking C5
#
# Calculating footprint for Vertex Plant Alpha
#   Product Vertex Iced Tea 500ml: Assigned footprint 33.2750
#   Final footprint for Vertex Plant Alpha: 33.2750
#   → Updated. New: N/A
# Checking C2
#
# Calculating footprint for Lumina Plant A
#   Product Lumina Sparkling Water 500ml: Assigned footprint 48.1410
#   Final footprint for Lumina Plant A: 48.1410
#   → Updated. New: N/A
# Checking C3
#
# Calculating footprint for Apex Site X
#   Product Apex Ginger Ale 330ml: Assigned footprint 55.8399
#   Product Apex Zero Cola 500ml: Assigned footprint 55.8399
#   Final footprint for Apex Site X: 55.8399
#   → Updated. New: N/A
#
# --- Iteration 30 ---
# Checking C3
#
# Calculating footprint for Apex Site X
#   Product Apex Ginger Ale 330ml: Assigned footprint 55.8399
#   Product Apex Zero Cola 500ml: Assigned footprint 55.8399
#   Final footprint for Apex Site X: 55.8399
#
# Calculating footprint for Apex Site X
#   Product Apex Ginger Ale 330ml: Assigned footprint 55.8399
#   Product Apex Zero Cola 500ml: Assigned footprint 55.8399
#   Final footprint for Apex Site X: 55.8399
#
# Calculating footprint for Apex Division 1
#
# Calculating footprint for Apex Site X
#   Product Apex Ginger Ale 330ml: Assigned footprint 55.8399
#   Product Apex Zero Cola 500ml: Assigned footprint 55.8399
#   Final footprint for Apex Site X: 55.8399
#
# Calculating footprint for Apex Division 1
#
# Calculating footprint for Apex Company
#   Product Apex Admin Support: Assigned footprint 28.8178
#   Final footprint for Apex Company: 28.8178
#   → Updated. New: 28.8178
# Checking C2
#
# Calculating footprint for Lumina Plant A
#   Product Lumina Sparkling Water 500ml: Assigned footprint 49.4688
#   Final footprint for Lumina Plant A: 49.4688
#   → Updated. New: N/A
# Checking C1
#
# Calculating footprint for Orion Plant A1
#   Product Orion Cola 500ml: Assigned footprint 84.7406
#   Product Orion Diet Cola 500ml: Assigned footprint 84.7406
#   Final footprint for Orion Plant A1: 84.7406
#   → Updated. New: N/A
# Checking C5
#
# Calculating footprint for Vertex Plant Alpha
#   Product Vertex Iced Tea 500ml: Assigned footprint 34.7713
#   Final footprint for Vertex Plant Alpha: 34.7713
#   → Updated. New: N/A
# Checking C4
#
# Calculating footprint for Nimbus Subsidiary
#   Product Nimbus Tonic Water 1L: Assigned footprint 61.0763
#   Product Nimbus Cola 500ml: Assigned footprint 61.0763
#   Final footprint for Nimbus Subsidiary: 61.0763
#   → Updated. New: 0.0000
#
# --- Iteration 31 ---
# Checking C2
#
# Calculating footprint for Lumina Plant A
#   Product Lumina Sparkling Water 500ml: Assigned footprint 50.2452
#   Final footprint for Lumina Plant A: 50.2452
#   → Updated. New: N/A
# Checking C1
#
# Calculating footprint for Orion Plant A1
#   Product Orion Cola 500ml: Assigned footprint 85.5634
#   Product Orion Diet Cola 500ml: Assigned footprint 85.5634
#   Final footprint for Orion Plant A1: 85.5634
#   → Updated. New: N/A
# Checking C3
#
# Calculating footprint for Apex Site X
#   Product Apex Ginger Ale 330ml: Assigned footprint 59.6013
#   Product Apex Zero Cola 500ml: Assigned footprint 59.6013
#   Final footprint for Apex Site X: 59.6013
#   → Updated. New: 28.8178
# Checking C4
#
# Calculating footprint for Nimbus Subsidiary
#   Product Nimbus Tonic Water 1L: Assigned footprint 61.8297
#   Product Nimbus Cola 500ml: Assigned footprint 61.8297
#   Final footprint for Nimbus Subsidiary: 61.8297
#   → Updated. New: 0.0000
# Checking C5
#
# Calculating footprint for Vertex Plant Alpha
#   Product Vertex Iced Tea 500ml: Assigned footprint 35.5197
#   Final footprint for Vertex Plant Alpha: 35.5197
#   → Updated. New: N/A
#
# --- Iteration 32 ---
# Checking C4
#
# Calculating footprint for Nimbus Subsidiary
#   Product Nimbus Tonic Water 1L: Assigned footprint 61.8820
#   Product Nimbus Cola 500ml: Assigned footprint 61.8820
#   Final footprint for Nimbus Subsidiary: 61.8820
#   → Updated. New: 0.0000
# Checking C2
#
# Calculating footprint for Lumina Plant A
#   Product Lumina Sparkling Water 500ml: Assigned footprint 50.8592
#   Final footprint for Lumina Plant A: 50.8592
#   → Updated. New: N/A
# Checking C3
#
# Calculating footprint for Apex Site X
#   Product Apex Ginger Ale 330ml: Assigned footprint 59.8463
#   Product Apex Zero Cola 500ml: Assigned footprint 59.8463
#   Final footprint for Apex Site X: 59.8463
#   → Updated. New: 28.8178
# Checking C5
#
# Calculating footprint for Vertex Plant Alpha
#   Product Vertex Iced Tea 500ml: Assigned footprint 35.5613
#   Final footprint for Vertex Plant Alpha: 35.5613
#   → Updated. New: N/A
# Checking C1
#
# Calculating footprint for Orion Plant A1
#   Product Orion Cola 500ml: Assigned footprint 86.4869
#   Product Orion Diet Cola 500ml: Assigned footprint 86.4869
#   Final footprint for Orion Plant A1: 86.4869
#   → Updated. New: N/A
#
# --- Iteration 33 ---
# Checking C1
#
# Calculating footprint for Orion Plant A1
#   Product Orion Cola 500ml: Assigned footprint 86.4869
#   Product Orion Diet Cola 500ml: Assigned footprint 86.4869
#   Final footprint for Orion Plant A1: 86.4869
#
# Calculating footprint for Orion Plant A2
#   Product Orion Orange Soda 330ml: Assigned footprint 32.4117
#   Final footprint for Orion Plant A2: 32.4117
#   → Updated. New: N/A
# Checking C4
#
# Calculating footprint for Nimbus Subsidiary
#   Product Nimbus Tonic Water 1L: Assigned footprint 64.9644
#   Product Nimbus Cola 500ml: Assigned footprint 64.9644
#   Final footprint for Nimbus Subsidiary: 64.9644
#   → Updated. New: 0.0000
# Checking C5
#
# Calculating footprint for Vertex Plant Alpha
#   Product Vertex Iced Tea 500ml: Assigned footprint 36.7494
#   Final footprint for Vertex Plant Alpha: 36.7494
#   → Updated. New: N/A
# Checking C3
#
# Calculating footprint for Apex Site X
#   Product Apex Ginger Ale 330ml: Assigned footprint 62.8908
#   Product Apex Zero Cola 500ml: Assigned footprint 62.8908
#   Final footprint for Apex Site X: 62.8908
#   → Updated. New: 28.8178
# Checking C2
#
# Calculating footprint for Lumina Plant A
#   Product Lumina Sparkling Water 500ml: Assigned footprint 52.5198
#   Final footprint for Lumina Plant A: 52.5198
#   → Updated. New: N/A
#
# --- Iteration 34 ---
# Checking C5
#
# Calculating footprint for Vertex Plant Alpha
#   Product Vertex Iced Tea 500ml: Assigned footprint 37.0150
#   Final footprint for Vertex Plant Alpha: 37.0150
#   → Updated. New: N/A
# Checking C1
#
# Calculating footprint for Orion Plant A1
#   Product Orion Cola 500ml: Assigned footprint 90.2105
#   Product Orion Diet Cola 500ml: Assigned footprint 90.2105
#   Final footprint for Orion Plant A1: 90.2105
#   → Updated. New: N/A
# Checking C2
#
# Calculating footprint for Lumina Plant A
#   Product Lumina Sparkling Water 500ml: Assigned footprint 52.9180
#   Final footprint for Lumina Plant A: 52.9180
#   → Updated. New: N/A
# Checking C4
#
# Calculating footprint for Nimbus Subsidiary
#   Product Nimbus Tonic Water 1L: Assigned footprint 66.2471
#   Product Nimbus Cola 500ml: Assigned footprint 66.2471
#   Final footprint for Nimbus Subsidiary: 66.2471
#   → Updated. New: 0.0000
# Checking C3
#
# Calculating footprint for Apex Site X
#   Product Apex Ginger Ale 330ml: Assigned footprint 63.8580
#   Product Apex Zero Cola 500ml: Assigned footprint 63.8580
#   Final footprint for Apex Site X: 63.8580
#   → Updated. New: 28.8178
#
# --- Iteration 35 ---
# Checking C3
#
# Calculating footprint for Apex Site X
#   Product Apex Ginger Ale 330ml: Assigned footprint 63.8580
#   Product Apex Zero Cola 500ml: Assigned footprint 63.8580
#   Final footprint for Apex Site X: 63.8580
#
# Calculating footprint for Apex Site X
#   Product Apex Ginger Ale 330ml: Assigned footprint 63.8580
#   Product Apex Zero Cola 500ml: Assigned footprint 63.8580
#   Final footprint for Apex Site X: 63.8580
#
# Calculating footprint for Apex Division 1
#
# Calculating footprint for Apex Site X
#   Product Apex Ginger Ale 330ml: Assigned footprint 63.8580
#   Product Apex Zero Cola 500ml: Assigned footprint 63.8580
#   Final footprint for Apex Site X: 63.8580
#
# Calculating footprint for Apex Division 1
#
# Calculating footprint for Apex Company
#   Product Apex Admin Support: Assigned footprint 33.1211
#   Final footprint for Apex Company: 33.1211
#   → Updated. New: 33.1211
# Checking C2
#
# Calculating footprint for Lumina Plant A
#   Product Lumina Sparkling Water 500ml: Assigned footprint 53.3452
#   Final footprint for Lumina Plant A: 53.3452
#   → Updated. New: N/A
# Checking C4
#
# Calculating footprint for Nimbus Subsidiary
#   Product Nimbus Tonic Water 1L: Assigned footprint 66.8887
#   Product Nimbus Cola 500ml: Assigned footprint 66.8887
#   Final footprint for Nimbus Subsidiary: 66.8887
#   → Updated. New: 0.0000
# Checking C1
#
# Calculating footprint for Orion Plant A1
#   Product Orion Cola 500ml: Assigned footprint 91.3123
#   Product Orion Diet Cola 500ml: Assigned footprint 91.3123
#   Final footprint for Orion Plant A1: 91.3123
#   → Updated. New: N/A
# Checking C5
#
# Calculating footprint for Vertex Plant Alpha
#   Product Vertex Iced Tea 500ml: Assigned footprint 37.6966
#   Final footprint for Vertex Plant Alpha: 37.6966
#   → Updated. New: N/A
#
# --- Iteration 36 ---
# Checking C5
#
# Calculating footprint for Vertex Plant Alpha
#   Product Vertex Iced Tea 500ml: Assigned footprint 37.6966
#   Final footprint for Vertex Plant Alpha: 37.6966
#
# Calculating footprint for Vertex Plant Beta
#   Product Vertex Cola 330ml: Assigned footprint 33.2757
#   Final footprint for Vertex Plant Beta: 33.2757
#   → Updated. New: N/A
# Checking C1
#
# Calculating footprint for Orion Plant A1
#   Product Orion Cola 500ml: Assigned footprint 91.7738
#   Product Orion Diet Cola 500ml: Assigned footprint 91.7738
#   Final footprint for Orion Plant A1: 91.7738
#   → Updated. New: N/A
# Checking C2
#
# Calculating footprint for Lumina Plant A
#   Product Lumina Sparkling Water 500ml: Assigned footprint 54.0498
#   Final footprint for Lumina Plant A: 54.0498
#   → Updated. New: N/A
# Checking C3
#
# Calculating footprint for Apex Site X
#   Product Apex Ginger Ale 330ml: Assigned footprint 65.0597
#   Product Apex Zero Cola 500ml: Assigned footprint 65.0597
#   Final footprint for Apex Site X: 65.0597
#   → Updated. New: 33.1211
# Checking C4
#
# Calculating footprint for Nimbus Subsidiary
#   Product Nimbus Tonic Water 1L: Assigned footprint 67.7377
#   Product Nimbus Cola 500ml: Assigned footprint 67.7377
#   Final footprint for Nimbus Subsidiary: 67.7377
#   → Updated. New: 0.0000
#
# --- Iteration 37 ---
# Checking C5
#
# Calculating footprint for Vertex Plant Alpha
#   Product Vertex Iced Tea 500ml: Assigned footprint 37.9825
#   Final footprint for Vertex Plant Alpha: 37.9825
#   → Updated. New: N/A
# Checking C2
#
# Calculating footprint for Lumina Plant A
#   Product Lumina Sparkling Water 500ml: Assigned footprint 54.2732
#   Final footprint for Lumina Plant A: 54.2732
#   → Updated. New: N/A
# Checking C1
#
# Calculating footprint for Orion Plant A1
#   Product Orion Cola 500ml: Assigned footprint 92.2694
#   Product Orion Diet Cola 500ml: Assigned footprint 92.2694
#   Final footprint for Orion Plant A1: 92.2694
#   → Updated. New: N/A
# Checking C4
#
# Calculating footprint for Nimbus Subsidiary
#   Product Nimbus Tonic Water 1L: Assigned footprint 67.8497
#   Product Nimbus Cola 500ml: Assigned footprint 67.8497
#   Final footprint for Nimbus Subsidiary: 67.8497
#   → Updated. New: 0.0000
# Checking C3
#
# Calculating footprint for Apex Site X
#   Product Apex Ginger Ale 330ml: Assigned footprint 65.3403
#   Product Apex Zero Cola 500ml: Assigned footprint 65.3403
#   Final footprint for Apex Site X: 65.3403
#   → Updated. New: 33.1211
#
# --- Iteration 38 ---
# Checking C2
#
# Calculating footprint for Lumina Plant A
#   Product Lumina Sparkling Water 500ml: Assigned footprint 54.3662
#   Final footprint for Lumina Plant A: 54.3662
#   → Updated. New: N/A
# Checking C5
#
# Calculating footprint for Vertex Plant Alpha
#   Product Vertex Iced Tea 500ml: Assigned footprint 38.0440
#   Final footprint for Vertex Plant Alpha: 38.0440
#   → Updated. New: N/A
# Checking C3
#
# Calculating footprint for Apex Site X
#   Product Apex Ginger Ale 330ml: Assigned footprint 65.3522
#   Product Apex Zero Cola 500ml: Assigned footprint 65.3522
#   Final footprint for Apex Site X: 65.3522
#   → Updated. New: 33.1211
# Checking C4
#
# Calculating footprint for Nimbus Subsidiary
#   Product Nimbus Tonic Water 1L: Assigned footprint 67.9052
#   Product Nimbus Cola 500ml: Assigned footprint 67.9052
#   Final footprint for Nimbus Subsidiary: 67.9052
#   → Updated. New: 0.0000
# Checking C1
#
# Calculating footprint for Orion Plant A1
#   Product Orion Cola 500ml: Assigned footprint 92.3614
#   Product Orion Diet Cola 500ml: Assigned footprint 92.3614
#   Final footprint for Orion Plant A1: 92.3614
#   → Updated. New: N/A
#
# --- Iteration 39 ---
# Checking C3
#
# Calculating footprint for Apex Site X
#   Product Apex Ginger Ale 330ml: Assigned footprint 65.3762
#   Product Apex Zero Cola 500ml: Assigned footprint 65.3762
#   Final footprint for Apex Site X: 65.3762
#   → Updated. New: 33.1211
# Checking C4
#
# Calculating footprint for Nimbus Subsidiary
#   Product Nimbus Tonic Water 1L: Assigned footprint 67.9229
#   Product Nimbus Cola 500ml: Assigned footprint 67.9229
#   Final footprint for Nimbus Subsidiary: 67.9229
#   → Updated. New: 0.0000
# Checking C1
#
# Calculating footprint for Orion Plant A1
#   Product Orion Cola 500ml: Assigned footprint 92.3679
#   Product Orion Diet Cola 500ml: Assigned footprint 92.3679
#   Final footprint for Orion Plant A1: 92.3679
#   → Updated. New: N/A
# Checking C2
#
# Calculating footprint for Lumina Plant A
#   Product Lumina Sparkling Water 500ml: Assigned footprint 54.3897
#   Final footprint for Lumina Plant A: 54.3897
#   → Updated. New: N/A
# Checking C5
#
# Calculating footprint for Vertex Plant Alpha
#   Product Vertex Iced Tea 500ml: Assigned footprint 38.0583
#   Final footprint for Vertex Plant Alpha: 38.0583
#   → Updated. New: N/A
#
# --- Iteration 40 ---
# Checking C4
#
# Calculating footprint for Nimbus Subsidiary
#   Product Nimbus Tonic Water 1L: Assigned footprint 67.9266
#   Product Nimbus Cola 500ml: Assigned footprint 67.9266
#   Final footprint for Nimbus Subsidiary: 67.9266
#   → Updated. New: 0.0000
# Checking C5
#
# Calculating footprint for Vertex Plant Alpha
#   Product Vertex Iced Tea 500ml: Assigned footprint 38.0587
#   Final footprint for Vertex Plant Alpha: 38.0587
#
# Calculating footprint for Vertex Plant Beta
#   Product Vertex Cola 330ml: Assigned footprint 33.6331
#   Final footprint for Vertex Plant Beta: 33.6331
#   → Updated. New: N/A
# Checking C2
#
# Calculating footprint for Lumina Plant A
#   Product Lumina Sparkling Water 500ml: Assigned footprint 54.4200
#   Final footprint for Lumina Plant A: 54.4200
#   → Updated. New: N/A
# Checking C1
#
# Calculating footprint for Orion Plant A1
#   Product Orion Cola 500ml: Assigned footprint 92.4047
#   Product Orion Diet Cola 500ml: Assigned footprint 92.4047
#   Final footprint for Orion Plant A1: 92.4047
#   → Updated. New: N/A
# Checking C3
#
# Calculating footprint for Apex Site X
#   Product Apex Ginger Ale 330ml: Assigned footprint 65.4156
#   Product Apex Zero Cola 500ml: Assigned footprint 65.4156
#   Final footprint for Apex Site X: 65.4156
#   → Updated. New: 33.1211
#
# --- Iteration 41 ---
# Checking C1
#
# Calculating footprint for Orion Plant A1
#   Product Orion Cola 500ml: Assigned footprint 92.4109
# ...
# Calculating footprint for Orion Plant A1
#   Product Orion Cola 500ml: Assigned footprint 169.4894
#   Product Orion Diet Cola 500ml: Assigned footprint 169.4894
#   Final footprint for Orion Plant A1: 169.4894
#
# Calculating footprint for Orion Plant A2
#   Product Orion Orange Soda 330ml: Assigned footprint 71.2248
#   Final footprint for Orion Plant A2: 71.2248
#
# Calculating footprint for Orion Bottling A
#
# Calculating footprint for Orion Bottling B
#   Product Orion Lemon Soda 1L: Assigned footprint 82.0049
#   Final footprint for Orion Bottling B: 82.0049
#
# Calculating footprint for Orion Company
#   Product Orion Admin Service: Assigned footprint 84.9856
#   Final footprint for Orion Company: 84.9856
#   → Updated. New: 84.9856
# Checking C5
#
# Calculating footprint for Vertex Plant Alpha
#   Product Vertex Iced Tea 500ml: Assigned footprint 71.8912
#   Final footprint for Vertex Plant Alpha: 71.8912
#
# Calculating footprint for Vertex Plant Beta
#   Product Vertex Cola 330ml: Assigned footprint 71.6341
#   Final footprint for Vertex Plant Beta: 71.6341
#   → Updated. New: 68.0872
#
# --- Iteration 1075 ---
# Checking C4
#
# Calculating footprint for Nimbus Subsidiary
#   Product Nimbus Tonic Water 1L: Assigned footprint 131.2291
#   Product Nimbus Cola 500ml: Assigned footprint 131.2291
#   Final footprint for Nimbus Subsidiary: 131.2291
#
# Calculating footprint for Nimbus Subsidiary
#   Product Nimbus Tonic Water 1L: Assigned footprint 131.2291
#   Product Nimbus Cola 500ml: Assigned footprint 131.2291
#   Final footprint for Nimbus Subsidiary: 131.2291
#
# Calculating footprint for Nimbus Company
#   → No update needed.
# Checking C2
#
# Calculating footprint for Lumina Plant A
#   Product Lumina Sparkling Water 500ml: Assigned footprint 91.8991
#   Final footprint for Lumina Plant A: 91.8991
#
# Calculating footprint for Lumina Plant B
#   Product Lumina Energy Drink 250ml: Assigned footprint 74.9690
#   Final footprint for Lumina Plant B: 74.9690
#
# Calculating footprint for Lumina Plant A
#   Product Lumina Sparkling Water 500ml: Assigned footprint 91.8991
#   Final footprint for Lumina Plant A: 91.8991
#
# Calculating footprint for Lumina Plant B
#   Product Lumina Energy Drink 250ml: Assigned footprint 74.9690
#   Final footprint for Lumina Plant B: 74.9690
#
# Calculating footprint for Lumina Company
#   Product Lumina Brand Management: Assigned footprint 83.5250
#   Final footprint for Lumina Company: 83.5250
#   → No update needed.
# Checking C1
#
# Calculating footprint for Orion Plant A1
#   Product Orion Cola 500ml: Assigned footprint 169.4902
#   Product Orion Diet Cola 500ml: Assigned footprint 169.4902
#   Final footprint for Orion Plant A1: 169.4902
#
# Calculating footprint for Orion Plant A2
#   Product Orion Orange Soda 330ml: Assigned footprint 71.2251
#   Final footprint for Orion Plant A2: 71.2251
#
# Calculating footprint for Orion Plant A1
#   Product Orion Cola 500ml: Assigned footprint 169.4902
#   Product Orion Diet Cola 500ml: Assigned footprint 169.4902
#   Final footprint for Orion Plant A1: 169.4902
#
# Calculating footprint for Orion Plant A2
#   Product Orion Orange Soda 330ml: Assigned footprint 71.2252
#   Final footprint for Orion Plant A2: 71.2252
#
# Calculating footprint for Orion Bottling A
#
# Calculating footprint for Orion Bottling B
#   Product Orion Lemon Soda 1L: Assigned footprint 82.0053
#   Final footprint for Orion Bottling B: 82.0053
#
# Calculating footprint for Orion Plant A1
#   Product Orion Cola 500ml: Assigned footprint 169.4903
#   Product Orion Diet Cola 500ml: Assigned footprint 169.4903
#   Final footprint for Orion Plant A1: 169.4903
#
# Calculating footprint for Orion Plant A2
#   Product Orion Orange Soda 330ml: Assigned footprint 71.2252
#   Final footprint for Orion Plant A2: 71.2252
#
# Calculating footprint for Orion Bottling A
#
# Calculating footprint for Orion Bottling B
#   Product Orion Lemon Soda 1L: Assigned footprint 82.0053
#   Final footprint for Orion Bottling B: 82.0053
#
# Calculating footprint for Orion Company
#   Product Orion Admin Service: Assigned footprint 84.9859
#   Final footprint for Orion Company: 84.9859
#   → No update needed.
# Checking C5
#
# Calculating footprint for Vertex Plant Alpha
#   Product Vertex Iced Tea 500ml: Assigned footprint 71.8914
#   Final footprint for Vertex Plant Alpha: 71.8914
#
# Calculating footprint for Vertex Plant Beta
#   Product Vertex Cola 330ml: Assigned footprint 71.6343
#   Final footprint for Vertex Plant Beta: 71.6343
#
# Calculating footprint for Vertex Plant Alpha
#   Product Vertex Iced Tea 500ml: Assigned footprint 71.8914
#   Final footprint for Vertex Plant Alpha: 71.8914
#
# Calculating footprint for Vertex Plant Beta
#   Product Vertex Cola 330ml: Assigned footprint 71.6343
#   Final footprint for Vertex Plant Beta: 71.6343
#
# Calculating footprint for Vertex Company
#   Product Vertex Admin Service: Assigned footprint 68.0891
#   Final footprint for Vertex Company: 68.0891
#   → Updated. New: 68.0891
# Checking C3
#
# Calculating footprint for Apex Site X
#   Product Apex Ginger Ale 330ml: Assigned footprint 131.7122
#   Product Apex Zero Cola 500ml: Assigned footprint 131.7122
#   Final footprint for Apex Site X: 131.7122
#   → Updated. New: 70.8686
#
# --- Iteration 1076 ---
# Checking C5
#
# Calculating footprint for Vertex Plant Alpha
#   Product Vertex Iced Tea 500ml: Assigned footprint 71.8916
#   Final footprint for Vertex Plant Alpha: 71.8916
#
# Calculating footprint for Vertex Plant Beta
#   Product Vertex Cola 330ml: Assigned footprint 71.6345
#   Final footprint for Vertex Plant Beta: 71.6345
#
# Calculating footprint for Vertex Plant Alpha
#   Product Vertex Iced Tea 500ml: Assigned footprint 71.8916
#   Final footprint for Vertex Plant Alpha: 71.8916
#
# Calculating footprint for Vertex Plant Beta
#   Product Vertex Cola 330ml: Assigned footprint 71.6345
#   Final footprint for Vertex Plant Beta: 71.6345
#
# Calculating footprint for Vertex Company
#   Product Vertex Admin Service: Assigned footprint 68.0893
#   Final footprint for Vertex Company: 68.0893
#   → No update needed.
# Checking C2
#
# Calculating footprint for Lumina Plant A
#   Product Lumina Sparkling Water 500ml: Assigned footprint 91.8996
#   Final footprint for Lumina Plant A: 91.8996
#
# Calculating footprint for Lumina Plant B
#   Product Lumina Energy Drink 250ml: Assigned footprint 74.9695
#   Final footprint for Lumina Plant B: 74.9695
#
# Calculating footprint for Lumina Plant A
#   Product Lumina Sparkling Water 500ml: Assigned footprint 91.8996
#   Final footprint for Lumina Plant A: 91.8996
#
# Calculating footprint for Lumina Plant B
#   Product Lumina Energy Drink 250ml: Assigned footprint 74.9695
#   Final footprint for Lumina Plant B: 74.9695
#
# Calculating footprint for Lumina Company
#   Product Lumina Brand Management: Assigned footprint 83.5254
#   Final footprint for Lumina Company: 83.5254
#   → No update needed.
# Checking C1
#
# Calculating footprint for Orion Plant A1
#   Product Orion Cola 500ml: Assigned footprint 169.4910
#   Product Orion Diet Cola 500ml: Assigned footprint 169.4910
#   Final footprint for Orion Plant A1: 169.4910
#
# Calculating footprint for Orion Plant A2
#   Product Orion Orange Soda 330ml: Assigned footprint 71.2255
#   Final footprint for Orion Plant A2: 71.2255
#
# Calculating footprint for Orion Plant A1
#   Product Orion Cola 500ml: Assigned footprint 169.4910
#   Product Orion Diet Cola 500ml: Assigned footprint 169.4910
#   Final footprint for Orion Plant A1: 169.4910
#
# Calculating footprint for Orion Plant A2
#   Product Orion Orange Soda 330ml: Assigned footprint 71.2256
#   Final footprint for Orion Plant A2: 71.2256
#
# Calculating footprint for Orion Bottling A
#
# Calculating footprint for Orion Bottling B
#   Product Orion Lemon Soda 1L: Assigned footprint 82.0059
#   Final footprint for Orion Bottling B: 82.0059
#
# Calculating footprint for Orion Plant A1
#   Product Orion Cola 500ml: Assigned footprint 169.4910
#   Product Orion Diet Cola 500ml: Assigned footprint 169.4910
#   Final footprint for Orion Plant A1: 169.4910
#
# Calculating footprint for Orion Plant A2
#   Product Orion Orange Soda 330ml: Assigned footprint 71.2256
#   Final footprint for Orion Plant A2: 71.2256
#
# Calculating footprint for Orion Bottling A
#
# Calculating footprint for Orion Bottling B
#   Product Orion Lemon Soda 1L: Assigned footprint 82.0059
#   Final footprint for Orion Bottling B: 82.0059
#
# Calculating footprint for Orion Company
#   Product Orion Admin Service: Assigned footprint 84.9863
#   Final footprint for Orion Company: 84.9863
#   → No update needed.
# Checking C4
#
# Calculating footprint for Nimbus Subsidiary
#   Product Nimbus Tonic Water 1L: Assigned footprint 131.2302
#   Product Nimbus Cola 500ml: Assigned footprint 131.2302
#   Final footprint for Nimbus Subsidiary: 131.2302
#
# Calculating footprint for Nimbus Subsidiary
#   Product Nimbus Tonic Water 1L: Assigned footprint 131.2302
#   Product Nimbus Cola 500ml: Assigned footprint 131.2302
#   Final footprint for Nimbus Subsidiary: 131.2302
#
# Calculating footprint for Nimbus Company
#   → No update needed.
# Checking C3
#
# Calculating footprint for Apex Site X
#   Product Apex Ginger Ale 330ml: Assigned footprint 131.7127
#   Product Apex Zero Cola 500ml: Assigned footprint 131.7127
#   Final footprint for Apex Site X: 131.7127
#
# Calculating footprint for Apex Site X
#   Product Apex Ginger Ale 330ml: Assigned footprint 131.7127
#   Product Apex Zero Cola 500ml: Assigned footprint 131.7127
#   Final footprint for Apex Site X: 131.7127
#
# Calculating footprint for Apex Division 1
#
# Calculating footprint for Apex Site X
#   Product Apex Ginger Ale 330ml: Assigned footprint 131.7127
#   Product Apex Zero Cola 500ml: Assigned footprint 131.7127
#   Final footprint for Apex Site X: 131.7127
#
# Calculating footprint for Apex Division 1
#
# Calculating footprint for Apex Company
#   Product Apex Admin Support: Assigned footprint 70.8698
#   Final footprint for Apex Company: 70.8698
#   → Updated. New: 70.8698
#
# --- Iteration 1077 ---
# Checking C4
#
# Calculating footprint for Nimbus Subsidiary
#   Product Nimbus Tonic Water 1L: Assigned footprint 131.2304
#   Product Nimbus Cola 500ml: Assigned footprint 131.2304
#   Final footprint for Nimbus Subsidiary: 131.2304
#
# Calculating footprint for Nimbus Subsidiary
#   Product Nimbus Tonic Water 1L: Assigned footprint 131.2304
#   Product Nimbus Cola 500ml: Assigned footprint 131.2304
#   Final footprint for Nimbus Subsidiary: 131.2304
#
# Calculating footprint for Nimbus Company
#   → No update needed.
# Checking C1
#
# Calculating footprint for Orion Plant A1
#   Product Orion Cola 500ml: Assigned footprint 169.4916
#   Product Orion Diet Cola 500ml: Assigned footprint 169.4916
#   Final footprint for Orion Plant A1: 169.4916
#
# Calculating footprint for Orion Plant A2
#   Product Orion Orange Soda 330ml: Assigned footprint 71.2258
#   Final footprint for Orion Plant A2: 71.2258
#
# Calculating footprint for Orion Plant A1
#   Product Orion Cola 500ml: Assigned footprint 169.4916
#   Product Orion Diet Cola 500ml: Assigned footprint 169.4916
#   Final footprint for Orion Plant A1: 169.4916
#
# Calculating footprint for Orion Plant A2
#   Product Orion Orange Soda 330ml: Assigned footprint 71.2259
#   Final footprint for Orion Plant A2: 71.2259
#
# Calculating footprint for Orion Bottling A
#
# Calculating footprint for Orion Bottling B
#   Product Orion Lemon Soda 1L: Assigned footprint 82.0061
#   Final footprint for Orion Bottling B: 82.0061
#
# Calculating footprint for Orion Plant A1
#   Product Orion Cola 500ml: Assigned footprint 169.4916
#   Product Orion Diet Cola 500ml: Assigned footprint 169.4916
#   Final footprint for Orion Plant A1: 169.4916
#
# Calculating footprint for Orion Plant A2
#   Product Orion Orange Soda 330ml: Assigned footprint 71.2259
#   Final footprint for Orion Plant A2: 71.2259
#
# Calculating footprint for Orion Bottling A
#
# Calculating footprint for Orion Bottling B
#   Product Orion Lemon Soda 1L: Assigned footprint 82.0062
#   Final footprint for Orion Bottling B: 82.0062
#
# Calculating footprint for Orion Company
#   Product Orion Admin Service: Assigned footprint 84.9866
#   Final footprint for Orion Company: 84.9866
#   → No update needed.
# Checking C3
#
# Calculating footprint for Apex Site X
#   Product Apex Ginger Ale 330ml: Assigned footprint 131.7130
#   Product Apex Zero Cola 500ml: Assigned footprint 131.7130
#   Final footprint for Apex Site X: 131.7130
#
# Calculating footprint for Apex Site X
#   Product Apex Ginger Ale 330ml: Assigned footprint 131.7130
#   Product Apex Zero Cola 500ml: Assigned footprint 131.7130
#   Final footprint for Apex Site X: 131.7130
#
# Calculating footprint for Apex Division 1
#
# Calculating footprint for Apex Site X
#   Product Apex Ginger Ale 330ml: Assigned footprint 131.7130
#   Product Apex Zero Cola 500ml: Assigned footprint 131.7130
#   Final footprint for Apex Site X: 131.7130
#
# Calculating footprint for Apex Division 1
#
# Calculating footprint for Apex Company
#   Product Apex Admin Support: Assigned footprint 70.8699
#   Final footprint for Apex Company: 70.8699
#   → No update needed.
# Checking C2
#
# Calculating footprint for Lumina Plant A
#   Product Lumina Sparkling Water 500ml: Assigned footprint 91.9001
#   Final footprint for Lumina Plant A: 91.9001
#
# Calculating footprint for Lumina Plant B
#   Product Lumina Energy Drink 250ml: Assigned footprint 74.9698
#   Final footprint for Lumina Plant B: 74.9698
#
# Calculating footprint for Lumina Plant A
#   Product Lumina Sparkling Water 500ml: Assigned footprint 91.9001
#   Final footprint for Lumina Plant A: 91.9001
#
# Calculating footprint for Lumina Plant B
#   Product Lumina Energy Drink 250ml: Assigned footprint 74.9699
#   Final footprint for Lumina Plant B: 74.9699
#
# Calculating footprint for Lumina Company
#   Product Lumina Brand Management: Assigned footprint 83.5259
#   Final footprint for Lumina Company: 83.5259
#   → No update needed.
# Checking C5
#
# Calculating footprint for Vertex Plant Alpha
#   Product Vertex Iced Tea 500ml: Assigned footprint 71.8921
#   Final footprint for Vertex Plant Alpha: 71.8921
#
# Calculating footprint for Vertex Plant Beta
#   Product Vertex Cola 330ml: Assigned footprint 71.6350
#   Final footprint for Vertex Plant Beta: 71.6350
#
# Calculating footprint for Vertex Plant Alpha
#   Product Vertex Iced Tea 500ml: Assigned footprint 71.8921
#   Final footprint for Vertex Plant Alpha: 71.8921
#
# Calculating footprint for Vertex Plant Beta
#   Product Vertex Cola 330ml: Assigned footprint 71.6350
#   Final footprint for Vertex Plant Beta: 71.6350
#
# Calculating footprint for Vertex Company
#   Product Vertex Admin Service: Assigned footprint 68.0898
#   Final footprint for Vertex Company: 68.0898
#   → No update needed.
#
# ✅ Updates completed.
# ⏱️ Time taken: 23.93 seconds
#
# 📦 Final Footprints:
# C1: 84.9866 kg CO2e/unit
# C2: 83.5259 kg CO2e/unit
# C3: 70.8699 kg CO2e/unit
# C4: 0.0000 kg CO2e/unit
# C5: 68.0898 kg CO2e/unit
#
# 🔁 Update Count:
# C1: 7 updates
# C2: 24 updates
# C3: 179 updates
# C4: 1 updates
# C5: 30 updates
# Total updates: 241
#
# 🗃️ Final footprint database:
#     id impact_ids      scores
# 0    1        CO2  169.491595
# 1    2        CO2  169.491595
# 2    3        CO2   71.225859
# 3    4        CO2   82.006151
# 4    5        CO2   84.985595
# 5    6        CO2   91.900058
# 6    7        CO2   74.969861
# 7    8        CO2   83.524529
# 8    9        CO2  131.712973
# 9   10        CO2  131.712973
# 10  11        CO2   70.869819
# 11  12        CO2  131.230414
# 12  13        CO2  131.230414
# 13  14        CO2   71.892059
# 14  15        CO2   71.635013
# 15  16        CO2   68.089077
# - Orion Company (latest_update=84.98660357516545)
#     - Orion Bottling A (latest_update=0.0)
#         - Orion Plant A1 (latest_update=169.49159530801882)
#         - Orion Plant A2 (latest_update=71.22585880602341)
#     - Orion Bottling B (latest_update=82.00615083253851)
# - Lumina Company (latest_update=83.52587999864667)
#     - Lumina Plant A (latest_update=91.90005812188556)
#     - Lumina Plant B (latest_update=74.96986079314122)
# - Apex Company (latest_update=70.86993995811058)
#     - Apex Division 1 (latest_update=0.0)
#         - Apex Site X (latest_update=131.71297267032338)
# - Nimbus Company (latest_update=0.0)
#     - Nimbus Subsidiary (latest_update=131.23041443020776)
# - Vertex Company (latest_update=68.08977832446226)
#     - Vertex Plant Alpha (latest_update=71.89205900789305)
#     - Vertex Plant Beta (latest_update=71.63501347506613)

# %%
footprint_db = FootprintDatabase(year=2024)

# Step 5: Register all products (including sub-company products)
for company in system.companies.values():
    for product in company.products:
        footprint_db.report(product.product_id, 0)
    if hasattr(company, "sub_companies"):
        for sub in company.sub_companies:
            for product in sub.products:
                footprint_db.report(product.product_id, 0)

# Step 6: Iterative update loop
updates_completed = False
iteration = 0
start_time = time.time()

for company in system.companies.values():
    company.num_updates = 0

while not updates_completed:
    iteration += 1
    print(f"\n--- Iteration {iteration} ---")
    any_company_updated = False

    for name, company in system.companies.items():
        previous = company.latest_update

        for sub in getattr(company, "sub_companies", []):
            sub.update_footprint(footprint_db)
            sub.report_footprint(footprint_db)

        company.update_footprint(footprint_db)
        new = company.latest_update

        if previous is None or not np.isclose(previous, new, atol=1e-6):
            print(f"  → {name} updated.")
            any_company_updated = True
            company.num_updates += 1
            company.report_footprint(footprint_db)

    updates_completed = not any_company_updated

end_time = time.time()

# Step 7: Summary
print("\n✅ Updates completed.")
print(f"⏱️ Time taken: {end_time - start_time:.2f} seconds")

print("\n📦 Final Footprints:")
for name, company in system.companies.items():
    print(f"{name}: {company.latest_update:.4f} kg CO2e/unit")
    for sub in getattr(company, "sub_companies", []):
        print(f"  {sub.name}: {sub.latest_update:.4f}")

print("\n🔁 Update Count:")
total_updates = sum(c.num_updates for c in system.companies.values())
for name, c in system.companies.items():
    print(f"{name}: {c.num_updates} updates")
print(f"Total updates: {total_updates}")

print("\n🗃️ Final footprint database:")
print(footprint_db.data.sort_values("id"))

# Optional: Additional forced update rounds
for i in range(3):
    print(f"\n--- Forced Update Iteration {i+1} ---")
    for name, company in system.companies.items():
        company.update_footprint(footprint_db)
        company.report_footprint(footprint_db)

print("\n🗃️ Final footprint database after forced iterations:")
print(footprint_db.data.sort_values("id"))

# %%
print("\n🔍 Carbon balance check:")

for name, company in system.companies.items():
    print(f"\n--- Balance check for {name} ---")

    # 1) Embodied impacts of purchases
    scores = footprint_db.data.set_index("id")["scores"].astype(float)
    in_emb = float(scores.loc[company.purchases.index].dot(company.purchases))

    # 2) Direct emissions
    in_direct = float(company.direct_impacts.sum().sum())

    # 3) Total carbon in
    carbon_in = in_emb + in_direct

    # 4) Carbon out (embodied in products sold)
    out_emb = 0
    for product in company.products:
        if product.product_id in company.sales.index:
            out_emb += float(product.footprint * company.sales.loc[product.product_id, "Sales"])

    # 5) Print check
    balanced = np.isclose(carbon_in, out_emb, atol=1e-6)

    print(f"  Purchases embodied (in_emb):     {in_emb:.6f}")
    print(f"  Direct emissions   (in_direct):  {in_direct:.6f}")
    print(f"  Total carbon in    (carbon_in):  {carbon_in:.6f}")
    print(f"  Sales embodied out (out_emb):    {out_emb:.6f}")
    print(f"  Balance?                         {balanced}")

    # Sub-companies
    if hasattr(company, "sub_companies"):
        for sub in company.sub_companies:
            print(f"\n  --- Sub-entity: {sub.name} ---")
            in_emb = float(scores.loc[sub.purchases.index].dot(sub.purchases)) if not sub.purchases.empty else 0
            in_direct = float(sub.direct_impacts.sum().sum())
            carbon_in = in_emb + in_direct

            out_emb = 0
            for product in sub.products:
                if product.product_id in sub.sales.index:
                    out_emb += float(product.footprint * sub.sales.loc[product.product_id, "Sales"])

            balanced = np.isclose(carbon_in, out_emb, rtol=1e-4)

            print(f"    Purchases embodied (in_emb):     {in_emb:.6f}")
            print(f"    Direct emissions   (in_direct):  {in_direct:.6f}")
            print(f"    Total carbon in    (carbon_in):  {carbon_in:.6f}")
            print(f"    Sales embodied out (out_emb):    {out_emb:.6f}")
            print(f"    Balance?                         {balanced}")
# Out:
# 🔍 Carbon balance check:
#
# --- Balance check for Company_1 ---
#   Purchases embodied (in_emb):     453.757772
#   Direct emissions   (in_direct):  418.000000
#   Total carbon in    (carbon_in):  871.757772
#   Sales embodied out (out_emb):    871.756988
#   Balance?                         True
#
#   --- Sub-entity: Company 1_Sub_1 ---
#     Purchases embodied (in_emb):     54.277301
#     Direct emissions   (in_direct):  0.000000
#     Total carbon in    (carbon_in):  54.277301
#     Sales embodied out (out_emb):    54.276601
#     Balance?                         True
#
#   --- Sub-entity: Company 1_Sub_2 ---
#     Purchases embodied (in_emb):     104.398865
#     Direct emissions   (in_direct):  0.000000
#     Total carbon in    (carbon_in):  104.398865
#     Sales embodied out (out_emb):    104.397549
#     Balance?                         True
#
# --- Balance check for Company_2 ---
#   Purchases embodied (in_emb):     448.933991
#   Direct emissions   (in_direct):  430.000000
#   Total carbon in    (carbon_in):  878.933991
#   Sales embodied out (out_emb):    878.933343
#   Balance?                         True
#
# --- Balance check for Company_3 ---
#   Purchases embodied (in_emb):     483.725877
#   Direct emissions   (in_direct):  79.000000
#   Total carbon in    (carbon_in):  562.725877
#   Sales embodied out (out_emb):    562.725333
#   Balance?                         True
#
#   --- Sub-entity: Company 3_Sub_1 ---
#     Purchases embodied (in_emb):     242.061927
#     Direct emissions   (in_direct):  0.000000
#     Total carbon in    (carbon_in):  242.061927
#     Sales embodied out (out_emb):    242.058605
#     Balance?                         True
#
#   --- Sub-entity: Company 3_Sub_2 ---
#     Purchases embodied (in_emb):     246.780862
#     Direct emissions   (in_direct):  0.000000
#     Total carbon in    (carbon_in):  246.780862
#     Sales embodied out (out_emb):    246.777799
#     Balance?                         True
#
# --- Balance check for Company_4 ---
#   Purchases embodied (in_emb):     475.303333
#   Direct emissions   (in_direct):  183.000000
#   Total carbon in    (carbon_in):  658.303333
#   Sales embodied out (out_emb):    658.302891
#   Balance?                         True
#
# --- Balance check for Company_5 ---
#   Purchases embodied (in_emb):     480.023771
#   Direct emissions   (in_direct):  159.000000
#   Total carbon in    (carbon_in):  639.023771
#   Sales embodied out (out_emb):    639.023416
#   Balance?                         True
#
# --- Balance check for Company_6 ---
#   Purchases embodied (in_emb):     485.825146
#   Direct emissions   (in_direct):  8.000000
#   Total carbon in    (carbon_in):  493.825146
#   Sales embodied out (out_emb):    493.824876
#   Balance?                         True
#
# --- Balance check for Company_7 ---
#   Purchases embodied (in_emb):     453.065966
#   Direct emissions   (in_direct):  503.000000
#   Total carbon in    (carbon_in):  956.065966
#   Sales embodied out (out_emb):    956.065773
#   Balance?                         True
#
# --- Balance check for Company_8 ---
#   Purchases embodied (in_emb):     456.706780
#   Direct emissions   (in_direct):  595.000000
#   Total carbon in    (carbon_in):  1051.706780
#   Sales embodied out (out_emb):    1051.706650
#   Balance?                         True
#
# --- Balance check for Company_9 ---
#   Purchases embodied (in_emb):     470.895579
#   Direct emissions   (in_direct):  257.000000
#   Total carbon in    (carbon_in):  727.895579
#   Sales embodied out (out_emb):    727.895511
#   Balance?                         True
#
# --- Balance check for Company_10 ---
#   Purchases embodied (in_emb):     464.852122
#   Direct emissions   (in_direct):  219.000000
#   Total carbon in    (carbon_in):  683.852122
#   Sales embodied out (out_emb):    683.852122
#   Balance?                         True

# %%
# simulate_hierarchy.ipynb (content for a new Jupyter notebook)

import random
import time
import numpy as np
import pandas as pd
from SSELF_base import FootprintDatabase
from hierarchy_extension import HierarchicalSystem, HierarchicalCompany, Product

# Step 1: Define parameters
num_companies = 10
base_products = num_companies  # One product per company by default
companies_with_subs = ["Company_1", "Company_3"]
num_subs_per_company = 2


# ✅ Just use base_products:
system = HierarchicalSystem(num_companies=num_companies, num_products=base_products)

# Corrected starting ID (start right after base products)
starting_id = base_products + 1

# Step 3: Add hierarchies
system.add_hierarchies(
    target_company_names=companies_with_subs,
    num_subs_per_hierarchical=num_subs_per_company,
    starting_id=starting_id
)

# Step 3: Add hierarchies with sub-companies and dynamic product IDs
system.add_hierarchies(
    target_company_names=companies_with_subs,
    num_subs_per_hierarchical=num_subs_per_company,
    starting_id = total_products + 1

)

# Step 4: Initialize footprint DB
footprint_db = FootprintDatabase(year=2024)

# ✅ Step 5: Register all products (including sub-company products)
for company in system.companies.values():
    for product in company.products:
        footprint_db.report(product.product_id, 0)
    if hasattr(company, "sub_companies"):
        for sub in company.sub_companies:
            for product in sub.products:
                footprint_db.report(product.product_id, 0)

# Step 6: Iterative update loop
updates_completed = False
iteration = 0
start_time = time.time()

for company in system.companies.values():
    company.num_updates = 0

while not updates_completed:
    iteration += 1
    print(f"\n--- Iteration {iteration} ---")
    any_company_updated = False

    for name, company in system.companies.items():
        previous = company.latest_update

        for sub in getattr(company, "sub_companies", []):
            sub.update_footprint(footprint_db)
            sub.report_footprint(footprint_db)

        company.update_footprint(footprint_db)
        new = company.latest_update

        if previous is None or not np.isclose(previous, new, atol=1e-6):
            print(f"  → {name} updated.")
            any_company_updated = True
            company.num_updates += 1
            company.report_footprint(footprint_db)

    updates_completed = not any_company_updated

end_time = time.time()

# Step 7: Summary
print("\n✅ Updates completed.")
print(f"⏱️ Time taken: {end_time - start_time:.2f} seconds")

print("\n📦 Final Footprints:")
for name, company in system.companies.items():
    print(f"{name}: {company.latest_update:.4f} kg CO2e/unit")
    for sub in getattr(company, "sub_companies", []):
        print(f"  {sub.name}: {sub.latest_update:.4f}")

print("\n🔁 Update Count:")
total_updates = sum(c.num_updates for c in system.companies.values())
for name, c in system.companies.items():
    print(f"{name}: {c.num_updates} updates")
print(f"Total updates: {total_updates}")

print("\n🗃️ Final footprint database:")
print(footprint_db.data.sort_values("id"))

# Optional: Additional forced update rounds
for i in range(3):
    print(f"\n--- Forced Update Iteration {i+1} ---")
    for name, company in system.companies.items():
        company.update_footprint(footprint_db)
        company.report_footprint(footprint_db)

print("\n🗃️ Final footprint database after forced iterations:")
print(footprint_db.data.sort_values("id"))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 34
#      24 system.add_hierarchies(
#      25     target_company_names=companies_with_subs,
#      26     num_subs_per_hierarchical=num_subs_per_company,
#      27     starting_id=starting_id
#      28 )
#      30 # Step 3: Add hierarchies with sub-companies and dynamic product IDs
#      31 system.add_hierarchies(
#      32     target_company_names=companies_with_subs,
#      33     num_subs_per_hierarchical=num_subs_per_company,
# ---> 34     starting_id = total_products + 1
#      35
#      36 )
#      38 # Step 4: Initialize footprint DB
#      39 footprint_db = FootprintDatabase(year=2024)
#
# NameError: name 'total_products' is not defined

# %%
#Testing without hierarchy to make sure the base works
import time
import random
import numpy as np

# Step 1: Initialize footprint database with 0 values
for company in system.companies.values():
    for product in company.products:
        footprint_db_2024.report(product.product_id, 0)

# Step 2: Iterative update loop
updates_completed = False
iteration = 0

for company in system.companies.values():
    company.num_updates = 0  # Track how many times each company updated

start_time = time.time()

while not updates_completed:
    iteration += 1
    print(f"\n--- Iteration {iteration} ---")

    companies_to_check = list(system.companies.keys())
    companies_not_checked = companies_to_check[:]
    any_company_updated = False

    while companies_not_checked:
        random_company_name = random.choice(companies_not_checked)
        company = system.companies[random_company_name]

        print(f"Checking {random_company_name}")

        # Use existing footprint to recalculate and compare
        previous = company.latest_update
        company.update_footprint(footprint_db_2024)
        new = company.latest_update

        if previous is None or not np.isclose(previous, new, atol=1e-6):
            print(f"  -> Updated. Previous: {previous}, New: {new}")
            any_company_updated = True
            company.num_updates += 1
            company.report_footprint(footprint_db_2024)
        else:
            print("  -> No update needed.")

        companies_not_checked.remove(random_company_name)

    updates_completed = not any_company_updated

end_time = time.time()

# Step 3: Summary
print("\n✅ Updates completed.")
print(f"⏱️ Time taken: {end_time - start_time:.2f} seconds")

print("\n📦 Final Footprints:")
for name, company in system.companies.items():
    print(f"{name}: {company.latest_update:.4f} kg CO2e/unit")

print("\n🔁 Update Count:")
total_updates = sum(company.num_updates for company in system.companies.values())
for name, company in system.companies.items():
    print(f"{name}: {company.num_updates} updates")
print(f"Total updates: {total_updates}")

# Optional: Additional forced update rounds
for i in range(3):
    print(f"\n--- Forced Update Iteration {i+1} ---")
    for name, company in system.companies.items():
        company.update_footprint(footprint_db_2024)
        company.report_footprint(footprint_db_2024)
# Out:
# --- Iteration 1 ---
# Checking Company_7
#
# Calculating footprint for Company 7
#   Product Product 7: Assigned footprint 32.5362
#   Final footprint for Company 7: 32.5362
#   -> Updated. Previous: 42.10108551239506, New: 32.536193065042376
# Checking Company_4
#
# Calculating footprint for Company 4
#   Product Product 4: Assigned footprint 29.4908
#   Final footprint for Company 4: 29.4908
#   -> Updated. Previous: 26.713881665959896, New: 29.49077627107289
# Checking Company_6
#
# Calculating footprint for Company 6
#   Product Product 6: Assigned footprint 50.2686
#   Final footprint for Company 6: 50.2686
#   -> Updated. Previous: 50.45252366948336, New: 50.26864666049353
# Checking Company_9
#
# Calculating footprint for Company 9
#   Product Product 9: Assigned footprint 14.3162
#   Final footprint for Company 9: 14.3162
#   -> Updated. Previous: 18.846184889401027, New: 14.316245929330478
# Checking Company_10
#
# Calculating footprint for Company 10
#   Product Product 10: Assigned footprint 44.3074
#   Final footprint for Company 10: 44.3074
#   -> Updated. Previous: 49.15689331674786, New: 44.30735312957776
# Checking Company_3
#
# Calculating footprint for Company 3
#   Product Product 3: Assigned footprint 22.7498
#   Final footprint for Company 3: 22.7498
#   -> Updated. Previous: 11.677047033482674, New: 22.749840213036634
# Checking Company_1
#
# Calculating footprint for Company 1
#   Product Product 1: Assigned footprint 18.3382
#   Final footprint for Company 1: 18.3382
#   -> Updated. Previous: 3.2681634888026165, New: 18.338214330221263
# Checking Company_5
#
# Calculating footprint for Company 5
#   Product Product 5: Assigned footprint 19.4558
#   Final footprint for Company 5: 19.4558
#   -> Updated. Previous: 6.485648861995102, New: 19.45583195518785
# Checking Company_8
#
# Calculating footprint for Company 8
#   Product Product 8: Assigned footprint 35.3395
#   Final footprint for Company 8: 35.3395
#   -> Updated. Previous: 29.701637543035446, New: 35.3395129456332
# Checking Company_2
#
# Calculating footprint for Company 2
#   Product Product 2: Assigned footprint 30.6540
#   Final footprint for Company 2: 30.6540
#   -> Updated. Previous: 13.886976874347859, New: 30.653951811435245
#
# --- Iteration 2 ---
# Checking Company_10
#
# Calculating footprint for Company 10
#   Product Product 10: Assigned footprint 52.0768
#   Final footprint for Company 10: 52.0768
#   -> Updated. Previous: 44.30735312957776, New: 52.0768139740766
# Checking Company_8
#
# Calculating footprint for Company 8
#   Product Product 8: Assigned footprint 38.2505
#   Final footprint for Company 8: 38.2505
#   -> Updated. Previous: 35.3395129456332, New: 38.250492794727876
# Checking Company_4
#
# Calculating footprint for Company 4
#   Product Product 4: Assigned footprint 50.4957
#   Final footprint for Company 4: 50.4957
#   -> Updated. Previous: 29.49077627107289, New: 50.49574247900099
# Checking Company_7
#
# Calculating footprint for Company 7
#   Product Product 7: Assigned footprint 57.2176
#   Final footprint for Company 7: 57.2176
#   -> Updated. Previous: 32.536193065042376, New: 57.21758162536697
# Checking Company_1
#
# Calculating footprint for Company 1
#   Product Product 1: Assigned footprint 29.3734
#   Final footprint for Company 1: 29.3734
#   -> Updated. Previous: 18.338214330221263, New: 29.373408962794315
# Checking Company_3
#
# Calculating footprint for Company 3
#   Product Product 3: Assigned footprint 35.0775
#   Final footprint for Company 3: 35.0775
#   -> Updated. Previous: 22.749840213036634, New: 35.077465793929086
# Checking Company_9
#
# Calculating footprint for Company 9
#   Product Product 9: Assigned footprint 29.5621
#   Final footprint for Company 9: 29.5621
#   -> Updated. Previous: 14.316245929330478, New: 29.56210409955328
# Checking Company_6
#
# Calculating footprint for Company 6
#   Product Product 6: Assigned footprint 71.1611
#   Final footprint for Company 6: 71.1611
#   -> Updated. Previous: 50.26864666049353, New: 71.16110284322046
# Checking Company_2
#
# Calculating footprint for Company 2
#   Product Product 2: Assigned footprint 38.0259
#   Final footprint for Company 2: 38.0259
#   -> Updated. Previous: 30.653951811435245, New: 38.025871009644696
# Checking Company_5
#
# Calculating footprint for Company 5
#   Product Product 5: Assigned footprint 35.3934
#   Final footprint for Company 5: 35.3934
#   -> Updated. Previous: 19.45583195518785, New: 35.39338908740099
#
# --- Iteration 3 ---
# Checking Company_1
#
# Calculating footprint for Company 1
#   Product Product 1: Assigned footprint 34.9585
#   Final footprint for Company 1: 34.9585
#   -> Updated. Previous: 29.373408962794315, New: 34.95849931585335
# Checking Company_9
#
# Calculating footprint for Company 9
#   Product Product 9: Assigned footprint 32.5913
#   Final footprint for Company 9: 32.5913
#   -> Updated. Previous: 29.56210409955328, New: 32.59132867912265
# Checking Company_8
#
# Calculating footprint for Company 8
#   Product Product 8: Assigned footprint 48.6381
#   Final footprint for Company 8: 48.6381
#   -> Updated. Previous: 38.250492794727876, New: 48.63812229754053
# Checking Company_3
#
# Calculating footprint for Company 3
#   Product Product 3: Assigned footprint 40.7268
#   Final footprint for Company 3: 40.7268
#   -> Updated. Previous: 35.077465793929086, New: 40.72675476925913
# Checking Company_4
#
# Calculating footprint for Company 4
#   Product Product 4: Assigned footprint 61.7739
#   Final footprint for Company 4: 61.7739
#   -> Updated. Previous: 50.49574247900099, New: 61.77388524510757
# Checking Company_2
#
# Calculating footprint for Company 2
#   Product Product 2: Assigned footprint 41.3258
#   Final footprint for Company 2: 41.3258
#   -> Updated. Previous: 38.025871009644696, New: 41.32582502902067
# Checking Company_10
#
# Calculating footprint for Company 10
#   Product Product 10: Assigned footprint 62.5540
#   Final footprint for Company 10: 62.5540
#   -> Updated. Previous: 52.0768139740766, New: 62.5540336968692
# Checking Company_7
#
# Calculating footprint for Company 7
#   Product Product 7: Assigned footprint 68.2447
#   Final footprint for Company 7: 68.2447
#   -> Updated. Previous: 57.21758162536697, New: 68.2447016477119
# Checking Company_6
#
# Calculating footprint for Company 6
#   Product Product 6: Assigned footprint 77.4290
#   Final footprint for Company 6: 77.4290
#   -> Updated. Previous: 71.16110284322046, New: 77.42900519189821
# Checking Company_5
#
# Calculating footprint for Company 5
#   Product Product 5: Assigned footprint 41.0364
#   Final footprint for Company 5: 41.0364
#   -> Updated. Previous: 35.39338908740099, New: 41.03637743782417
#
# --- Iteration 4 ---
# Checking Company_6
#
# Calculating footprint for Company 6
#   Product Product 6: Assigned footprint 77.8499
#   Final footprint for Company 6: 77.8499
#   -> Updated. Previous: 77.42900519189821, New: 77.84985687944433
# Checking Company_4
#
# Calculating footprint for Company 4
#   Product Product 4: Assigned footprint 64.9434
#   Final footprint for Company 4: 64.9434
#   -> Updated. Previous: 61.77388524510757, New: 64.94336663579419
# Checking Company_7
#
# Calculating footprint for Company 7
#   Product Product 7: Assigned footprint 69.5346
#   Final footprint for Company 7: 69.5346
#   -> Updated. Previous: 68.2447016477119, New: 69.53460141641717
# Checking Company_8
#
# Calculating footprint for Company 8
#   Product Product 8: Assigned footprint 53.0718
#   Final footprint for Company 8: 53.0718
#   -> Updated. Previous: 48.63812229754053, New: 53.071847011881836
# Checking Company_1
#
# Calculating footprint for Company 1
#   Product Product 1: Assigned footprint 40.9014
#   Final footprint for Company 1: 40.9014
#   -> Updated. Previous: 34.95849931585335, New: 40.90137665894533
# Checking Company_3
#
# Calculating footprint for Company 3
#   Product Product 3: Assigned footprint 45.2815
#   Final footprint for Company 3: 45.2815
#   -> Updated. Previous: 40.72675476925913, New: 45.281498556357974
# Checking Company_10
#
# Calculating footprint for Company 10
#   Product Product 10: Assigned footprint 65.1789
#   Final footprint for Company 10: 65.1789
#   -> Updated. Previous: 62.5540336968692, New: 65.17888128350288
# Checking Company_2
#
# Calculating footprint for Company 2
#   Product Product 2: Assigned footprint 44.8793
#   Final footprint for Company 2: 44.8793
#   -> Updated. Previous: 41.32582502902067, New: 44.87930095926999
# Checking Company_9
#
# Calculating footprint for Company 9
#   Product Product 9: Assigned footprint 38.0685
#   Final footprint for Company 9: 38.0685
#   -> Updated. Previous: 32.59132867912265, New: 38.068483749371985
# Checking Company_5
#
# Calculating footprint for Company 5
#   Product Product 5: Assigned footprint 43.6866
#   Final footprint for Company 5: 43.6866
#   -> Updated. Previous: 41.03637743782417, New: 43.68658744896404
#
# --- Iteration 5 ---
# Checking Company_2
#
# Calculating footprint for Company 2
#   Product Product 2: Assigned footprint 45.3964
#   Final footprint for Company 2: 45.3964
#   -> Updated. Previous: 44.87930095926999, New: 45.39639208758941
# Checking Company_3
#
# Calculating footprint for Company 3
#   Product Product 3: Assigned footprint 46.3489
#   Final footprint for Company 3: 46.3489
#   -> Updated. Previous: 45.281498556357974, New: 46.348910268664675
# Checking Company_1
#
# Calculating footprint for Company 1
#   Product Product 1: Assigned footprint 42.4923
#   Final footprint for Company 1: 42.4923
#   -> Updated. Previous: 40.90137665894533, New: 42.49226691695815
# Checking Company_10
#
# Calculating footprint for Company 10
#   Product Product 10: Assigned footprint 66.0911
#   Final footprint for Company 10: 66.0911
#   -> Updated. Previous: 65.17888128350288, New: 66.09106198012132
# Checking Company_4
#
# Calculating footprint for Company 4
#   Product Product 4: Assigned footprint 67.8976
#   Final footprint for Company 4: 67.8976
#   -> Updated. Previous: 64.94336663579419, New: 67.89764098345614
# Checking Company_6
#
# Calculating footprint for Company 6
#   Product Product 6: Assigned footprint 80.8881
#   Final footprint for Company 6: 80.8881
#   -> Updated. Previous: 77.84985687944433, New: 80.88809938149473
# Checking Company_7
#
# Calculating footprint for Company 7
#   Product Product 7: Assigned footprint 72.8063
#   Final footprint for Company 7: 72.8063
#   -> Updated. Previous: 69.53460141641717, New: 72.80628830290883
# Checking Company_9
#
# Calculating footprint for Company 9
#   Product Product 9: Assigned footprint 39.0421
#   Final footprint for Company 9: 39.0421
#   -> Updated. Previous: 38.068483749371985, New: 39.04210320270368
# Checking Company_8
#
# Calculating footprint for Company 8
#   Product Product 8: Assigned footprint 56.0363
#   Final footprint for Company 8: 56.0363
#   -> Updated. Previous: 53.071847011881836, New: 56.03626034453862
# Checking Company_5
#
# Calculating footprint for Company 5
#   Product Product 5: Assigned footprint 45.1428
#   Final footprint for Company 5: 45.1428
#   -> Updated. Previous: 43.68658744896404, New: 45.14276519028635
#
# --- Iteration 6 ---
# Checking Company_6
#
# Calculating footprint for Company 6
#   Product Product 6: Assigned footprint 81.5344
#   Final footprint for Company 6: 81.5344
#   -> Updated. Previous: 80.88809938149473, New: 81.53439835009476
# Checking Company_7
#
# Calculating footprint for Company 7
#   Product Product 7: Assigned footprint 73.3089
#   Final footprint for Company 7: 73.3089
#   -> Updated. Previous: 72.80628830290883, New: 73.30893583019828
# Checking Company_4
#
# Calculating footprint for Company 4
#   Product Product 4: Assigned footprint 68.9946
#   Final footprint for Company 4: 68.9946
#   -> Updated. Previous: 67.89764098345614, New: 68.99462446411316
# Checking Company_5
#
# Calculating footprint for Company 5
#   Product Product 5: Assigned footprint 45.3319
#   Final footprint for Company 5: 45.3319
#   -> Updated. Previous: 45.14276519028635, New: 45.33192129902138
# Checking Company_8
#
# Calculating footprint for Company 8
#   Product Product 8: Assigned footprint 56.3311
#   Final footprint for Company 8: 56.3311
#   -> Updated. Previous: 56.03626034453862, New: 56.331064730817026
# Checking Company_9
#
# Calculating footprint for Company 9
#   Product Product 9: Assigned footprint 39.4772
#   Final footprint for Company 9: 39.4772
#   -> Updated. Previous: 39.04210320270368, New: 39.477164654594695
# Checking Company_3
#
# Calculating footprint for Company 3
#   Product Product 3: Assigned footprint 47.8126
#   Final footprint for Company 3: 47.8126
#   -> Updated. Previous: 46.348910268664675, New: 47.81264901906136
# Checking Company_1
#
# Calculating footprint for Company 1
#   Product Product 1: Assigned footprint 44.0640
#   Final footprint for Company 1: 44.0640
#   -> Updated. Previous: 42.49226691695815, New: 44.06404234097891
# Checking Company_10
#
# Calculating footprint for Company 10
#   Product Product 10: Assigned footprint 67.3718
#   Final footprint for Company 10: 67.3718
#   -> Updated. Previous: 66.09106198012132, New: 67.37180835753365
# Checking Company_2
#
# Calculating footprint for Company 2
#   Product Product 2: Assigned footprint 47.0322
#   Final footprint for Company 2: 47.0322
#   -> Updated. Previous: 45.39639208758941, New: 47.032158335160794
#
# --- Iteration 7 ---
# Checking Company_1
#
# Calculating footprint for Company 1
#   Product Product 1: Assigned footprint 44.2910
#   Final footprint for Company 1: 44.2910
#   -> Updated. Previous: 44.06404234097891, New: 44.29098615230279
# Checking Company_10
#
# Calculating footprint for Company 10
#   Product Product 10: Assigned footprint 67.4862
#   Final footprint for Company 10: 67.4862
#   -> Updated. Previous: 67.37180835753365, New: 67.4861797484601
# Checking Company_5
#
# Calculating footprint for Company 5
#   Product Product 5: Assigned footprint 45.9234
#   Final footprint for Company 5: 45.9234
#   -> Updated. Previous: 45.33192129902138, New: 45.92342801547771
# Checking Company_3
#
# Calculating footprint for Company 3
#   Product Product 3: Assigned footprint 48.2030
#   Final footprint for Company 3: 48.2030
#   -> Updated. Previous: 47.81264901906136, New: 48.20303168546884
# Checking Company_6
#
# Calculating footprint for Company 6
#   Product Product 6: Assigned footprint 82.2648
#   Final footprint for Company 6: 82.2648
#   -> Updated. Previous: 81.53439835009476, New: 82.2648221071356
# Checking Company_8
#
# Calculating footprint for Company 8
#   Product Product 8: Assigned footprint 56.9705
#   Final footprint for Company 8: 56.9705
#   -> Updated. Previous: 56.331064730817026, New: 56.97053827616461
# Checking Company_7
#
# Calculating footprint for Company 7
#   Product Product 7: Assigned footprint 74.1961
#   Final footprint for Company 7: 74.1961
#   -> Updated. Previous: 73.30893583019828, New: 74.19607833106924
# Checking Company_9
#
# Calculating footprint for Company 9
#   Product Product 9: Assigned footprint 40.0571
#   Final footprint for Company 9: 40.0571
#   -> Updated. Previous: 39.477164654594695, New: 40.05714290030591
# Checking Company_2
#
# Calculating footprint for Company 2
#   Product Product 2: Assigned footprint 47.2968
#   Final footprint for Company 2: 47.2968
#   -> Updated. Previous: 47.032158335160794, New: 47.2968461145796
# Checking Company_4
#
# Calculating footprint for Company 4
#   Product Product 4: Assigned footprint 69.9587
#   Final footprint for Company 4: 69.9587
#   -> Updated. Previous: 68.99462446411316, New: 69.95871045867756
#
# --- Iteration 8 ---
# Checking Company_3
#
# Calculating footprint for Company 3
#   Product Product 3: Assigned footprint 48.4958
#   Final footprint for Company 3: 48.4958
#   -> Updated. Previous: 48.20303168546884, New: 48.495815757800166
# Checking Company_8
#
# Calculating footprint for Company 8
#   Product Product 8: Assigned footprint 57.1970
#   Final footprint for Company 8: 57.1970
#   -> Updated. Previous: 56.97053827616461, New: 57.196962285849736
# Checking Company_10
#
# Calculating footprint for Company 10
#   Product Product 10: Assigned footprint 67.8280
#   Final footprint for Company 10: 67.8280
#   -> Updated. Previous: 67.4861797484601, New: 67.827989719337
# Checking Company_6
#
# Calculating footprint for Company 6
#   Product Product 6: Assigned footprint 82.5778
#   Final footprint for Company 6: 82.5778
#   -> Updated. Previous: 82.2648221071356, New: 82.57778681130026
# Checking Company_5
#
# Calculating footprint for Company 5
#   Product Product 5: Assigned footprint 46.3976
#   Final footprint for Company 5: 46.3976
#   -> Updated. Previous: 45.92342801547771, New: 46.397609600576175
# Checking Company_9
#
# Calculating footprint for Company 9
#   Product Product 9: Assigned footprint 40.2322
#   Final footprint for Company 9: 40.2322
#   -> Updated. Previous: 40.05714290030591, New: 40.232186338406834
# Checking Company_2
#
# Calculating footprint for Company 2
#   Product Product 2: Assigned footprint 47.4742
#   Final footprint for Company 2: 47.4742
#   -> Updated. Previous: 47.2968461145796, New: 47.47418340268552
# Checking Company_1
#
# Calculating footprint for Company 1
#   Product Product 1: Assigned footprint 44.8483
#   Final footprint for Company 1: 44.8483
#   -> Updated. Previous: 44.29098615230279, New: 44.848332346923904
# Checking Company_4
#
# Calculating footprint for Company 4
#   Product Product 4: Assigned footprint 70.1770
#   Final footprint for Company 4: 70.1770
#   -> Updated. Previous: 69.95871045867756, New: 70.1770210162295
# Checking Company_7
#
# Calculating footprint for Company 7
#   Product Product 7: Assigned footprint 74.5776
#   Final footprint for Company 7: 74.5776
#   -> Updated. Previous: 74.19607833106924, New: 74.57760504037886
#
# --- Iteration 9 ---
# Checking Company_10
#
# Calculating footprint for Company 10
#   Product Product 10: Assigned footprint 67.9690
#   Final footprint for Company 10: 67.9690
#   -> Updated. Previous: 67.827989719337, New: 67.96900896736757
# Checking Company_5
#
# Calculating footprint for Company 5
#   Product Product 5: Assigned footprint 46.5366
#   Final footprint for Company 5: 46.5366
#   -> Updated. Previous: 46.397609600576175, New: 46.536624593520614
# Checking Company_2
#
# Calculating footprint for Company 2
#   Product Product 2: Assigned footprint 47.5656
#   Final footprint for Company 2: 47.5656
#   -> Updated. Previous: 47.47418340268552, New: 47.56562417296743
# Checking Company_9
#
# Calculating footprint for Company 9
#   Product Product 9: Assigned footprint 40.3360
#   Final footprint for Company 9: 40.3360
#   -> Updated. Previous: 40.232186338406834, New: 40.33598536059946
# Checking Company_6
#
# Calculating footprint for Company 6
#   Product Product 6: Assigned footprint 82.7612
#   Final footprint for Company 6: 82.7612
#   -> Updated. Previous: 82.57778681130026, New: 82.76117946974632
# Checking Company_1
#
# Calculating footprint for Company 1
#   Product Product 1: Assigned footprint 44.9463
#   Final footprint for Company 1: 44.9463
#   -> Updated. Previous: 44.848332346923904, New: 44.946260839507815
# Checking Company_8
#
# Calculating footprint for Company 8
#   Product Product 8: Assigned footprint 57.4542
#   Final footprint for Company 8: 57.4542
#   -> Updated. Previous: 57.196962285849736, New: 57.454178199477646
# Checking Company_3
#
# Calculating footprint for Company 3
#   Product Product 3: Assigned footprint 48.7751
#   Final footprint for Company 3: 48.7751
#   -> Updated. Previous: 48.495815757800166, New: 48.775131053960045
# Checking Company_4
#
# Calculating footprint for Company 4
#   Product Product 4: Assigned footprint 70.3199
#   Final footprint for Company 4: 70.3199
#   -> Updated. Previous: 70.1770210162295, New: 70.31994908281251
# Checking Company_7
#
# Calculating footprint for Company 7
#   Product Product 7: Assigned footprint 74.6971
#   Final footprint for Company 7: 74.6971
#   -> Updated. Previous: 74.57760504037886, New: 74.69710310991886
#
# --- Iteration 10 ---
# Checking Company_3
#
# Calculating footprint for Company 3
#   Product Product 3: Assigned footprint 48.7940
#   Final footprint for Company 3: 48.7940
#   -> Updated. Previous: 48.775131053960045, New: 48.79402877331363
# Checking Company_1
#
# Calculating footprint for Company 1
#   Product Product 1: Assigned footprint 45.0099
#   Final footprint for Company 1: 45.0099
#   -> Updated. Previous: 44.946260839507815, New: 45.00990093625612
# Checking Company_9
#
# Calculating footprint for Company 9
#   Product Product 9: Assigned footprint 40.4067
#   Final footprint for Company 9: 40.4067
#   -> Updated. Previous: 40.33598536059946, New: 40.406735358374156
# Checking Company_2
#
# Calculating footprint for Company 2
#   Product Product 2: Assigned footprint 47.6507
#   Final footprint for Company 2: 47.6507
#   -> Updated. Previous: 47.56562417296743, New: 47.65071198951021
# Checking Company_6
#
# Calculating footprint for Company 6
#   Product Product 6: Assigned footprint 82.8458
#   Final footprint for Company 6: 82.8458
#   -> Updated. Previous: 82.76117946974632, New: 82.84584679055745
# Checking Company_10
#
# Calculating footprint for Company 10
#   Product Product 10: Assigned footprint 68.0757
#   Final footprint for Company 10: 68.0757
#   -> Updated. Previous: 67.96900896736757, New: 68.07569707469132
# Checking Company_5
#
# Calculating footprint for Company 5
#   Product Product 5: Assigned footprint 46.6802
#   Final footprint for Company 5: 46.6802
#   -> Updated. Previous: 46.536624593520614, New: 46.68024364418258
# Checking Company_4
#
# Calculating footprint for Company 4
#   Product Product 4: Assigned footprint 70.3791
#   Final footprint for Company 4: 70.3791
#   -> Updated. Previous: 70.31994908281251, New: 70.37908219546354
# Checking Company_7
#
# Calculating footprint for Company 7
#   Product Product 7: Assigned footprint 74.7497
#   Final footprint for Company 7: 74.7497
#   -> Updated. Previous: 74.69710310991886, New: 74.74973379078094
# Checking Company_8
#
# Calculating footprint for Company 8
#   Product Product 8: Assigned footprint 57.5471
#   Final footprint for Company 8: 57.5471
#   -> Updated. Previous: 57.454178199477646, New: 57.54712546550929
#
# --- Iteration 11 ---
# Checking Company_8
#
# Calculating footprint for Company 8
#   Product Product 8: Assigned footprint 57.5471
#   Final footprint for Company 8: 57.5471
#   -> No update needed.
# Checking Company_3
#
# Calculating footprint for Company 3
#   Product Product 3: Assigned footprint 48.8487
#   Final footprint for Company 3: 48.8487
#   -> Updated. Previous: 48.79402877331363, New: 48.848697328901686
# Checking Company_10
#
# Calculating footprint for Company 10
#   Product Product 10: Assigned footprint 68.1004
#   Final footprint for Company 10: 68.1004
#   -> Updated. Previous: 68.07569707469132, New: 68.10044140767451
# Checking Company_9
#
# Calculating footprint for Company 9
#   Product Product 9: Assigned footprint 40.4496
#   Final footprint for Company 9: 40.4496
#   -> Updated. Previous: 40.406735358374156, New: 40.4495806251619
# Checking Company_6
#
# Calculating footprint for Company 6
#   Product Product 6: Assigned footprint 82.8889
#   Final footprint for Company 6: 82.8889
#   -> Updated. Previous: 82.84584679055745, New: 82.88889981860291
# Checking Company_2
#
# Calculating footprint for Company 2
#   Product Product 2: Assigned footprint 47.6956
#   Final footprint for Company 2: 47.6956
#   -> Updated. Previous: 47.65071198951021, New: 47.69556632380655
# Checking Company_7
#
# Calculating footprint for Company 7
#   Product Product 7: Assigned footprint 74.7750
#   Final footprint for Company 7: 74.7750
#   -> Updated. Previous: 74.74973379078094, New: 74.77495664513388
# Checking Company_1
#
# Calculating footprint for Company 1
#   Product Product 1: Assigned footprint 45.0823
#   Final footprint for Company 1: 45.0823
#   -> Updated. Previous: 45.00990093625612, New: 45.08233835792291
# Checking Company_5
#
# Calculating footprint for Company 5
#   Product Product 5: Assigned footprint 46.7234
#   Final footprint for Company 5: 46.7234
#   -> Updated. Previous: 46.68024364418258, New: 46.723410384802
# Checking Company_4
#
# Calculating footprint for Company 4
#   Product Product 4: Assigned footprint 70.4215
#   Final footprint for Company 4: 70.4215
#   -> Updated. Previous: 70.37908219546354, New: 70.42146342573346
#
# --- Iteration 12 ---
# Checking Company_5
#
# Calculating footprint for Company 5
#   Product Product 5: Assigned footprint 46.7270
#   Final footprint for Company 5: 46.7270
#   -> Updated. Previous: 46.723410384802, New: 46.72697980534714
# Checking Company_3
#
# Calculating footprint for Company 3
#   Product Product 3: Assigned footprint 48.8733
#   Final footprint for Company 3: 48.8733
#   -> Updated. Previous: 48.848697328901686, New: 48.87334506402047
# Checking Company_10
#
# Calculating footprint for Company 10
#   Product Product 10: Assigned footprint 68.1215
#   Final footprint for Company 10: 68.1215
#   -> Updated. Previous: 68.10044140767451, New: 68.12145132129119
# Checking Company_4
#
# Calculating footprint for Company 4
#   Product Product 4: Assigned footprint 70.4257
#   Final footprint for Company 4: 70.4257
#   -> Updated. Previous: 70.42146342573346, New: 70.42566485098433
# Checking Company_7
#
# Calculating footprint for Company 7
#   Product Product 7: Assigned footprint 74.7925
#   Final footprint for Company 7: 74.7925
#   -> Updated. Previous: 74.77495664513388, New: 74.79254898029222
# Checking Company_9
#
# Calculating footprint for Company 9
#   Product Product 9: Assigned footprint 40.4704
#   Final footprint for Company 9: 40.4704
#   -> Updated. Previous: 40.4495806251619, New: 40.47039745755597
# Checking Company_1
#
# Calculating footprint for Company 1
#   Product Product 1: Assigned footprint 45.0961
#   Final footprint for Company 1: 45.0961
#   -> Updated. Previous: 45.08233835792291, New: 45.09614134004484
# Checking Company_6
#
# Calculating footprint for Company 6
#   Product Product 6: Assigned footprint 82.9138
#   Final footprint for Company 6: 82.9138
#   -> Updated. Previous: 82.88889981860291, New: 82.91378726419605
# Checking Company_8
#
# Calculating footprint for Company 8
#   Product Product 8: Assigned footprint 57.5868
#   Final footprint for Company 8: 57.5868
#   -> Updated. Previous: 57.54712546550929, New: 57.58681657141765
# Checking Company_2
#
# Calculating footprint for Company 2
#   Product Product 2: Assigned footprint 47.7181
#   Final footprint for Company 2: 47.7181
#   -> Updated. Previous: 47.69556632380655, New: 47.71805260235458
#
# --- Iteration 13 ---
# Checking Company_6
#
# Calculating footprint for Company 6
#   Product Product 6: Assigned footprint 82.9184
#   Final footprint for Company 6: 82.9184
#   -> Updated. Previous: 82.91378726419605, New: 82.91842442726475
# Checking Company_5
#
# Calculating footprint for Company 5
#   Product Product 5: Assigned footprint 46.7433
#   Final footprint for Company 5: 46.7433
#   -> Updated. Previous: 46.72697980534714, New: 46.74329972094814
# Checking Company_1
#
# Calculating footprint for Company 1
#   Product Product 1: Assigned footprint 45.1045
#   Final footprint for Company 1: 45.1045
#   -> Updated. Previous: 45.09614134004484, New: 45.10454689380833
# Checking Company_4
#
# Calculating footprint for Company 4
#   Product Product 4: Assigned footprint 70.4401
#   Final footprint for Company 4: 70.4401
#   -> Updated. Previous: 70.42566485098433, New: 70.44005788179379
# Checking Company_3
#
# Calculating footprint for Company 3
#   Product Product 3: Assigned footprint 48.8883
#   Final footprint for Company 3: 48.8883
#   -> Updated. Previous: 48.87334506402047, New: 48.888341041112966
# Checking Company_8
#
# Calculating footprint for Company 8
#   Product Product 8: Assigned footprint 57.5930
#   Final footprint for Company 8: 57.5930
#   -> Updated. Previous: 57.58681657141765, New: 57.59297120289115
# Checking Company_2
#
# Calculating footprint for Company 2
#   Product Product 2: Assigned footprint 47.7222
#   Final footprint for Company 2: 47.7222
#   -> Updated. Previous: 47.71805260235458, New: 47.72218216427144
# Checking Company_10
#
# Calculating footprint for Company 10
#   Product Product 10: Assigned footprint 68.1345
#   Final footprint for Company 10: 68.1345
#   -> Updated. Previous: 68.12145132129119, New: 68.1344998088729
# Checking Company_7
#
# Calculating footprint for Company 7
#   Product Product 7: Assigned footprint 74.8095
#   Final footprint for Company 7: 74.8095
#   -> Updated. Previous: 74.79254898029222, New: 74.80950516037994
# Checking Company_9
#
# Calculating footprint for Company 9
#   Product Product 9: Assigned footprint 40.4826
#   Final footprint for Company 9: 40.4826
#   -> Updated. Previous: 40.47039745755597, New: 40.4825606105676
#
# --- Iteration 14 ---
# Checking Company_3
#
# Calculating footprint for Company 3
#   Product Product 3: Assigned footprint 48.8921
#   Final footprint for Company 3: 48.8921
#   -> Updated. Previous: 48.888341041112966, New: 48.89211819325221
# Checking Company_9
#
# Calculating footprint for Company 9
#   Product Product 9: Assigned footprint 40.4828
#   Final footprint for Company 9: 40.4828
#   -> No update needed.
# Checking Company_1
#
# Calculating footprint for Company 1
#   Product Product 1: Assigned footprint 45.1112
#   Final footprint for Company 1: 45.1112
#   -> Updated. Previous: 45.10454689380833, New: 45.11120913644197
# Checking Company_5
#
# Calculating footprint for Company 5
#   Product Product 5: Assigned footprint 46.7518
#   Final footprint for Company 5: 46.7518
#   -> Updated. Previous: 46.74329972094814, New: 46.751779667600395
# Checking Company_6
#
# Calculating footprint for Company 6
#   Product Product 6: Assigned footprint 82.9278
#   Final footprint for Company 6: 82.9278
#   -> Updated. Previous: 82.91842442726475, New: 82.92778310766633
# Checking Company_8
#
# Calculating footprint for Company 8
#   Product Product 8: Assigned footprint 57.5986
#   Final footprint for Company 8: 57.5986
#   -> Updated. Previous: 57.59297120289115, New: 57.5986210784361
# Checking Company_10
#
# Calculating footprint for Company 10
#   Product Product 10: Assigned footprint 68.1384
#   Final footprint for Company 10: 68.1384
#   -> Updated. Previous: 68.1344998088729, New: 68.13837094244444
# Checking Company_7
#
# Calculating footprint for Company 7
#   Product Product 7: Assigned footprint 74.8137
#   Final footprint for Company 7: 74.8137
#   -> Updated. Previous: 74.80950516037994, New: 74.81366265210146
# Checking Company_4
#
# Calculating footprint for Company 4
#   Product Product 4: Assigned footprint 70.4494
#   Final footprint for Company 4: 70.4494
#   -> Updated. Previous: 70.44005788179379, New: 70.4493953234428
# Checking Company_2
#
# Calculating footprint for Company 2
#   Product Product 2: Assigned footprint 47.7281
#   Final footprint for Company 2: 47.7281
#   -> Updated. Previous: 47.72218216427144, New: 47.72812852688389
#
# --- Iteration 15 ---
# Checking Company_3
#
# Calculating footprint for Company 3
#   Product Product 3: Assigned footprint 48.8960
#   Final footprint for Company 3: 48.8960
#   -> Updated. Previous: 48.89211819325221, New: 48.895968160667046
# Checking Company_7
#
# Calculating footprint for Company 7
#   Product Product 7: Assigned footprint 74.8153
#   Final footprint for Company 7: 74.8153
#   -> Updated. Previous: 74.81366265210146, New: 74.81525482624295
# Checking Company_4
#
# Calculating footprint for Company 4
#   Product Product 4: Assigned footprint 70.4504
#   Final footprint for Company 4: 70.4504
#   -> Updated. Previous: 70.4493953234428, New: 70.45036730795627
# Checking Company_10
#
# Calculating footprint for Company 10
#   Product Product 10: Assigned footprint 68.1400
#   Final footprint for Company 10: 68.1400
#   -> Updated. Previous: 68.13837094244444, New: 68.13995847914616
# Checking Company_8
#
# Calculating footprint for Company 8
#   Product Product 8: Assigned footprint 57.6010
#   Final footprint for Company 8: 57.6010
#   -> Updated. Previous: 57.5986210784361, New: 57.600993452086776
# Checking Company_9
#
# Calculating footprint for Company 9
#   Product Product 9: Assigned footprint 40.4867
#   Final footprint for Company 9: 40.4867
#   -> Updated. Previous: 40.482790426319625, New: 40.48667451575003
# Checking Company_6
#
# Calculating footprint for Company 6
#   Product Product 6: Assigned footprint 82.9310
#   Final footprint for Company 6: 82.9310
#   -> Updated. Previous: 82.92778310766633, New: 82.93102360871191
# Checking Company_5
#
# Calculating footprint for Company 5
#   Product Product 5: Assigned footprint 46.7565
#   Final footprint for Company 5: 46.7565
#   -> Updated. Previous: 46.751779667600395, New: 46.75650024742107
# Checking Company_1
#
# Calculating footprint for Company 1
#   Product Product 1: Assigned footprint 45.1166
#   Final footprint for Company 1: 45.1166
#   -> Updated. Previous: 45.11120913644197, New: 45.11659771199684
# Checking Company_2
#
# Calculating footprint for Company 2
#   Product Product 2: Assigned footprint 47.7299
#   Final footprint for Company 2: 47.7299
#   -> Updated. Previous: 47.72812852688389, New: 47.72989965132935
#
# --- Iteration 16 ---
# Checking Company_3
#
# Calculating footprint for Company 3
#   Product Product 3: Assigned footprint 48.8978
#   Final footprint for Company 3: 48.8978
#   -> Updated. Previous: 48.895968160667046, New: 48.89782308918578
# Checking Company_8
#
# Calculating footprint for Company 8
#   Product Product 8: Assigned footprint 57.6026
#   Final footprint for Company 8: 57.6026
#   -> Updated. Previous: 57.600993452086776, New: 57.60259121341999
# Checking Company_5
#
# Calculating footprint for Company 5
#   Product Product 5: Assigned footprint 46.7574
#   Final footprint for Company 5: 46.7574
#   -> Updated. Previous: 46.75650024742107, New: 46.75739404125694
# Checking Company_6
#
# Calculating footprint for Company 6
#   Product Product 6: Assigned footprint 82.9322
#   Final footprint for Company 6: 82.9322
#   -> Updated. Previous: 82.93102360871191, New: 82.93223379388012
# Checking Company_10
#
# Calculating footprint for Company 10
#   Product Product 10: Assigned footprint 68.1416
#   Final footprint for Company 10: 68.1416
#   -> Updated. Previous: 68.13995847914616, New: 68.14162634656483
# Checking Company_9
#
# Calculating footprint for Company 9
#   Product Product 9: Assigned footprint 40.4880
#   Final footprint for Company 9: 40.4880
#   -> Updated. Previous: 40.48667451575003, New: 40.48803408657845
# Checking Company_2
#
# Calculating footprint for Company 2
#   Product Product 2: Assigned footprint 47.7304
#   Final footprint for Company 2: 47.7304
#   -> Updated. Previous: 47.72989965132935, New: 47.73044580196773
# Checking Company_1
#
# Calculating footprint for Company 1
#   Product Product 1: Assigned footprint 45.1174
#   Final footprint for Company 1: 45.1174
#   -> Updated. Previous: 45.11659771199684, New: 45.11744598578827
# Checking Company_7
#
# Calculating footprint for Company 7
#   Product Product 7: Assigned footprint 74.8181
#   Final footprint for Company 7: 74.8181
#   -> Updated. Previous: 74.81525482624295, New: 74.81809613563125
# Checking Company_4
#
# Calculating footprint for Company 4
#   Product Product 4: Assigned footprint 70.4534
#   Final footprint for Company 4: 70.4534
#   -> Updated. Previous: 70.45036730795627, New: 70.45344106328183
#
# --- Iteration 17 ---
# Checking Company_9
#
# Calculating footprint for Company 9
#   Product Product 9: Assigned footprint 40.4885
#   Final footprint for Company 9: 40.4885
#   -> Updated. Previous: 40.48803408657845, New: 40.48847882263422
# Checking Company_5
#
# Calculating footprint for Company 5
#   Product Product 5: Assigned footprint 46.7584
#   Final footprint for Company 5: 46.7584
#   -> Updated. Previous: 46.75739404125694, New: 46.75840401549665
# Checking Company_10
#
# Calculating footprint for Company 10
#   Product Product 10: Assigned footprint 68.1422
#   Final footprint for Company 10: 68.1422
#   -> No update needed.
# Checking Company_4
#
# Calculating footprint for Company 4
#   Product Product 4: Assigned footprint 70.4536
#   Final footprint for Company 4: 70.4536
#   -> No update needed.
# Checking Company_2
#
# Calculating footprint for Company 2
#   Product Product 2: Assigned footprint 47.7310
#   Final footprint for Company 2: 47.7310
#   -> Updated. Previous: 47.73044580196773, New: 47.730968662708506
# Checking Company_7
#
# Calculating footprint for Company 7
#   Product Product 7: Assigned footprint 74.8185
#   Final footprint for Company 7: 74.8185
#   -> No update needed.
# Checking Company_1
#
# Calculating footprint for Company 1
#   Product Product 1: Assigned footprint 45.1181
#   Final footprint for Company 1: 45.1181
#   -> Updated. Previous: 45.11744598578827, New: 45.118060138740404
# Checking Company_8
#
# Calculating footprint for Company 8
#   Product Product 8: Assigned footprint 57.6037
#   Final footprint for Company 8: 57.6037
#   -> Updated. Previous: 57.60259121341999, New: 57.6037300941466
# Checking Company_6
#
# Calculating footprint for Company 6
#   Product Product 6: Assigned footprint 82.9333
#   Final footprint for Company 6: 82.9333
#   -> Updated. Previous: 82.93223379388012, New: 82.93328294448237
# Checking Company_3
#
# Calculating footprint for Company 3
#   Product Product 3: Assigned footprint 48.8992
#   Final footprint for Company 3: 48.8992
#   -> Updated. Previous: 48.89782308918578, New: 48.89917823346615
#
# --- Iteration 18 ---
# Checking Company_3
#
# Calculating footprint for Company 3
#   Product Product 3: Assigned footprint 48.8992
#   Final footprint for Company 3: 48.8992
#   -> No update needed.
# Checking Company_10
#
# Calculating footprint for Company 10
#   Product Product 10: Assigned footprint 68.1425
#   Final footprint for Company 10: 68.1425
#   -> No update needed.
# Checking Company_8
#
# Calculating footprint for Company 8
#   Product Product 8: Assigned footprint 57.6039
#   Final footprint for Company 8: 57.6039
#   -> No update needed.
# Checking Company_4
#
# Calculating footprint for Company 4
#   Product Product 4: Assigned footprint 70.4540
#   Final footprint for Company 4: 70.4540
#   -> No update needed.
# Checking Company_5
#
# Calculating footprint for Company 5
#   Product Product 5: Assigned footprint 46.7588
#   Final footprint for Company 5: 46.7588
#   -> No update needed.
# Checking Company_1
#
# Calculating footprint for Company 1
#   Product Product 1: Assigned footprint 45.1183
#   Final footprint for Company 1: 45.1183
#   -> No update needed.
# Checking Company_7
#
# Calculating footprint for Company 7
#   Product Product 7: Assigned footprint 74.8189
#   Final footprint for Company 7: 74.8189
#   -> No update needed.
# Checking Company_6
#
# Calculating footprint for Company 6
#   Product Product 6: Assigned footprint 82.9334
#   Final footprint for Company 6: 82.9334
#   -> No update needed.
# Checking Company_2
#
# Calculating footprint for Company 2
#   Product Product 2: Assigned footprint 47.7312
#   Final footprint for Company 2: 47.7312
#   -> No update needed.
# Checking Company_9
#
# Calculating footprint for Company 9
#   Product Product 9: Assigned footprint 40.4888
#   Final footprint for Company 9: 40.4888
#   -> No update needed.
#
# ✅ Updates completed.
# ⏱️ Time taken: 0.35 seconds
#
# 📦 Final Footprints:
# Company_1: 45.1183 kg CO2e/unit
# Company_2: 47.7312 kg CO2e/unit
# Company_3: 48.8992 kg CO2e/unit
# Company_4: 70.4540 kg CO2e/unit
# Company_5: 46.7588 kg CO2e/unit
# Company_6: 82.9334 kg CO2e/unit
# Company_7: 74.8189 kg CO2e/unit
# Company_8: 57.6039 kg CO2e/unit
# Company_9: 40.4888 kg CO2e/unit
# Company_10: 68.1425 kg CO2e/unit
#
# 🔁 Update Count:
# Company_1: 17 updates
# Company_2: 17 updates
# Company_3: 17 updates
# Company_4: 16 updates
# Company_5: 17 updates
# Company_6: 17 updates
# Company_7: 16 updates
# Company_8: 16 updates
# Company_9: 16 updates
# Company_10: 16 updates
# Total updates: 165
#
# --- Forced Update Iteration 1 ---
#
# Calculating footprint for Company 1
#   Product Product 1: Assigned footprint 45.1183
#   Final footprint for Company 1: 45.1183
#
# Calculating footprint for Company 2
#   Product Product 2: Assigned footprint 47.7313
#   Final footprint for Company 2: 47.7313
#
# Calculating footprint for Company 3
#   Product Product 3: Assigned footprint 48.8992
#   Final footprint for Company 3: 48.8992
#
# Calculating footprint for Company 4
#   Product Product 4: Assigned footprint 70.4540
#   Final footprint for Company 4: 70.4540
#
# Calculating footprint for Company 5
#   Product Product 5: Assigned footprint 46.7589
#   Final footprint for Company 5: 46.7589
#
# Calculating footprint for Company 6
#   Product Product 6: Assigned footprint 82.9335
#   Final footprint for Company 6: 82.9335
#
# Calculating footprint for Company 7
#   Product Product 7: Assigned footprint 74.8190
#   Final footprint for Company 7: 74.8190
#
# Calculating footprint for Company 8
#   Product Product 8: Assigned footprint 57.6041
#   Final footprint for Company 8: 57.6041
#
# Calculating footprint for Company 9
#   Product Product 9: Assigned footprint 40.4890
#   Final footprint for Company 9: 40.4890
#
# Calculating footprint for Company 10
#   Product Product 10: Assigned footprint 68.1428
#   Final footprint for Company 10: 68.1428
#
# --- Forced Update Iteration 2 ---
#
# Calculating footprint for Company 1
#   Product Product 1: Assigned footprint 45.1187
#   Final footprint for Company 1: 45.1187
#
# Calculating footprint for Company 2
#   Product Product 2: Assigned footprint 47.7315
#   Final footprint for Company 2: 47.7315
#
# Calculating footprint for Company 3
#   Product Product 3: Assigned footprint 48.8996
#   Final footprint for Company 3: 48.8996
#
# Calculating footprint for Company 4
#   Product Product 4: Assigned footprint 70.4544
#   Final footprint for Company 4: 70.4544
#
# Calculating footprint for Company 5
#   Product Product 5: Assigned footprint 46.7593
#   Final footprint for Company 5: 46.7593
#
# Calculating footprint for Company 6
#   Product Product 6: Assigned footprint 82.9339
#   Final footprint for Company 6: 82.9339
#
# Calculating footprint for Company 7
#   Product Product 7: Assigned footprint 74.8194
#   Final footprint for Company 7: 74.8194
#
# Calculating footprint for Company 8
#   Product Product 8: Assigned footprint 57.6044
#   Final footprint for Company 8: 57.6044
#
# Calculating footprint for Company 9
#   Product Product 9: Assigned footprint 40.4893
#   Final footprint for Company 9: 40.4893
#
# Calculating footprint for Company 10
#   Product Product 10: Assigned footprint 68.1430
#   Final footprint for Company 10: 68.1430
#
# --- Forced Update Iteration 3 ---
#
# Calculating footprint for Company 1
#   Product Product 1: Assigned footprint 45.1189
#   Final footprint for Company 1: 45.1189
#
# Calculating footprint for Company 2
#   Product Product 2: Assigned footprint 47.7317
#   Final footprint for Company 2: 47.7317
#
# Calculating footprint for Company 3
#   Product Product 3: Assigned footprint 48.8998
#   Final footprint for Company 3: 48.8998
#
# Calculating footprint for Company 4
#   Product Product 4: Assigned footprint 70.4546
#   Final footprint for Company 4: 70.4546
#
# Calculating footprint for Company 5
#   Product Product 5: Assigned footprint 46.7595
#   Final footprint for Company 5: 46.7595
#
# Calculating footprint for Company 6
#   Product Product 6: Assigned footprint 82.9340
#   Final footprint for Company 6: 82.9340
#
# Calculating footprint for Company 7
#   Product Product 7: Assigned footprint 74.8195
#   Final footprint for Company 7: 74.8195
#
# Calculating footprint for Company 8
#   Product Product 8: Assigned footprint 57.6046
#   Final footprint for Company 8: 57.6046
#
# Calculating footprint for Company 9
#   Product Product 9: Assigned footprint 40.4894
#   Final footprint for Company 9: 40.4894
#
# Calculating footprint for Company 10
#   Product Product 10: Assigned footprint 68.1430
#   Final footprint for Company 10: 68.1430

# %%
foo = None
a = 5 if foo is None else a = 4
# Out:
#   Cell In[1], line 2
#     a = 5 if foo is None else a = 4
#     ^
# SyntaxError: invalid syntax. Maybe you meant '==' or ':=' instead of '='?
