# %%
# simulate_allocation.ipynb

import random
import time
import numpy as np
import pandas as pd
from SSELF_base import FootprintDatabase
from allocation_extension import AllocationSystem, AllocationCompany, AllocationProduct

# Step 1: Create a system with multiple interconnected companies
num_companies = 10
base_products = num_companies
system = AllocationSystem(num_companies=num_companies, num_products=base_products)

# Step 2: Add hierarchies to one company and define two co-products using mass allocation
company = system.companies['Company_1']

sub_sales = pd.DataFrame.from_dict({
    system.product_id_counter: 300.0,  # Product A ($300)
    system.product_id_counter + 1: 200.0  # Product B ($200)
}, orient="index", columns=["Sales"])
sub_purchases = pd.Series({i + 1: np.random.uniform(50, 150) for i in range(3)})
direct_impacts = pd.DataFrame({"kg CO2eq": [random.randint(50, 150)]})

sub = AllocationCompany("Company_1_Sub_1", 2024, sub_purchases, sub_sales, direct_impacts)

product_A = AllocationProduct(system.product_id_counter, "Copper coil", "kg", sub, properties={"mass": 600})
product_B = AllocationProduct(system.product_id_counter + 1, "Copper residue", "kg", sub, properties={"mass": 400})
sub.add_product(product_A)
sub.add_product(product_B)
company.add_sub_company(sub)
system.product_id_counter += 2

# Step 3: Initialize footprint database
fp_db = FootprintDatabase(2024)
for c in system.companies.values():
    for p in c.products:
        fp_db.report(p.product_id, 0)
    for sub in getattr(c, "sub_companies", []):
        for p in sub.products:
            fp_db.report(p.product_id, 0)

# Step 4: Run iterative simulation
updates_completed = False
iteration = 0
start_time = time.time()

while not updates_completed:
    iteration += 1
    print(f"\n--- Iteration {iteration} ---")
    any_updated = False

    for name, company in system.companies.items():
        previous = company.latest_update

        for sub in getattr(company, "sub_companies", []):
            sub.update_footprint(fp_db)
            sub.report_footprint(fp_db)

        company.update_footprint(fp_db)
        new = company.latest_update

        if previous is None or not np.isclose(previous, new, atol=1e-6):
            print(f"  → {name} updated.")
            any_updated = True
            company.report_footprint(fp_db)

    updates_completed = not any_updated

end_time = time.time()
print("\n Updates completed.")
print(f" Time taken: {end_time - start_time:.2f} seconds")

print("\n Final Footprints:")
for name, company in system.companies.items():
    print(f"{name}: {company.latest_update:.4f} kg CO2e/unit")
    for sub in getattr(company, "sub_companies", []):
        print(f"  {sub.name}: {sub.latest_update:.4f}")

print("\n🗃 Final footprint database:")
print(fp_db.data.sort_values("id"))
# Out:
# --- Iteration 1 ---
#
# Calculating footprint for Company_1_Sub_1
#   Using mass allocation
#   Product Copper coil (Mass=600): Assigned footprint 54.0000
#   Product Copper residue (Mass=400): Assigned footprint 36.0000
#   Final footprint for Company_1_Sub_1: 46.8000
#
# Calculating footprint for Company_1
#   Using economic allocation
#   Product Product 1 (Sales=14.260690423988319): Assigned footprint 18.4423
#   Final footprint for Company_1: 18.4423
#   → Company_1 updated.
#
# Calculating footprint for Company_2
#   Using economic allocation
#   Product Product 2 (Sales=14.493943601470443): Assigned footprint 43.2210
#   Final footprint for Company_2: 43.2210
#   → Company_2 updated.
#
# Calculating footprint for Company_3
#   Using economic allocation
#   Product Product 3 (Sales=15.616834898514655): Assigned footprint 17.9078
#   Final footprint for Company_3: 17.9078
#   → Company_3 updated.
#
# Calculating footprint for Company_4
#   Using economic allocation
#   Product Product 4 (Sales=15.951473109750504): Assigned footprint 25.6134
#   Final footprint for Company_4: 25.6134
#   → Company_4 updated.
#
# Calculating footprint for Company_5
#   Using economic allocation
#   Product Product 5 (Sales=12.25733502304246): Assigned footprint 24.9797
#   Final footprint for Company_5: 24.9797
#   → Company_5 updated.
#
# Calculating footprint for Company_6
#   Using economic allocation
#   Product Product 6 (Sales=12.689936262491791): Assigned footprint 11.2029
#   Final footprint for Company_6: 11.2029
#   → Company_6 updated.
#
# Calculating footprint for Company_7
#   Using economic allocation
#   Product Product 7 (Sales=12.948904000293917): Assigned footprint 42.2713
#   Final footprint for Company_7: 42.2713
#   → Company_7 updated.
#
# Calculating footprint for Company_8
#   Using economic allocation
#   Product Product 8 (Sales=14.850433902213426): Assigned footprint 40.8499
#   Final footprint for Company_8: 40.8499
#   → Company_8 updated.
#
# Calculating footprint for Company_9
#   Using economic allocation
#   Product Product 9 (Sales=14.933457771877734): Assigned footprint 47.3760
#   Final footprint for Company_9: 47.3760
#   → Company_9 updated.
#
# Calculating footprint for Company_10
#   Using economic allocation
#   Product Product 10 (Sales=15.9696336183309): Assigned footprint 18.0257
#   Final footprint for Company_10: 18.0257
#   → Company_10 updated.
#
# --- Iteration 2 ---
#
# Calculating footprint for Company_1_Sub_1
#   Using mass allocation
#   Product Copper coil (Mass=600): Assigned footprint 4570.0392
#   Product Copper residue (Mass=400): Assigned footprint 3046.6928
#   Final footprint for Company_1_Sub_1: 3960.7006
#
# Calculating footprint for Company_1
#   Using economic allocation
#   Product Product 1 (Sales=14.260690423988319): Assigned footprint 37.4770
#   Final footprint for Company_1: 37.4770
#   → Company_1 updated.
#
# Calculating footprint for Company_2
#   Using economic allocation
#   Product Product 2 (Sales=14.493943601470443): Assigned footprint 60.2806
#   Final footprint for Company_2: 60.2806
#   → Company_2 updated.
#
# Calculating footprint for Company_3
#   Using economic allocation
#   Product Product 3 (Sales=15.616834898514655): Assigned footprint 33.6865
#   Final footprint for Company_3: 33.6865
#   → Company_3 updated.
#
# Calculating footprint for Company_4
#   Using economic allocation
#   Product Product 4 (Sales=15.951473109750504): Assigned footprint 40.4445
#   Final footprint for Company_4: 40.4445
#   → Company_4 updated.
#
# Calculating footprint for Company_5
#   Using economic allocation
#   Product Product 5 (Sales=12.25733502304246): Assigned footprint 43.4527
#   Final footprint for Company_5: 43.4527
#   → Company_5 updated.
#
# Calculating footprint for Company_6
#   Using economic allocation
#   Product Product 6 (Sales=12.689936262491791): Assigned footprint 29.6191
#   Final footprint for Company_6: 29.6191
#   → Company_6 updated.
#
# Calculating footprint for Company_7
#   Using economic allocation
#   Product Product 7 (Sales=12.948904000293917): Assigned footprint 58.4769
#   Final footprint for Company_7: 58.4769
#   → Company_7 updated.
#
# Calculating footprint for Company_8
#   Using economic allocation
#   Product Product 8 (Sales=14.850433902213426): Assigned footprint 53.3209
#   Final footprint for Company_8: 53.3209
#   → Company_8 updated.
#
# Calculating footprint for Company_9
#   Using economic allocation
#   Product Product 9 (Sales=14.933457771877734): Assigned footprint 57.4404
#   Final footprint for Company_9: 57.4404
#   → Company_9 updated.
#
# Calculating footprint for Company_10
#   Using economic allocation
#   Product Product 10 (Sales=15.9696336183309): Assigned footprint 26.9385
#   Final footprint for Company_10: 26.9385
#   → Company_10 updated.
#
# --- Iteration 3 ---
#
# Calculating footprint for Company_1_Sub_1
#   Using mass allocation
#   Product Copper coil (Mass=600): Assigned footprint 7421.6025
#   Product Copper residue (Mass=400): Assigned footprint 4947.7350
#   Final footprint for Company_1_Sub_1: 6432.0555
#
# Calculating footprint for Company_1
#   Using economic allocation
#   Product Product 1 (Sales=14.260690423988319): Assigned footprint 46.7481
#   Final footprint for Company_1: 46.7481
#   → Company_1 updated.
#
# Calculating footprint for Company_2
#   Using economic allocation
#   Product Product 2 (Sales=14.493943601470443): Assigned footprint 68.8652
#   Final footprint for Company_2: 68.8652
#   → Company_2 updated.
#
# Calculating footprint for Company_3
#   Using economic allocation
#   Product Product 3 (Sales=15.616834898514655): Assigned footprint 41.1931
#   Final footprint for Company_3: 41.1931
#   → Company_3 updated.
#
# Calculating footprint for Company_4
#   Using economic allocation
#   Product Product 4 (Sales=15.951473109750504): Assigned footprint 47.3345
#   Final footprint for Company_4: 47.3345
#   → Company_4 updated.
#
# Calculating footprint for Company_5
#   Using economic allocation
#   Product Product 5 (Sales=12.25733502304246): Assigned footprint 51.4742
#   Final footprint for Company_5: 51.4742
#   → Company_5 updated.
#
# Calculating footprint for Company_6
#   Using economic allocation
#   Product Product 6 (Sales=12.689936262491791): Assigned footprint 36.5480
#   Final footprint for Company_6: 36.5480
#   → Company_6 updated.
#
# Calculating footprint for Company_7
#   Using economic allocation
#   Product Product 7 (Sales=12.948904000293917): Assigned footprint 64.5509
#   Final footprint for Company_7: 64.5509
#   → Company_7 updated.
#
# Calculating footprint for Company_8
#   Using economic allocation
#   Product Product 8 (Sales=14.850433902213426): Assigned footprint 58.1864
#   Final footprint for Company_8: 58.1864
#   → Company_8 updated.
#
# Calculating footprint for Company_9
#   Using economic allocation
#   Product Product 9 (Sales=14.933457771877734): Assigned footprint 61.9307
#   Final footprint for Company_9: 61.9307
#   → Company_9 updated.
#
# Calculating footprint for Company_10
#   Using economic allocation
#   Product Product 10 (Sales=15.9696336183309): Assigned footprint 30.8605
#   Final footprint for Company_10: 30.8605
#   → Company_10 updated.
#
# --- Iteration 4 ---
#
# Calculating footprint for Company_1_Sub_1
#   Using mass allocation
#   Product Copper coil (Mass=600): Assigned footprint 8814.8621
#   Product Copper residue (Mass=400): Assigned footprint 5876.5747
#   Final footprint for Company_1_Sub_1: 7639.5471
#
# Calculating footprint for Company_1
#   Using economic allocation
#   Product Product 1 (Sales=14.260690423988319): Assigned footprint 50.7650
#   Final footprint for Company_1: 50.7650
#   → Company_1 updated.
#
# Calculating footprint for Company_2
#   Using economic allocation
#   Product Product 2 (Sales=14.493943601470443): Assigned footprint 72.5022
#   Final footprint for Company_2: 72.5022
#   → Company_2 updated.
#
# Calculating footprint for Company_3
#   Using economic allocation
#   Product Product 3 (Sales=15.616834898514655): Assigned footprint 44.3209
#   Final footprint for Company_3: 44.3209
#   → Company_3 updated.
#
# Calculating footprint for Company_4
#   Using economic allocation
#   Product Product 4 (Sales=15.951473109750504): Assigned footprint 50.1608
#   Final footprint for Company_4: 50.1608
#   → Company_4 updated.
#
# Calculating footprint for Company_5
#   Using economic allocation
#   Product Product 5 (Sales=12.25733502304246): Assigned footprint 54.7285
#   Final footprint for Company_5: 54.7285
#   → Company_5 updated.
#
# Calculating footprint for Company_6
#   Using economic allocation
#   Product Product 6 (Sales=12.689936262491791): Assigned footprint 39.4018
#   Final footprint for Company_6: 39.4018
#   → Company_6 updated.
#
# Calculating footprint for Company_7
#   Using economic allocation
#   Product Product 7 (Sales=12.948904000293917): Assigned footprint 67.0989
#   Final footprint for Company_7: 67.0989
#   → Company_7 updated.
#
# Calculating footprint for Company_8
#   Using economic allocation
#   Product Product 8 (Sales=14.850433902213426): Assigned footprint 60.2521
#   Final footprint for Company_8: 60.2521
#   → Company_8 updated.
#
# Calculating footprint for Company_9
#   Using economic allocation
#   Product Product 9 (Sales=14.933457771877734): Assigned footprint 63.8225
#   Final footprint for Company_9: 63.8225
#   → Company_9 updated.
#
# Calculating footprint for Company_10
#   Using economic allocation
#   Product Product 10 (Sales=15.9696336183309): Assigned footprint 32.5025
#   Final footprint for Company_10: 32.5025
#   → Company_10 updated.
#
# --- Iteration 5 ---
#
# Calculating footprint for Company_1_Sub_1
#   Using mass allocation
#   Product Copper coil (Mass=600): Assigned footprint 9405.3303
#   Product Copper residue (Mass=400): Assigned footprint 6270.2202
#   Final footprint for Company_1_Sub_1: 8151.2863
#
# Calculating footprint for Company_1
#   Using economic allocation
#   Product Product 1 (Sales=14.260690423988319): Assigned footprint 52.4372
#   Final footprint for Company_1: 52.4372
#   → Company_1 updated.
#
# Calculating footprint for Company_2
#   Using economic allocation
#   Product Product 2 (Sales=14.493943601470443): Assigned footprint 74.0119
#   Final footprint for Company_2: 74.0119
#   → Company_2 updated.
#
# Calculating footprint for Company_3
#   Using economic allocation
#   Product Product 3 (Sales=15.616834898514655): Assigned footprint 45.6185
#   Final footprint for Company_3: 45.6185
#   → Company_3 updated.
#
# Calculating footprint for Company_4
#   Using economic allocation
#   Product Product 4 (Sales=15.951473109750504): Assigned footprint 51.3353
#   Final footprint for Company_4: 51.3353
#   → Company_4 updated.
#
# Calculating footprint for Company_5
#   Using economic allocation
#   Product Product 5 (Sales=12.25733502304246): Assigned footprint 56.0873
#   Final footprint for Company_5: 56.0873
#   → Company_5 updated.
#
# Calculating footprint for Company_6
#   Using economic allocation
#   Product Product 6 (Sales=12.689936262491791): Assigned footprint 40.5964
#   Final footprint for Company_6: 40.5964
#   → Company_6 updated.
#
# Calculating footprint for Company_7
#   Using economic allocation
#   Product Product 7 (Sales=12.948904000293917): Assigned footprint 68.1651
#   Final footprint for Company_7: 68.1651
#   → Company_7 updated.
#
# Calculating footprint for Company_8
#   Using economic allocation
#   Product Product 8 (Sales=14.850433902213426): Assigned footprint 61.1145
#   Final footprint for Company_8: 61.1145
#   → Company_8 updated.
#
# Calculating footprint for Company_9
#   Using economic allocation
#   Product Product 9 (Sales=14.933457771877734): Assigned footprint 64.6112
#   Final footprint for Company_9: 64.6112
#   → Company_9 updated.
#
# Calculating footprint for Company_10
#   Using economic allocation
#   Product Product 10 (Sales=15.9696336183309): Assigned footprint 33.1866
#   Final footprint for Company_10: 33.1866
#   → Company_10 updated.
#
# --- Iteration 6 ---
#
# Calculating footprint for Company_1_Sub_1
#   Using mass allocation
#   Product Copper coil (Mass=600): Assigned footprint 9650.5782
#   Product Copper residue (Mass=400): Assigned footprint 6433.7188
#   Final footprint for Company_1_Sub_1: 8363.8345
#
# Calculating footprint for Company_1
#   Using economic allocation
#   Product Product 1 (Sales=14.260690423988319): Assigned footprint 53.1339
#   Final footprint for Company_1: 53.1339
#   → Company_1 updated.
#
# Calculating footprint for Company_2
#   Using economic allocation
#   Product Product 2 (Sales=14.493943601470443): Assigned footprint 74.6414
#   Final footprint for Company_2: 74.6414
#   → Company_2 updated.
#
# Calculating footprint for Company_3
#   Using economic allocation
#   Product Product 3 (Sales=15.616834898514655): Assigned footprint 46.1599
#   Final footprint for Company_3: 46.1599
#   → Company_3 updated.
#
# Calculating footprint for Company_4
#   Using economic allocation
#   Product Product 4 (Sales=15.951473109750504): Assigned footprint 51.8257
#   Final footprint for Company_4: 51.8257
#   → Company_4 updated.
#
# Calculating footprint for Company_5
#   Using economic allocation
#   Product Product 5 (Sales=12.25733502304246): Assigned footprint 56.6546
#   Final footprint for Company_5: 56.6546
#   → Company_5 updated.
#
# Calculating footprint for Company_6
#   Using economic allocation
#   Product Product 6 (Sales=12.689936262491791): Assigned footprint 41.0950
#   Final footprint for Company_6: 41.0950
#   → Company_6 updated.
#
# Calculating footprint for Company_7
#   Using economic allocation
#   Product Product 7 (Sales=12.948904000293917): Assigned footprint 68.6099
#   Final footprint for Company_7: 68.6099
#   → Company_7 updated.
#
# Calculating footprint for Company_8
#   Using economic allocation
#   Product Product 8 (Sales=14.850433902213426): Assigned footprint 61.4742
#   Final footprint for Company_8: 61.4742
#   → Company_8 updated.
#
# Calculating footprint for Company_9
#   Using economic allocation
#   Product Product 9 (Sales=14.933457771877734): Assigned footprint 64.9402
#   Final footprint for Company_9: 64.9402
#   → Company_9 updated.
#
# Calculating footprint for Company_10
#   Using economic allocation
#   Product Product 10 (Sales=15.9696336183309): Assigned footprint 33.4720
#   Final footprint for Company_10: 33.4720
#   → Company_10 updated.
#
# --- Iteration 7 ---
#
# Calculating footprint for Company_1_Sub_1
#   Using mass allocation
#   Product Copper coil (Mass=600): Assigned footprint 9752.8463
#   Product Copper residue (Mass=400): Assigned footprint 6501.8975
#   Final footprint for Company_1_Sub_1: 8452.4668
#
# Calculating footprint for Company_1
#   Using economic allocation
#   Product Product 1 (Sales=14.260690423988319): Assigned footprint 53.4247
#   Final footprint for Company_1: 53.4247
#   → Company_1 updated.
#
# Calculating footprint for Company_2
#   Using economic allocation
#   Product Product 2 (Sales=14.493943601470443): Assigned footprint 74.9041
#   Final footprint for Company_2: 74.9041
#   → Company_2 updated.
#
# Calculating footprint for Company_3
#   Using economic allocation
#   Product Product 3 (Sales=15.616834898514655): Assigned footprint 46.3859
#   Final footprint for Company_3: 46.3859
#   → Company_3 updated.
#
# Calculating footprint for Company_4
#   Using economic allocation
#   Product Product 4 (Sales=15.951473109750504): Assigned footprint 52.0303
#   Final footprint for Company_4: 52.0303
#   → Company_4 updated.
#
# Calculating footprint for Company_5
#   Using economic allocation
#   Product Product 5 (Sales=12.25733502304246): Assigned footprint 56.8913
#   Final footprint for Company_5: 56.8913
#   → Company_5 updated.
#
# Calculating footprint for Company_6
#   Using economic allocation
#   Product Product 6 (Sales=12.689936262491791): Assigned footprint 41.3030
#   Final footprint for Company_6: 41.3030
#   → Company_6 updated.
#
# Calculating footprint for Company_7
#   Using economic allocation
#   Product Product 7 (Sales=12.948904000293917): Assigned footprint 68.7954
#   Final footprint for Company_7: 68.7954
#   → Company_7 updated.
#
# Calculating footprint for Company_8
#   Using economic allocation
#   Product Product 8 (Sales=14.850433902213426): Assigned footprint 61.6243
#   Final footprint for Company_8: 61.6243
#   → Company_8 updated.
#
# Calculating footprint for Company_9
#   Using economic allocation
#   Product Product 9 (Sales=14.933457771877734): Assigned footprint 65.0774
#   Final footprint for Company_9: 65.0774
#   → Company_9 updated.
#
# Calculating footprint for Company_10
#   Using economic allocation
#   Product Product 10 (Sales=15.9696336183309): Assigned footprint 33.5910
#   Final footprint for Company_10: 33.5910
#   → Company_10 updated.
#
# --- Iteration 8 ---
#
# Calculating footprint for Company_1_Sub_1
#   Using mass allocation
#   Product Copper coil (Mass=600): Assigned footprint 9795.5214
#   Product Copper residue (Mass=400): Assigned footprint 6530.3476
#   Final footprint for Company_1_Sub_1: 8489.4519
#
# Calculating footprint for Company_1
#   Using economic allocation
#   Product Product 1 (Sales=14.260690423988319): Assigned footprint 53.5460
#   Final footprint for Company_1: 53.5460
#   → Company_1 updated.
#
# Calculating footprint for Company_2
#   Using economic allocation
#   Product Product 2 (Sales=14.493943601470443): Assigned footprint 75.0137
#   Final footprint for Company_2: 75.0137
#   → Company_2 updated.
#
# Calculating footprint for Company_3
#   Using economic allocation
#   Product Product 3 (Sales=15.616834898514655): Assigned footprint 46.4801
#   Final footprint for Company_3: 46.4801
#   → Company_3 updated.
#
# Calculating footprint for Company_4
#   Using economic allocation
#   Product Product 4 (Sales=15.951473109750504): Assigned footprint 52.1157
#   Final footprint for Company_4: 52.1157
#   → Company_4 updated.
#
# Calculating footprint for Company_5
#   Using economic allocation
#   Product Product 5 (Sales=12.25733502304246): Assigned footprint 56.9901
#   Final footprint for Company_5: 56.9901
#   → Company_5 updated.
#
# Calculating footprint for Company_6
#   Using economic allocation
#   Product Product 6 (Sales=12.689936262491791): Assigned footprint 41.3898
#   Final footprint for Company_6: 41.3898
#   → Company_6 updated.
#
# Calculating footprint for Company_7
#   Using economic allocation
#   Product Product 7 (Sales=12.948904000293917): Assigned footprint 68.8729
#   Final footprint for Company_7: 68.8729
#   → Company_7 updated.
#
# Calculating footprint for Company_8
#   Using economic allocation
#   Product Product 8 (Sales=14.850433902213426): Assigned footprint 61.6869
#   Final footprint for Company_8: 61.6869
#   → Company_8 updated.
#
# Calculating footprint for Company_9
#   Using economic allocation
#   Product Product 9 (Sales=14.933457771877734): Assigned footprint 65.1347
#   Final footprint for Company_9: 65.1347
#   → Company_9 updated.
#
# Calculating footprint for Company_10
#   Using economic allocation
#   Product Product 10 (Sales=15.9696336183309): Assigned footprint 33.6407
#   Final footprint for Company_10: 33.6407
#   → Company_10 updated.
#
# --- Iteration 9 ---
#
# Calculating footprint for Company_1_Sub_1
#   Using mass allocation
#   Product Copper coil (Mass=600): Assigned footprint 9813.3269
#   Product Copper residue (Mass=400): Assigned footprint 6542.2179
#   Final footprint for Company_1_Sub_1: 8504.8833
#
# Calculating footprint for Company_1
#   Using economic allocation
#   Product Product 1 (Sales=14.260690423988319): Assigned footprint 53.5966
#   Final footprint for Company_1: 53.5966
#   → Company_1 updated.
#
# Calculating footprint for Company_2
#   Using economic allocation
#   Product Product 2 (Sales=14.493943601470443): Assigned footprint 75.0595
#   Final footprint for Company_2: 75.0595
#   → Company_2 updated.
#
# Calculating footprint for Company_3
#   Using economic allocation
#   Product Product 3 (Sales=15.616834898514655): Assigned footprint 46.5195
#   Final footprint for Company_3: 46.5195
#   → Company_3 updated.
#
# Calculating footprint for Company_4
#   Using economic allocation
#   Product Product 4 (Sales=15.951473109750504): Assigned footprint 52.1513
#   Final footprint for Company_4: 52.1513
#   → Company_4 updated.
#
# Calculating footprint for Company_5
#   Using economic allocation
#   Product Product 5 (Sales=12.25733502304246): Assigned footprint 57.0313
#   Final footprint for Company_5: 57.0313
#   → Company_5 updated.
#
# Calculating footprint for Company_6
#   Using economic allocation
#   Product Product 6 (Sales=12.689936262491791): Assigned footprint 41.4260
#   Final footprint for Company_6: 41.4260
#   → Company_6 updated.
#
# Calculating footprint for Company_7
#   Using economic allocation
#   Product Product 7 (Sales=12.948904000293917): Assigned footprint 68.9052
#   Final footprint for Company_7: 68.9052
#   → Company_7 updated.
#
# Calculating footprint for Company_8
#   Using economic allocation
#   Product Product 8 (Sales=14.850433902213426): Assigned footprint 61.7130
#   Final footprint for Company_8: 61.7130
#   → Company_8 updated.
#
# Calculating footprint for Company_9
#   Using economic allocation
#   Product Product 9 (Sales=14.933457771877734): Assigned footprint 65.1586
#   Final footprint for Company_9: 65.1586
#   → Company_9 updated.
#
# Calculating footprint for Company_10
#   Using economic allocation
#   Product Product 10 (Sales=15.9696336183309): Assigned footprint 33.6614
#   Final footprint for Company_10: 33.6614
#   → Company_10 updated.
#
# --- Iteration 10 ---
#
# Calculating footprint for Company_1_Sub_1
#   Using mass allocation
#   Product Copper coil (Mass=600): Assigned footprint 9820.7557
#   Product Copper residue (Mass=400): Assigned footprint 6547.1705
#   Final footprint for Company_1_Sub_1: 8511.3216
#
# Calculating footprint for Company_1
#   Using economic allocation
#   Product Product 1 (Sales=14.260690423988319): Assigned footprint 53.6177
#   Final footprint for Company_1: 53.6177
#   → Company_1 updated.
#
# Calculating footprint for Company_2
#   Using economic allocation
#   Product Product 2 (Sales=14.493943601470443): Assigned footprint 75.0785
#   Final footprint for Company_2: 75.0785
#   → Company_2 updated.
#
# Calculating footprint for Company_3
#   Using economic allocation
#   Product Product 3 (Sales=15.616834898514655): Assigned footprint 46.5359
#   Final footprint for Company_3: 46.5359
#   → Company_3 updated.
#
# Calculating footprint for Company_4
#   Using economic allocation
#   Product Product 4 (Sales=15.951473109750504): Assigned footprint 52.1662
#   Final footprint for Company_4: 52.1662
#   → Company_4 updated.
#
# Calculating footprint for Company_5
#   Using economic allocation
#   Product Product 5 (Sales=12.25733502304246): Assigned footprint 57.0485
#   Final footprint for Company_5: 57.0485
#   → Company_5 updated.
#
# Calculating footprint for Company_6
#   Using economic allocation
#   Product Product 6 (Sales=12.689936262491791): Assigned footprint 41.4411
#   Final footprint for Company_6: 41.4411
#   → Company_6 updated.
#
# Calculating footprint for Company_7
#   Using economic allocation
#   Product Product 7 (Sales=12.948904000293917): Assigned footprint 68.9186
#   Final footprint for Company_7: 68.9186
#   → Company_7 updated.
#
# Calculating footprint for Company_8
#   Using economic allocation
#   Product Product 8 (Sales=14.850433902213426): Assigned footprint 61.7239
#   Final footprint for Company_8: 61.7239
#   → Company_8 updated.
#
# Calculating footprint for Company_9
#   Using economic allocation
#   Product Product 9 (Sales=14.933457771877734): Assigned footprint 65.1686
#   Final footprint for Company_9: 65.1686
#   → Company_9 updated.
#
# Calculating footprint for Company_10
#   Using economic allocation
#   Product Product 10 (Sales=15.9696336183309): Assigned footprint 33.6701
#   Final footprint for Company_10: 33.6701
#   → Company_10 updated.
#
# --- Iteration 11 ---
#
# Calculating footprint for Company_1_Sub_1
#   Using mass allocation
#   Product Copper coil (Mass=600): Assigned footprint 9823.8552
#   Product Copper residue (Mass=400): Assigned footprint 6549.2368
#   Final footprint for Company_1_Sub_1: 8514.0079
#
# Calculating footprint for Company_1
#   Using economic allocation
#   Product Product 1 (Sales=14.260690423988319): Assigned footprint 53.6265
#   Final footprint for Company_1: 53.6265
#   → Company_1 updated.
#
# Calculating footprint for Company_2
#   Using economic allocation
#   Product Product 2 (Sales=14.493943601470443): Assigned footprint 75.0865
#   Final footprint for Company_2: 75.0865
#   → Company_2 updated.
#
# Calculating footprint for Company_3
#   Using economic allocation
#   Product Product 3 (Sales=15.616834898514655): Assigned footprint 46.5427
#   Final footprint for Company_3: 46.5427
#   → Company_3 updated.
#
# Calculating footprint for Company_4
#   Using economic allocation
#   Product Product 4 (Sales=15.951473109750504): Assigned footprint 52.1724
#   Final footprint for Company_4: 52.1724
#   → Company_4 updated.
#
# Calculating footprint for Company_5
#   Using economic allocation
#   Product Product 5 (Sales=12.25733502304246): Assigned footprint 57.0557
#   Final footprint for Company_5: 57.0557
#   → Company_5 updated.
#
# Calculating footprint for Company_6
#   Using economic allocation
#   Product Product 6 (Sales=12.689936262491791): Assigned footprint 41.4474
#   Final footprint for Company_6: 41.4474
#   → Company_6 updated.
#
# Calculating footprint for Company_7
#   Using economic allocation
#   Product Product 7 (Sales=12.948904000293917): Assigned footprint 68.9243
#   Final footprint for Company_7: 68.9243
#   → Company_7 updated.
#
# Calculating footprint for Company_8
#   Using economic allocation
#   Product Product 8 (Sales=14.850433902213426): Assigned footprint 61.7284
#   Final footprint for Company_8: 61.7284
#   → Company_8 updated.
#
# Calculating footprint for Company_9
#   Using economic allocation
#   Product Product 9 (Sales=14.933457771877734): Assigned footprint 65.1727
#   Final footprint for Company_9: 65.1727
#   → Company_9 updated.
#
# Calculating footprint for Company_10
#   Using economic allocation
#   Product Product 10 (Sales=15.9696336183309): Assigned footprint 33.6737
#   Final footprint for Company_10: 33.6737
#   → Company_10 updated.
#
# --- Iteration 12 ---
#
# Calculating footprint for Company_1_Sub_1
#   Using mass allocation
#   Product Copper coil (Mass=600): Assigned footprint 9825.1484
#   Product Copper residue (Mass=400): Assigned footprint 6550.0990
#   Final footprint for Company_1_Sub_1: 8515.1286
#
# Calculating footprint for Company_1
#   Using economic allocation
#   Product Product 1 (Sales=14.260690423988319): Assigned footprint 53.6302
#   Final footprint for Company_1: 53.6302
#   → Company_1 updated.
#
# Calculating footprint for Company_2
#   Using economic allocation
#   Product Product 2 (Sales=14.493943601470443): Assigned footprint 75.0898
#   Final footprint for Company_2: 75.0898
#   → Company_2 updated.
#
# Calculating footprint for Company_3
#   Using economic allocation
#   Product Product 3 (Sales=15.616834898514655): Assigned footprint 46.5456
#   Final footprint for Company_3: 46.5456
#   → Company_3 updated.
#
# Calculating footprint for Company_4
#   Using economic allocation
#   Product Product 4 (Sales=15.951473109750504): Assigned footprint 52.1750
#   Final footprint for Company_4: 52.1750
#   → Company_4 updated.
#
# Calculating footprint for Company_5
#   Using economic allocation
#   Product Product 5 (Sales=12.25733502304246): Assigned footprint 57.0587
#   Final footprint for Company_5: 57.0587
#   → Company_5 updated.
#
# Calculating footprint for Company_6
#   Using economic allocation
#   Product Product 6 (Sales=12.689936262491791): Assigned footprint 41.4500
#   Final footprint for Company_6: 41.4500
#   → Company_6 updated.
#
# Calculating footprint for Company_7
#   Using economic allocation
#   Product Product 7 (Sales=12.948904000293917): Assigned footprint 68.9266
#   Final footprint for Company_7: 68.9266
#   → Company_7 updated.
#
# Calculating footprint for Company_8
#   Using economic allocation
#   Product Product 8 (Sales=14.850433902213426): Assigned footprint 61.7303
#   Final footprint for Company_8: 61.7303
#   → Company_8 updated.
#
# Calculating footprint for Company_9
#   Using economic allocation
#   Product Product 9 (Sales=14.933457771877734): Assigned footprint 65.1745
#   Final footprint for Company_9: 65.1745
#   → Company_9 updated.
#
# Calculating footprint for Company_10
#   Using economic allocation
#   Product Product 10 (Sales=15.9696336183309): Assigned footprint 33.6752
#   Final footprint for Company_10: 33.6752
#   → Company_10 updated.
#
# --- Iteration 13 ---
#
# Calculating footprint for Company_1_Sub_1
#   Using mass allocation
#   Product Copper coil (Mass=600): Assigned footprint 9825.6880
#   Product Copper residue (Mass=400): Assigned footprint 6550.4587
#   Final footprint for Company_1_Sub_1: 8515.5963
#
# Calculating footprint for Company_1
#   Using economic allocation
#   Product Product 1 (Sales=14.260690423988319): Assigned footprint 53.6317
#   Final footprint for Company_1: 53.6317
#   → Company_1 updated.
#
# Calculating footprint for Company_2
#   Using economic allocation
#   Product Product 2 (Sales=14.493943601470443): Assigned footprint 75.0912
#   Final footprint for Company_2: 75.0912
#   → Company_2 updated.
#
# Calculating footprint for Company_3
#   Using economic allocation
#   Product Product 3 (Sales=15.616834898514655): Assigned footprint 46.5468
#   Final footprint for Company_3: 46.5468
#   → Company_3 updated.
#
# Calculating footprint for Company_4
#   Using economic allocation
#   Product Product 4 (Sales=15.951473109750504): Assigned footprint 52.1761
#   Final footprint for Company_4: 52.1761
#   → Company_4 updated.
#
# Calculating footprint for Company_5
#   Using economic allocation
#   Product Product 5 (Sales=12.25733502304246): Assigned footprint 57.0599
#   Final footprint for Company_5: 57.0599
#   → Company_5 updated.
#
# Calculating footprint for Company_6
#   Using economic allocation
#   Product Product 6 (Sales=12.689936262491791): Assigned footprint 41.4511
#   Final footprint for Company_6: 41.4511
#   → Company_6 updated.
#
# Calculating footprint for Company_7
#   Using economic allocation
#   Product Product 7 (Sales=12.948904000293917): Assigned footprint 68.9276
#   Final footprint for Company_7: 68.9276
#   → Company_7 updated.
#
# Calculating footprint for Company_8
#   Using economic allocation
#   Product Product 8 (Sales=14.850433902213426): Assigned footprint 61.7311
#   Final footprint for Company_8: 61.7311
#   → Company_8 updated.
#
# Calculating footprint for Company_9
#   Using economic allocation
#   Product Product 9 (Sales=14.933457771877734): Assigned footprint 65.1752
#   Final footprint for Company_9: 65.1752
#   → Company_9 updated.
#
# Calculating footprint for Company_10
#   Using economic allocation
#   Product Product 10 (Sales=15.9696336183309): Assigned footprint 33.6758
#   Final footprint for Company_10: 33.6758
#   → Company_10 updated.
#
# --- Iteration 14 ---
#
# Calculating footprint for Company_1_Sub_1
#   Using mass allocation
#   Product Copper coil (Mass=600): Assigned footprint 9825.9131
#   Product Copper residue (Mass=400): Assigned footprint 6550.6087
#   Final footprint for Company_1_Sub_1: 8515.7914
#
# Calculating footprint for Company_1
#   Using economic allocation
#   Product Product 1 (Sales=14.260690423988319): Assigned footprint 53.6324
#   Final footprint for Company_1: 53.6324
#   → Company_1 updated.
#
# Calculating footprint for Company_2
#   Using economic allocation
#   Product Product 2 (Sales=14.493943601470443): Assigned footprint 75.0918
#   Final footprint for Company_2: 75.0918
#
# Calculating footprint for Company_3
#   Using economic allocation
#   Product Product 3 (Sales=15.616834898514655): Assigned footprint 46.5472
#   Final footprint for Company_3: 46.5472
#
# Calculating footprint for Company_4
#   Using economic allocation
#   Product Product 4 (Sales=15.951473109750504): Assigned footprint 52.1764
#   Final footprint for Company_4: 52.1764
#
# Calculating footprint for Company_5
#   Using economic allocation
#   Product Product 5 (Sales=12.25733502304246): Assigned footprint 57.0603
#   Final footprint for Company_5: 57.0603
#
# Calculating footprint for Company_6
#   Using economic allocation
#   Product Product 6 (Sales=12.689936262491791): Assigned footprint 41.4514
#   Final footprint for Company_6: 41.4514
#
# Calculating footprint for Company_7
#   Using economic allocation
#   Product Product 7 (Sales=12.948904000293917): Assigned footprint 68.9278
#   Final footprint for Company_7: 68.9278
#
# Calculating footprint for Company_8
#   Using economic allocation
#   Product Product 8 (Sales=14.850433902213426): Assigned footprint 61.7313
#   Final footprint for Company_8: 61.7313
#
# Calculating footprint for Company_9
#   Using economic allocation
#   Product Product 9 (Sales=14.933457771877734): Assigned footprint 65.1753
#   Final footprint for Company_9: 65.1753
#
# Calculating footprint for Company_10
#   Using economic allocation
#   Product Product 10 (Sales=15.9696336183309): Assigned footprint 33.6759
#   Final footprint for Company_10: 33.6759
#
# --- Iteration 15 ---
#
# Calculating footprint for Company_1_Sub_1
#   Using mass allocation
#   Product Copper coil (Mass=600): Assigned footprint 9825.9396
#   Product Copper residue (Mass=400): Assigned footprint 6550.6264
#   Final footprint for Company_1_Sub_1: 8515.8144
#
# Calculating footprint for Company_1
#   Using economic allocation
#   Product Product 1 (Sales=14.260690423988319): Assigned footprint 53.6324
#   Final footprint for Company_1: 53.6324
#
# Calculating footprint for Company_2
#   Using economic allocation
#   Product Product 2 (Sales=14.493943601470443): Assigned footprint 75.0918
#   Final footprint for Company_2: 75.0918
#
# Calculating footprint for Company_3
#   Using economic allocation
#   Product Product 3 (Sales=15.616834898514655): Assigned footprint 46.5472
#   Final footprint for Company_3: 46.5472
#
# Calculating footprint for Company_4
#   Using economic allocation
#   Product Product 4 (Sales=15.951473109750504): Assigned footprint 52.1764
#   Final footprint for Company_4: 52.1764
#
# Calculating footprint for Company_5
#   Using economic allocation
#   Product Product 5 (Sales=12.25733502304246): Assigned footprint 57.0603
#   Final footprint for Company_5: 57.0603
#
# Calculating footprint for Company_6
#   Using economic allocation
#   Product Product 6 (Sales=12.689936262491791): Assigned footprint 41.4514
#   Final footprint for Company_6: 41.4514
#
# Calculating footprint for Company_7
#   Using economic allocation
#   Product Product 7 (Sales=12.948904000293917): Assigned footprint 68.9278
#   Final footprint for Company_7: 68.9278
#
# Calculating footprint for Company_8
#   Using economic allocation
#   Product Product 8 (Sales=14.850433902213426): Assigned footprint 61.7313
#   Final footprint for Company_8: 61.7313
#
# Calculating footprint for Company_9
#   Using economic allocation
#   Product Product 9 (Sales=14.933457771877734): Assigned footprint 65.1753
#   Final footprint for Company_9: 65.1753
#
# Calculating footprint for Company_10
#   Using economic allocation
#   Product Product 10 (Sales=15.9696336183309): Assigned footprint 33.6759
#   Final footprint for Company_10: 33.6759
#
# ✅ Updates completed.
# ⏱️ Time taken: 0.22 seconds
#
# 📦 Final Footprints:
# Company_1: 53.6324 kg CO2e/unit
#   Company_1_Sub_1: 8515.8144
# Company_2: 75.0918 kg CO2e/unit
# Company_3: 46.5472 kg CO2e/unit
# Company_4: 52.1764 kg CO2e/unit
# Company_5: 57.0603 kg CO2e/unit
# Company_6: 41.4514 kg CO2e/unit
# Company_7: 68.9278 kg CO2e/unit
# Company_8: 61.7313 kg CO2e/unit
# Company_9: 65.1753 kg CO2e/unit
# Company_10: 33.6759 kg CO2e/unit
#
# 🗃️ Final footprint database:
#     id impact_ids       scores
# 0    1        CO2    53.632384
# 3    2        CO2    75.091200
# 4    3        CO2    46.546771
# 5    4        CO2    52.176061
# 6    5        CO2    57.059910
# 7    6        CO2    41.451138
# 8    7        CO2    68.927596
# 9    8        CO2    61.731131
# 10   9        CO2    65.175177
# 11  10        CO2    33.675834
# 1   11        CO2  9825.939647
# 2   12        CO2  6550.626431
