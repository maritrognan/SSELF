# %%
#simulate_base.ipynb
#Testing without hierarchy to make sure the base works
import time
import random
import numpy as np
from SSELF_base import System, FootprintDatabase

# Step 1: Initialize the system and footprint DB
system = System(num_companies=10, num_products=10)
footprint_db_2024 = FootprintDatabase(year=2024)

# Step 1: Initialize footprint database with 0 values
for company in system.companies.values():
    for product in company.products:
        footprint_db_2024.report(product.product_id, 0)

system.solve(footprint_db_2024, forced_updates=0, verbose=True)
# Out:
# --- Iteration 1 ---
# Checking Company_2
#
# Calculating footprint for Company 2
#   Product Product 2: Assigned footprint 20.4035
#   Final footprint for Company 2: 20.4035
#   → Updated. New: 20.4035
# Checking Company_4
#
# Calculating footprint for Company 4
#   Product Product 4: Assigned footprint 30.9540
#   Final footprint for Company 4: 30.9540
#   → Updated. New: 30.9540
# Checking Company_7
#
# Calculating footprint for Company 7
#   Product Product 7: Assigned footprint 23.0187
#   Final footprint for Company 7: 23.0187
#   → Updated. New: 23.0187
# Checking Company_3
#
# Calculating footprint for Company 3
#   Product Product 3: Assigned footprint 17.8834
#   Final footprint for Company 3: 17.8834
#   → Updated. New: 17.8834
# Checking Company_9
#
# Calculating footprint for Company 9
#   Product Product 9: Assigned footprint 25.9758
#   Final footprint for Company 9: 25.9758
#   → Updated. New: 25.9758
# Checking Company_1
#
# Calculating footprint for Company 1
#   Product Product 1: Assigned footprint 48.2538
#   Final footprint for Company 1: 48.2538
#   → Updated. New: 48.2538
# Checking Company_5
#
# Calculating footprint for Company 5
#   Product Product 5: Assigned footprint 66.9191
#   Final footprint for Company 5: 66.9191
#   → Updated. New: 66.9191
# Checking Company_8
#
# Calculating footprint for Company 8
#   Product Product 8: Assigned footprint 47.9496
#   Final footprint for Company 8: 47.9496
#   → Updated. New: 47.9496
# Checking Company_6
#
# Calculating footprint for Company 6
#   Product Product 6: Assigned footprint 75.2001
#   Final footprint for Company 6: 75.2001
#   → Updated. New: 75.2001
# Checking Company_10
#
# Calculating footprint for Company 10
#   Product Product 10: Assigned footprint 44.5011
#   Final footprint for Company 10: 44.5011
#   → Updated. New: 44.5011
#
# --- Iteration 2 ---
# Checking Company_3
#
# Calculating footprint for Company 3
#   Product Product 3: Assigned footprint 36.4538
#   Final footprint for Company 3: 36.4538
#   → Updated. New: 36.4538
# Checking Company_2
#
# Calculating footprint for Company 2
#   Product Product 2: Assigned footprint 46.6796
#   Final footprint for Company 2: 46.6796
#   → Updated. New: 46.6796
# Checking Company_7
#
# Calculating footprint for Company 7
#   Product Product 7: Assigned footprint 46.7510
#   Final footprint for Company 7: 46.7510
#   → Updated. New: 46.7510
# Checking Company_10
#
# Calculating footprint for Company 10
#   Product Product 10: Assigned footprint 49.5326
#   Final footprint for Company 10: 49.5326
#   → Updated. New: 49.5326
# Checking Company_1
#
# Calculating footprint for Company 1
#   Product Product 1: Assigned footprint 71.3727
#   Final footprint for Company 1: 71.3727
#   → Updated. New: 71.3727
# Checking Company_8
#
# Calculating footprint for Company 8
#   Product Product 8: Assigned footprint 60.6922
#   Final footprint for Company 8: 60.6922
#   → Updated. New: 60.6922
# Checking Company_6
#
# Calculating footprint for Company 6
#   Product Product 6: Assigned footprint 87.7264
#   Final footprint for Company 6: 87.7264
#   → Updated. New: 87.7264
# Checking Company_4
#
# Calculating footprint for Company 4
#   Product Product 4: Assigned footprint 68.2581
#   Final footprint for Company 4: 68.2581
#   → Updated. New: 68.2581
# Checking Company_5
#
# Calculating footprint for Company 5
#   Product Product 5: Assigned footprint 94.7029
#   Final footprint for Company 5: 94.7029
#   → Updated. New: 94.7029
# Checking Company_9
#
# Calculating footprint for Company 9
#   Product Product 9: Assigned footprint 65.1915
#   Final footprint for Company 9: 65.1915
#   → Updated. New: 65.1915
#
# --- Iteration 3 ---
# Checking Company_10
#
# Calculating footprint for Company 10
#   Product Product 10: Assigned footprint 60.7350
#   Final footprint for Company 10: 60.7350
#   → Updated. New: 60.7350
# Checking Company_9
#
# Calculating footprint for Company 9
#   Product Product 9: Assigned footprint 66.1264
#   Final footprint for Company 9: 66.1264
#   → Updated. New: 66.1264
# Checking Company_7
#
# Calculating footprint for Company 7
#   Product Product 7: Assigned footprint 57.6013
#   Final footprint for Company 7: 57.6013
#   → Updated. New: 57.6013
# Checking Company_6
#
# Calculating footprint for Company 6
#   Product Product 6: Assigned footprint 98.0821
#   Final footprint for Company 6: 98.0821
#   → Updated. New: 98.0821
# Checking Company_5
#
# Calculating footprint for Company 5
#   Product Product 5: Assigned footprint 100.8688
#   Final footprint for Company 5: 100.8688
#   → Updated. New: 100.8688
# Checking Company_2
#
# Calculating footprint for Company 2
#   Product Product 2: Assigned footprint 61.2230
#   Final footprint for Company 2: 61.2230
#   → Updated. New: 61.2230
# Checking Company_4
#
# Calculating footprint for Company 4
#   Product Product 4: Assigned footprint 77.8314
#   Final footprint for Company 4: 77.8314
#   → Updated. New: 77.8314
# Checking Company_1
#
# Calculating footprint for Company 1
#   Product Product 1: Assigned footprint 85.8659
#   Final footprint for Company 1: 85.8659
#   → Updated. New: 85.8659
# Checking Company_3
#
# Calculating footprint for Company 3
#   Product Product 3: Assigned footprint 53.6441
#   Final footprint for Company 3: 53.6441
#   → Updated. New: 53.6441
# Checking Company_8
#
# Calculating footprint for Company 8
#   Product Product 8: Assigned footprint 73.1823
#   Final footprint for Company 8: 73.1823
#   → Updated. New: 73.1823
#
# --- Iteration 4 ---
# Checking Company_1
#
# Calculating footprint for Company 1
#   Product Product 1: Assigned footprint 88.0924
#   Final footprint for Company 1: 88.0924
#   → Updated. New: 88.0924
# Checking Company_3
#
# Calculating footprint for Company 3
#   Product Product 3: Assigned footprint 54.5291
#   Final footprint for Company 3: 54.5291
#   → Updated. New: 54.5291
# Checking Company_5
#
# Calculating footprint for Company 5
#   Product Product 5: Assigned footprint 106.9363
#   Final footprint for Company 5: 106.9363
#   → Updated. New: 106.9363
# Checking Company_6
#
# Calculating footprint for Company 6
#   Product Product 6: Assigned footprint 104.8861
#   Final footprint for Company 6: 104.8861
#   → Updated. New: 104.8861
# Checking Company_4
#
# Calculating footprint for Company 4
#   Product Product 4: Assigned footprint 82.5889
#   Final footprint for Company 4: 82.5889
#   → Updated. New: 82.5889
# Checking Company_7
#
# Calculating footprint for Company 7
#   Product Product 7: Assigned footprint 64.3437
#   Final footprint for Company 7: 64.3437
#   → Updated. New: 64.3437
# Checking Company_8
#
# Calculating footprint for Company 8
#   Product Product 8: Assigned footprint 74.8004
#   Final footprint for Company 8: 74.8004
#   → Updated. New: 74.8004
# Checking Company_2
#
# Calculating footprint for Company 2
#   Product Product 2: Assigned footprint 66.6758
#   Final footprint for Company 2: 66.6758
#   → Updated. New: 66.6758
# Checking Company_9
#
# Calculating footprint for Company 9
#   Product Product 9: Assigned footprint 76.9934
#   Final footprint for Company 9: 76.9934
#   → Updated. New: 76.9934
# Checking Company_10
#
# Calculating footprint for Company 10
#   Product Product 10: Assigned footprint 71.1544
#   Final footprint for Company 10: 71.1544
#   → Updated. New: 71.1544
#
# --- Iteration 5 ---
# Checking Company_10
#
# Calculating footprint for Company 10
#   Product Product 10: Assigned footprint 71.1544
#   Final footprint for Company 10: 71.1544
#   → No update needed.
# Checking Company_2
#
# Calculating footprint for Company 2
#   Product Product 2: Assigned footprint 68.0768
#   Final footprint for Company 2: 68.0768
#   → Updated. New: 68.0768
# Checking Company_4
#
# Calculating footprint for Company 4
#   Product Product 4: Assigned footprint 85.4755
#   Final footprint for Company 4: 85.4755
#   → Updated. New: 85.4755
# Checking Company_7
#
# Calculating footprint for Company 7
#   Product Product 7: Assigned footprint 66.4290
#   Final footprint for Company 7: 66.4290
#   → Updated. New: 66.4290
# Checking Company_3
#
# Calculating footprint for Company 3
#   Product Product 3: Assigned footprint 58.0834
#   Final footprint for Company 3: 58.0834
#   → Updated. New: 58.0834
# Checking Company_9
#
# Calculating footprint for Company 9
#   Product Product 9: Assigned footprint 78.6914
#   Final footprint for Company 9: 78.6914
#   → Updated. New: 78.6914
# Checking Company_6
#
# Calculating footprint for Company 6
#   Product Product 6: Assigned footprint 109.0744
#   Final footprint for Company 6: 109.0744
#   → Updated. New: 109.0744
# Checking Company_1
#
# Calculating footprint for Company 1
#   Product Product 1: Assigned footprint 93.3007
#   Final footprint for Company 1: 93.3007
#   → Updated. New: 93.3007
# Checking Company_5
#
# Calculating footprint for Company 5
#   Product Product 5: Assigned footprint 112.6879
#   Final footprint for Company 5: 112.6879
#   → Updated. New: 112.6879
# Checking Company_8
#
# Calculating footprint for Company 8
#   Product Product 8: Assigned footprint 77.9510
#   Final footprint for Company 8: 77.9510
#   → Updated. New: 77.9510
#
# --- Iteration 6 ---
# Checking Company_10
#
# Calculating footprint for Company 10
#   Product Product 10: Assigned footprint 73.3498
#   Final footprint for Company 10: 73.3498
#   → Updated. New: 73.3498
# Checking Company_3
#
# Calculating footprint for Company 3
#   Product Product 3: Assigned footprint 59.4179
#   Final footprint for Company 3: 59.4179
#   → Updated. New: 59.4179
# Checking Company_5
#
# Calculating footprint for Company 5
#   Product Product 5: Assigned footprint 113.2556
#   Final footprint for Company 5: 113.2556
#   → Updated. New: 113.2556
# Checking Company_7
#
# Calculating footprint for Company 7
#   Product Product 7: Assigned footprint 68.1951
#   Final footprint for Company 7: 68.1951
#   → Updated. New: 68.1951
# Checking Company_6
#
# Calculating footprint for Company 6
#   Product Product 6: Assigned footprint 110.6994
#   Final footprint for Company 6: 110.6994
#   → Updated. New: 110.6994
# Checking Company_9
#
# Calculating footprint for Company 9
#   Product Product 9: Assigned footprint 80.8434
#   Final footprint for Company 9: 80.8434
#   → Updated. New: 80.8434
# Checking Company_1
#
# Calculating footprint for Company 1
#   Product Product 1: Assigned footprint 94.6917
#   Final footprint for Company 1: 94.6917
#   → Updated. New: 94.6917
# Checking Company_8
#
# Calculating footprint for Company 8
#   Product Product 8: Assigned footprint 78.6005
#   Final footprint for Company 8: 78.6005
#   → Updated. New: 78.6005
# Checking Company_2
#
# Calculating footprint for Company 2
#   Product Product 2: Assigned footprint 70.7230
#   Final footprint for Company 2: 70.7230
#   → Updated. New: 70.7230
# Checking Company_4
#
# Calculating footprint for Company 4
#   Product Product 4: Assigned footprint 88.6361
#   Final footprint for Company 4: 88.6361
#   → Updated. New: 88.6361
#
# --- Iteration 7 ---
# Checking Company_2
#
# Calculating footprint for Company 2
#   Product Product 2: Assigned footprint 70.9310
#   Final footprint for Company 2: 70.9310
#   → Updated. New: 70.9310
# Checking Company_7
#
# Calculating footprint for Company 7
#   Product Product 7: Assigned footprint 68.9509
#   Final footprint for Company 7: 68.9509
#   → Updated. New: 68.9509
# Checking Company_10
#
# Calculating footprint for Company 10
#   Product Product 10: Assigned footprint 74.5425
#   Final footprint for Company 10: 74.5425
#   → Updated. New: 74.5425
# Checking Company_4
#
# Calculating footprint for Company 4
#   Product Product 4: Assigned footprint 88.8066
#   Final footprint for Company 4: 88.8066
#   → Updated. New: 88.8066
# Checking Company_5
#
# Calculating footprint for Company 5
#   Product Product 5: Assigned footprint 114.5912
#   Final footprint for Company 5: 114.5912
#   → Updated. New: 114.5912
# Checking Company_1
#
# Calculating footprint for Company 1
#   Product Product 1: Assigned footprint 95.4508
#   Final footprint for Company 1: 95.4508
#   → Updated. New: 95.4508
# Checking Company_8
#
# Calculating footprint for Company 8
#   Product Product 8: Assigned footprint 79.2027
#   Final footprint for Company 8: 79.2027
#   → Updated. New: 79.2027
# Checking Company_3
#
# Calculating footprint for Company 3
#   Product Product 3: Assigned footprint 60.5595
#   Final footprint for Company 3: 60.5595
#   → Updated. New: 60.5595
# Checking Company_6
#
# Calculating footprint for Company 6
#   Product Product 6: Assigned footprint 112.0145
#   Final footprint for Company 6: 112.0145
#   → Updated. New: 112.0145
# Checking Company_9
#
# Calculating footprint for Company 9
#   Product Product 9: Assigned footprint 82.1226
#   Final footprint for Company 9: 82.1226
#   → Updated. New: 82.1226
#
# --- Iteration 8 ---
# Checking Company_2
#
# Calculating footprint for Company 2
#   Product Product 2: Assigned footprint 71.4939
#   Final footprint for Company 2: 71.4939
#   → Updated. New: 71.4939
# Checking Company_7
#
# Calculating footprint for Company 7
#   Product Product 7: Assigned footprint 69.4849
#   Final footprint for Company 7: 69.4849
#   → Updated. New: 69.4849
# Checking Company_9
#
# Calculating footprint for Company 9
#   Product Product 9: Assigned footprint 82.2141
#   Final footprint for Company 9: 82.2141
#   → Updated. New: 82.2141
# Checking Company_6
#
# Calculating footprint for Company 6
#   Product Product 6: Assigned footprint 112.2152
#   Final footprint for Company 6: 112.2152
#   → Updated. New: 112.2152
# Checking Company_4
#
# Calculating footprint for Company 4
#   Product Product 4: Assigned footprint 89.4252
#   Final footprint for Company 4: 89.4252
#   → Updated. New: 89.4252
# Checking Company_1
#
# Calculating footprint for Company 1
#   Product Product 1: Assigned footprint 95.9269
#   Final footprint for Company 1: 95.9269
#   → Updated. New: 95.9269
# Checking Company_8
#
# Calculating footprint for Company 8
#   Product Product 8: Assigned footprint 79.5689
#   Final footprint for Company 8: 79.5689
#   → Updated. New: 79.5689
# Checking Company_5
#
# Calculating footprint for Company 5
#   Product Product 5: Assigned footprint 115.2665
#   Final footprint for Company 5: 115.2665
#   → Updated. New: 115.2665
# Checking Company_3
#
# Calculating footprint for Company 3
#   Product Product 3: Assigned footprint 60.9275
#   Final footprint for Company 3: 60.9275
#   → Updated. New: 60.9275
# Checking Company_10
#
# Calculating footprint for Company 10
#   Product Product 10: Assigned footprint 75.3126
#   Final footprint for Company 10: 75.3126
#   → Updated. New: 75.3126
#
# --- Iteration 9 ---
# Checking Company_4
#
# Calculating footprint for Company 4
#   Product Product 4: Assigned footprint 89.6352
#   Final footprint for Company 4: 89.6352
#   → Updated. New: 89.6352
# Checking Company_7
#
# Calculating footprint for Company 7
#   Product Product 7: Assigned footprint 69.7261
#   Final footprint for Company 7: 69.7261
#   → Updated. New: 69.7261
# Checking Company_3
#
# Calculating footprint for Company 3
#   Product Product 3: Assigned footprint 61.0009
#   Final footprint for Company 3: 61.0009
#   → Updated. New: 61.0009
# Checking Company_8
#
# Calculating footprint for Company 8
#   Product Product 8: Assigned footprint 79.7066
#   Final footprint for Company 8: 79.7066
#   → Updated. New: 79.7066
# Checking Company_6
#
# Calculating footprint for Company 6
#   Product Product 6: Assigned footprint 112.5355
#   Final footprint for Company 6: 112.5355
#   → Updated. New: 112.5355
# Checking Company_2
#
# Calculating footprint for Company 2
#   Product Product 2: Assigned footprint 71.8284
#   Final footprint for Company 2: 71.8284
#   → Updated. New: 71.8284
# Checking Company_5
#
# Calculating footprint for Company 5
#   Product Product 5: Assigned footprint 115.4752
#   Final footprint for Company 5: 115.4752
#   → Updated. New: 115.4752
# Checking Company_1
#
# Calculating footprint for Company 1
#   Product Product 1: Assigned footprint 96.2048
#   Final footprint for Company 1: 96.2048
#   → Updated. New: 96.2048
# Checking Company_9
#
# Calculating footprint for Company 9
#   Product Product 9: Assigned footprint 82.6547
#   Final footprint for Company 9: 82.6547
#   → Updated. New: 82.6547
# Checking Company_10
#
# Calculating footprint for Company 10
#   Product Product 10: Assigned footprint 75.4773
#   Final footprint for Company 10: 75.4773
#   → Updated. New: 75.4773
#
# --- Iteration 10 ---
# Checking Company_3
#
# Calculating footprint for Company 3
#   Product Product 3: Assigned footprint 61.1143
#   Final footprint for Company 3: 61.1143
#   → Updated. New: 61.1143
# Checking Company_2
#
# Calculating footprint for Company 2
#   Product Product 2: Assigned footprint 71.9077
#   Final footprint for Company 2: 71.9077
#   → Updated. New: 71.9077
# Checking Company_5
#
# Calculating footprint for Company 5
#   Product Product 5: Assigned footprint 115.5666
#   Final footprint for Company 5: 115.5666
#   → Updated. New: 115.5666
# Checking Company_7
#
# Calculating footprint for Company 7
#   Product Product 7: Assigned footprint 69.8693
#   Final footprint for Company 7: 69.8693
#   → Updated. New: 69.8693
# Checking Company_10
#
# Calculating footprint for Company 10
#   Product Product 10: Assigned footprint 75.5086
#   Final footprint for Company 10: 75.5086
#   → Updated. New: 75.5086
# Checking Company_6
#
# Calculating footprint for Company 6
#   Product Product 6: Assigned footprint 112.6888
#   Final footprint for Company 6: 112.6888
#   → Updated. New: 112.6888
# Checking Company_4
#
# Calculating footprint for Company 4
#   Product Product 4: Assigned footprint 89.8575
#   Final footprint for Company 4: 89.8575
#   → Updated. New: 89.8575
# Checking Company_8
#
# Calculating footprint for Company 8
#   Product Product 8: Assigned footprint 79.8585
#   Final footprint for Company 8: 79.8585
#   → Updated. New: 79.8585
# Checking Company_9
#
# Calculating footprint for Company 9
#   Product Product 9: Assigned footprint 82.7507
#   Final footprint for Company 9: 82.7507
#   → Updated. New: 82.7507
# Checking Company_1
#
# Calculating footprint for Company 1
#   Product Product 1: Assigned footprint 96.3314
#   Final footprint for Company 1: 96.3314
#   → Updated. New: 96.3314
#
# --- Iteration 11 ---
# Checking Company_2
#
# Calculating footprint for Company 2
#   Product Product 2: Assigned footprint 71.9746
#   Final footprint for Company 2: 71.9746
#   → Updated. New: 71.9746
# Checking Company_5
#
# Calculating footprint for Company 5
#   Product Product 5: Assigned footprint 115.6509
#   Final footprint for Company 5: 115.6509
#   → Updated. New: 115.6509
# Checking Company_1
#
# Calculating footprint for Company 1
#   Product Product 1: Assigned footprint 96.3428
#   Final footprint for Company 1: 96.3428
#   → Updated. New: 96.3428
# Checking Company_4
#
# Calculating footprint for Company 4
#   Product Product 4: Assigned footprint 89.9000
#   Final footprint for Company 4: 89.9000
#   → Updated. New: 89.9000
# Checking Company_9
#
# Calculating footprint for Company 9
#   Product Product 9: Assigned footprint 82.7784
#   Final footprint for Company 9: 82.7784
#   → Updated. New: 82.7784
# Checking Company_7
#
# Calculating footprint for Company 7
#   Product Product 7: Assigned footprint 69.9341
#   Final footprint for Company 7: 69.9341
#   → Updated. New: 69.9341
# Checking Company_6
#
# Calculating footprint for Company 6
#   Product Product 6: Assigned footprint 112.7616
#   Final footprint for Company 6: 112.7616
#   → Updated. New: 112.7616
# Checking Company_3
#
# Calculating footprint for Company 3
#   Product Product 3: Assigned footprint 61.2024
#   Final footprint for Company 3: 61.2024
#   → Updated. New: 61.2024
# Checking Company_8
#
# Calculating footprint for Company 8
#   Product Product 8: Assigned footprint 79.8986
#   Final footprint for Company 8: 79.8986
#   → Updated. New: 79.8986
# Checking Company_10
#
# Calculating footprint for Company 10
#   Product Product 10: Assigned footprint 75.6002
#   Final footprint for Company 10: 75.6002
#   → Updated. New: 75.6002
#
# --- Iteration 12 ---
# Checking Company_1
#
# Calculating footprint for Company 1
#   Product Product 1: Assigned footprint 96.3748
#   Final footprint for Company 1: 96.3748
#   → Updated. New: 96.3748
# Checking Company_2
#
# Calculating footprint for Company 2
#   Product Product 2: Assigned footprint 72.0112
#   Final footprint for Company 2: 72.0112
#   → Updated. New: 72.0112
# Checking Company_6
#
# Calculating footprint for Company 6
#   Product Product 6: Assigned footprint 112.7850
#   Final footprint for Company 6: 112.7850
#   → Updated. New: 112.7850
# Checking Company_3
#
# Calculating footprint for Company 3
#   Product Product 3: Assigned footprint 61.2159
#   Final footprint for Company 3: 61.2159
#   → Updated. New: 61.2159
# Checking Company_9
#
# Calculating footprint for Company 9
#   Product Product 9: Assigned footprint 82.8170
#   Final footprint for Company 9: 82.8170
#   → Updated. New: 82.8170
# Checking Company_4
#
# Calculating footprint for Company 4
#   Product Product 4: Assigned footprint 89.9418
#   Final footprint for Company 4: 89.9418
#   → Updated. New: 89.9418
# Checking Company_7
#
# Calculating footprint for Company 7
#   Product Product 7: Assigned footprint 69.9646
#   Final footprint for Company 7: 69.9646
#   → Updated. New: 69.9646
# Checking Company_10
#
# Calculating footprint for Company 10
#   Product Product 10: Assigned footprint 75.6161
#   Final footprint for Company 10: 75.6161
#   → Updated. New: 75.6161
# Checking Company_8
#
# Calculating footprint for Company 8
#   Product Product 8: Assigned footprint 79.9177
#   Final footprint for Company 8: 79.9177
#   → Updated. New: 79.9177
# Checking Company_5
#
# Calculating footprint for Company 5
#   Product Product 5: Assigned footprint 115.7095
#   Final footprint for Company 5: 115.7095
#   → Updated. New: 115.7095
#
# --- Iteration 13 ---
# Checking Company_5
#
# Calculating footprint for Company 5
#   Product Product 5: Assigned footprint 115.7095
#   Final footprint for Company 5: 115.7095
#   → No update needed.
# Checking Company_3
#
# Calculating footprint for Company 3
#   Product Product 3: Assigned footprint 61.2282
#   Final footprint for Company 3: 61.2282
#   → Updated. New: 61.2282
# Checking Company_4
#
# Calculating footprint for Company 4
#   Product Product 4: Assigned footprint 89.9526
#   Final footprint for Company 4: 89.9526
#   → Updated. New: 89.9526
# Checking Company_2
#
# Calculating footprint for Company 2
#   Product Product 2: Assigned footprint 72.0286
#   Final footprint for Company 2: 72.0286
#   → Updated. New: 72.0286
# Checking Company_10
#
# Calculating footprint for Company 10
#   Product Product 10: Assigned footprint 75.6248
#   Final footprint for Company 10: 75.6248
#   → Updated. New: 75.6248
# Checking Company_7
#
# Calculating footprint for Company 7
#   Product Product 7: Assigned footprint 69.9738
#   Final footprint for Company 7: 69.9738
#   → Updated. New: 69.9738
# Checking Company_9
#
# Calculating footprint for Company 9
#   Product Product 9: Assigned footprint 82.8357
#   Final footprint for Company 9: 82.8357
#   → Updated. New: 82.8357
# Checking Company_1
#
# Calculating footprint for Company 1
#   Product Product 1: Assigned footprint 96.4015
#   Final footprint for Company 1: 96.4015
#   → Updated. New: 96.4015
# Checking Company_6
#
# Calculating footprint for Company 6
#   Product Product 6: Assigned footprint 112.8112
#   Final footprint for Company 6: 112.8112
#   → Updated. New: 112.8112
# Checking Company_8
#
# Calculating footprint for Company 8
#   Product Product 8: Assigned footprint 79.9288
#   Final footprint for Company 8: 79.9288
#   → Updated. New: 79.9288
#
# --- Iteration 14 ---
# Checking Company_7
#
# Calculating footprint for Company 7
#   Product Product 7: Assigned footprint 69.9790
#   Final footprint for Company 7: 69.9790
#   → Updated. New: 69.9790
# Checking Company_8
#
# Calculating footprint for Company 8
#   Product Product 8: Assigned footprint 79.9291
#   Final footprint for Company 8: 79.9291
#   → No update needed.
# Checking Company_5
#
# Calculating footprint for Company 5
#   Product Product 5: Assigned footprint 115.7220
#   Final footprint for Company 5: 115.7220
#   → Updated. New: 115.7220
# Checking Company_2
#
# Calculating footprint for Company 2
#   Product Product 2: Assigned footprint 72.0364
#   Final footprint for Company 2: 72.0364
#   → Updated. New: 72.0364
# Checking Company_9
#
# Calculating footprint for Company 9
#   Product Product 9: Assigned footprint 82.8432
#   Final footprint for Company 9: 82.8432
#   → Updated. New: 82.8432
# Checking Company_3
#
# Calculating footprint for Company 3
#   Product Product 3: Assigned footprint 61.2379
#   Final footprint for Company 3: 61.2379
#   → Updated. New: 61.2379
# Checking Company_10
#
# Calculating footprint for Company 10
#   Product Product 10: Assigned footprint 75.6347
#   Final footprint for Company 10: 75.6347
#   → Updated. New: 75.6347
# Checking Company_4
#
# Calculating footprint for Company 4
#   Product Product 4: Assigned footprint 89.9661
#   Final footprint for Company 4: 89.9661
#   → Updated. New: 89.9661
# Checking Company_1
#
# Calculating footprint for Company 1
#   Product Product 1: Assigned footprint 96.4092
#   Final footprint for Company 1: 96.4092
#   → Updated. New: 96.4092
# Checking Company_6
#
# Calculating footprint for Company 6
#   Product Product 6: Assigned footprint 112.8181
#   Final footprint for Company 6: 112.8181
#   → Updated. New: 112.8181
#
# --- Iteration 15 ---
# Checking Company_4
#
# Calculating footprint for Company 4
#   Product Product 4: Assigned footprint 89.9673
#   Final footprint for Company 4: 89.9673
#   → Updated. New: 89.9673
# Checking Company_8
#
# Calculating footprint for Company 8
#   Product Product 8: Assigned footprint 79.9336
#   Final footprint for Company 8: 79.9336
#   → Updated. New: 79.9336
# Checking Company_3
#
# Calculating footprint for Company 3
#   Product Product 3: Assigned footprint 61.2405
#   Final footprint for Company 3: 61.2405
#   → Updated. New: 61.2405
# Checking Company_2
#
# Calculating footprint for Company 2
#   Product Product 2: Assigned footprint 72.0406
#   Final footprint for Company 2: 72.0406
#   → Updated. New: 72.0406
# Checking Company_5
#
# Calculating footprint for Company 5
#   Product Product 5: Assigned footprint 115.7284
#   Final footprint for Company 5: 115.7284
#   → Updated. New: 115.7284
# Checking Company_1
#
# Calculating footprint for Company 1
#   Product Product 1: Assigned footprint 96.4112
#   Final footprint for Company 1: 96.4112
#   → Updated. New: 96.4112
# Checking Company_7
#
# Calculating footprint for Company 7
#   Product Product 7: Assigned footprint 69.9852
#   Final footprint for Company 7: 69.9852
#   → Updated. New: 69.9852
# Checking Company_9
#
# Calculating footprint for Company 9
#   Product Product 9: Assigned footprint 82.8495
#   Final footprint for Company 9: 82.8495
#   → Updated. New: 82.8495
# Checking Company_10
#
# Calculating footprint for Company 10
#   Product Product 10: Assigned footprint 75.6392
#   Final footprint for Company 10: 75.6392
#   → Updated. New: 75.6392
# Checking Company_6
#
# Calculating footprint for Company 6
#   Product Product 6: Assigned footprint 112.8212
#   Final footprint for Company 6: 112.8212
#   → Updated. New: 112.8212
#
# --- Iteration 16 ---
# Checking Company_5
#
# Calculating footprint for Company 5
#   Product Product 5: Assigned footprint 115.7303
#   Final footprint for Company 5: 115.7303
#   → Updated. New: 115.7303
# Checking Company_2
#
# Calculating footprint for Company 2
#   Product Product 2: Assigned footprint 72.0426
#   Final footprint for Company 2: 72.0426
#   → Updated. New: 72.0426
# Checking Company_1
#
# Calculating footprint for Company 1
#   Product Product 1: Assigned footprint 96.4130
#   Final footprint for Company 1: 96.4130
#   → Updated. New: 96.4130
# Checking Company_4
#
# Calculating footprint for Company 4
#   Product Product 4: Assigned footprint 89.9709
#   Final footprint for Company 4: 89.9709
#   → Updated. New: 89.9709
# Checking Company_6
#
# Calculating footprint for Company 6
#   Product Product 6: Assigned footprint 112.8220
#   Final footprint for Company 6: 112.8220
#   → No update needed.
# Checking Company_9
#
# Calculating footprint for Company 9
#   Product Product 9: Assigned footprint 82.8509
#   Final footprint for Company 9: 82.8509
#   → Updated. New: 82.8509
# Checking Company_7
#
# Calculating footprint for Company 7
#   Product Product 7: Assigned footprint 69.9868
#   Final footprint for Company 7: 69.9868
#   → Updated. New: 69.9868
# Checking Company_3
#
# Calculating footprint for Company 3
#   Product Product 3: Assigned footprint 61.2432
#   Final footprint for Company 3: 61.2432
#   → Updated. New: 61.2432
# Checking Company_8
#
# Calculating footprint for Company 8
#   Product Product 8: Assigned footprint 79.9366
#   Final footprint for Company 8: 79.9366
#   → Updated. New: 79.9366
# Checking Company_10
#
# Calculating footprint for Company 10
#   Product Product 10: Assigned footprint 75.6407
#   Final footprint for Company 10: 75.6407
#   → Updated. New: 75.6407
#
# --- Iteration 17 ---
# Checking Company_4
#
# Calculating footprint for Company 4
#   Product Product 4: Assigned footprint 89.9717
#   Final footprint for Company 4: 89.9717
#   → No update needed.
# Checking Company_10
#
# Calculating footprint for Company 10
#   Product Product 10: Assigned footprint 75.6407
#   Final footprint for Company 10: 75.6407
#   → No update needed.
# Checking Company_9
#
# Calculating footprint for Company 9
#   Product Product 9: Assigned footprint 82.8516
#   Final footprint for Company 9: 82.8516
#   → No update needed.
# Checking Company_6
#
# Calculating footprint for Company 6
#   Product Product 6: Assigned footprint 112.8228
#   Final footprint for Company 6: 112.8228
#   → No update needed.
# Checking Company_3
#
# Calculating footprint for Company 3
#   Product Product 3: Assigned footprint 61.2435
#   Final footprint for Company 3: 61.2435
#   → No update needed.
# Checking Company_2
#
# Calculating footprint for Company 2
#   Product Product 2: Assigned footprint 72.0436
#   Final footprint for Company 2: 72.0436
#   → Updated. New: 72.0436
# Checking Company_1
#
# Calculating footprint for Company 1
#   Product Product 1: Assigned footprint 96.4141
#   Final footprint for Company 1: 96.4141
#   → Updated. New: 96.4141
# Checking Company_5
#
# Calculating footprint for Company 5
#   Product Product 5: Assigned footprint 115.7320
#   Final footprint for Company 5: 115.7320
#   → Updated. New: 115.7320
# Checking Company_7
#
# Calculating footprint for Company 7
#   Product Product 7: Assigned footprint 69.9875
#   Final footprint for Company 7: 69.9875
#   → Updated. New: 69.9875
# Checking Company_8
#
# Calculating footprint for Company 8
#   Product Product 8: Assigned footprint 79.9369
#   Final footprint for Company 8: 79.9369
#   → No update needed.
#
# --- Iteration 18 ---
# Checking Company_7
#
# Calculating footprint for Company 7
#   Product Product 7: Assigned footprint 69.9875
#   Final footprint for Company 7: 69.9875
#   → No update needed.
# Checking Company_6
#
# Calculating footprint for Company 6
#   Product Product 6: Assigned footprint 112.8232
#   Final footprint for Company 6: 112.8232
#   → No update needed.
# Checking Company_3
#
# Calculating footprint for Company 3
#   Product Product 3: Assigned footprint 61.2438
#   Final footprint for Company 3: 61.2438
#   → No update needed.
# Checking Company_2
#
# Calculating footprint for Company 2
#   Product Product 2: Assigned footprint 72.0438
#   Final footprint for Company 2: 72.0438
#   → No update needed.
# Checking Company_1
#
# Calculating footprint for Company 1
#   Product Product 1: Assigned footprint 96.4143
#   Final footprint for Company 1: 96.4143
#   → No update needed.
# Checking Company_9
#
# Calculating footprint for Company 9
#   Product Product 9: Assigned footprint 82.8520
#   Final footprint for Company 9: 82.8520
#   → No update needed.
# Checking Company_10
#
# Calculating footprint for Company 10
#   Product Product 10: Assigned footprint 75.6411
#   Final footprint for Company 10: 75.6411
#   → No update needed.
# Checking Company_4
#
# Calculating footprint for Company 4
#   Product Product 4: Assigned footprint 89.9721
#   Final footprint for Company 4: 89.9721
#   → No update needed.
# Checking Company_5
#
# Calculating footprint for Company 5
#   Product Product 5: Assigned footprint 115.7320
#   Final footprint for Company 5: 115.7320
#   → No update needed.
# Checking Company_8
#
# Calculating footprint for Company 8
#   Product Product 8: Assigned footprint 79.9369
#   Final footprint for Company 8: 79.9369
#   → No update needed.
#
# ✅ Updates completed.
# ⏱️ Time taken: 0.41 seconds
#
# 📦 Final Footprints:
# Company_1: 96.4143 kg CO2e/unit
# Company_2: 72.0438 kg CO2e/unit
# Company_3: 61.2438 kg CO2e/unit
# Company_4: 89.9721 kg CO2e/unit
# Company_5: 115.7320 kg CO2e/unit
# Company_6: 112.8232 kg CO2e/unit
# Company_7: 69.9875 kg CO2e/unit
# Company_8: 79.9369 kg CO2e/unit
# Company_9: 82.8520 kg CO2e/unit
# Company_10: 75.6411 kg CO2e/unit
#
# 🔁 Update Count:
# Company_1: 17 updates
# Company_2: 17 updates
# Company_3: 16 updates
# Company_4: 16 updates
# Company_5: 16 updates
# Company_6: 15 updates
# Company_7: 17 updates
# Company_8: 15 updates
# Company_9: 16 updates
# Company_10: 15 updates
# Total updates: 160
#
# 🗃️ Final footprint database:
#    id impact_ids      scores
# 0   1        CO2   96.414101
# 1   2        CO2   72.043599
# 2   3        CO2   61.243230
# 3   4        CO2   89.970899
# 4   5        CO2  115.731963
# 5   6        CO2  112.821232
# 6   7        CO2   69.987494
# 7   8        CO2   79.936586
# 8   9        CO2   82.850889
# 9  10        CO2   75.640730

# %% [markdown]
# # Step 3: Iterative update loop
# updates_completed = False
# iteration = 0
# start_time = time.time()
#
# while not updates_completed:
#     iteration += 1
#     print(f"\n--- Iteration {iteration} ---")
#     any_company_updated = False
#
#     companies_to_check = list(system.companies.keys())
#     random.shuffle(companies_to_check)
#
#     for cname in companies_to_check:
#         company = system.companies[cname]
#         print(f"Checking {cname}")
#         if company.check_update_needed(footprint_db_2024):
#             print(f"  → Updated. New: {company.latest_update:.4f}")
#             any_company_updated = True
#         else:
#             print("  → No update needed.")
#
#     updates_completed = not any_company_updated
#
# end_time = time.time()
#
# # Step 4: Summary
# print("\n✅ Updates completed.")
# print(f"⏱️ Time taken: {end_time - start_time:.2f} seconds")
#
# print("\n📦 Final Footprints:")
# for cname, company in system.companies.items():
#     print(f"{cname}: {company.latest_update:.4f} kg CO2e/unit")
#
# print("\n🔁 Update Count:")
# total_updates = sum(c.num_updates for c in system.companies.values())
# for cname, c in system.companies.items():
#     print(f"{cname}: {c.num_updates} updates")
# print(f"Total updates: {total_updates}")
#
# # Step 5: Optional forced recheck
# for i in range(3):
#     print(f"\n--- Forced Update Iteration {i+1} ---")
#     for cname, company in system.companies.items():
#         company.update_footprint(footprint_db_2024)
#         company.report_footprint(footprint_db_2024)
